# %%
import pandas as pd

code_data = pd.read_csv('./산업코드_11차.csv')
code_data.head()
# Out:
#    산업코드             산업코드명
# 0     1                농업
# 1     2                임업
# 2     3                어업
# 3     5  석탄, 원유 및 천연가스 광업
# 4     6             금속 광업

# %%
import requests
import time
from sqlalchemy import create_engine, text
import pymysql
import pandas as pd

# OpenDART API 인증키
API_KEY = "4643bd437d383b208294914ce72d693589458062"

# DART API 기본 URL
BASE_URL = "https://opendart.fss.or.kr/api/company.json"

# AWS RDS 연결 정보
DB_URL = "mysql+pymysql://root:1234@localhost:3310/stock_db"

# DB 엔진 생성
engine = create_engine(DB_URL)

def fetch_corp_codes():
    query = "SELECT DISTINCT corp_code FROM dart_code"
    with engine.connect() as conn:
        result = conn.execute(text(query))
        corp_codes = [row[0] for row in result.fetchall()]
    return corp_codes

def fetch_overview(corp_code):
    params = {
        "crtfc_key": API_KEY,
        "corp_code": corp_code
    }
    res = requests.get(BASE_URL, params=params)
    if res.status_code == 200 and res.json().get("status") == "013":
        return None  # 존재하지 않는 기업
    return res.json()

def get_industry_name(induty_code):
    try:
        return code_data[code_data['산업코드'] == int(induty_code)]['산업코드명'].values[0]
    except (IndexError, KeyError):
        return ""

def insert_or_update_overview(data):
    # 산업코드명 자동 매칭
    induty_code = data.get("induty_code", "")
    induty_name = get_industry_name(induty_code) if induty_code else ""

    # 누락 방지용 안전한 데이터 딕셔너리
    safe_data = {
        "corp_code": data.get("corp_code", ""),
        "corp_name": data.get("corp_name", ""),
        "stock_code": data.get("stock_code", ""),
        "ceo_nm": data.get("ceo_nm", ""),
        "corp_cls": data.get("corp_cls", ""),
        "jurir_no": data.get("jurir_no", ""),
        "bizr_no": data.get("bizr_no", ""),
        "adres": data.get("adres", ""),
        "hm_url": data.get("hm_url", ""),
        "ir_url": data.get("ir_url", ""),
        "phn_no": data.get("phn_no", ""),
        "fax_no": data.get("fax_no", ""),
        "induty_code": induty_code,
        "induty_name": induty_name,
        "est_dt": data.get("est_dt", ""),
        "acc_mt": data.get("acc_mt", "")
    }

    insert_query = """
    INSERT INTO company_overview_row (
        corp_code, corp_name, stock_code, ceo_nm, corp_cls, jurir_no,
        bizr_no, adres, hm_url, ir_url, phn_no, fax_no,
        induty_code, induty_name, est_dt, acc_mt
    ) VALUES (
        :corp_code, :corp_name, :stock_code, :ceo_nm, :corp_cls, :jurir_no,
        :bizr_no, :adres, :hm_url, :ir_url, :phn_no, :fax_no,
        :induty_code, :induty_name, :est_dt, :acc_mt
    )
    ON DUPLICATE KEY UPDATE
        corp_name = VALUES(corp_name),
        stock_code = VALUES(stock_code),
        ceo_nm = VALUES(ceo_nm),
        corp_cls = VALUES(corp_cls),
        jurir_no = VALUES(jurir_no),
        bizr_no = VALUES(bizr_no),
        adres = VALUES(adres),
        hm_url = VALUES(hm_url),
        ir_url = VALUES(ir_url),
        phn_no = VALUES(phn_no),
        fax_no = VALUES(fax_no),
        induty_code = VALUES(induty_code),
        induty_name = VALUES(induty_name),
        est_dt = VALUES(est_dt),
        acc_mt = VALUES(acc_mt);
    """
    with engine.begin() as conn:
        conn.execute(text(insert_query), safe_data)

def run_bulk_fetch():
    corp_codes = fetch_corp_codes()
    print(f"{len(corp_codes)}개 기업 조회 시작")

    for i, corp_code in enumerate(corp_codes):
        data = fetch_overview(corp_code)
        if data:
            insert_or_update_overview(data)
            print(f"[{i+1}/{len(corp_codes)}] {data.get('corp_name')} 저장됨")
        else:
            print(f"[{i+1}/{len(corp_codes)}] {corp_code}: 정보 없음")

        time.sleep(0.6)  # 100건/분 제한 고려

run_bulk_fetch()
# Out:
# 3837개 기업 조회 시작
# [1/3837] 한빛네트 저장됨
# [2/3837] (주)엔플렉스 저장됨
# [3/3837] (주)동서정보기술 저장됨
# [4/3837] 주식회사 애드모바일 저장됨
# [5/3837] (주)리더컴 저장됨
# [6/3837] (주)허메스홀딩스 저장됨
# [7/3837] (주)유티엑스 저장됨
# [8/3837] (주)글로포스트 저장됨
# [9/3837] (주)쏠라엔텍 저장됨
# [10/3837] (주)보홍 저장됨
# [11/3837] 동북아1호선박투자회사 저장됨
# [12/3837] 에듀아크 저장됨
# [13/3837] (주)데코 저장됨
# [14/3837] (주)엘앤씨피 저장됨
# [15/3837] (주)희훈디앤지 저장됨
# [16/3837] (주)퓨쳐인포넷 저장됨
# [17/3837] (주)쓰리디넷 저장됨
# [18/3837] (주)제일저축은행 저장됨
# [19/3837] 제일창업투자(주) 저장됨
# [20/3837] (주)현대DSF 저장됨
# [21/3837] (주)네프로아이티 저장됨
# [22/3837] (주)자강 저장됨
# [23/3837] 케이엠에스(주) 저장됨
# [24/3837] (주)에버리소스 저장됨
# [25/3837] 제이에스(주) 저장됨
# [26/3837] 태창기업(주) 저장됨
# [27/3837] (주)에이치비이에너지 저장됨
# [28/3837] (주)코어비트 저장됨
# [29/3837] 동북아8호선박투자회사 저장됨
# [30/3837] 한국통신데이타(주) 저장됨
# [31/3837] (주)케너텍 저장됨
# [32/3837] (주)다휘 저장됨
# [33/3837] 코오롱아이넷(주) 저장됨
# [34/3837] 캠브리지코오롱(주) 저장됨
# [35/3837] 네오세미테크(주) 저장됨
# [36/3837] (주)디에이치패션 저장됨
# [37/3837] 케이엠에이치(주) 저장됨
# [38/3837] (주)씨엘엘씨디 저장됨
# [39/3837] (주)현대푸드시스템 저장됨
# [40/3837] 메리츠종합금융(주) 저장됨
# [41/3837] 제넥셀세인(주) 저장됨
# [42/3837] (주)쓰리디월드 저장됨
# [43/3837] (주)스톰이앤에프 저장됨
# [44/3837] (주)소예 저장됨
# [45/3837] (주)엠엔에프씨 저장됨
# [46/3837] 하이트맥주(주) 저장됨
# [47/3837] (주)보광티에스 저장됨
# [48/3837] (주)아인스엠앤엠 저장됨
# [49/3837] 씨엔씨엔터프라이즈(주) 저장됨
# [50/3837] (주)아이알디 저장됨
# [51/3837] (주)바이나믹 저장됨
# [52/3837] (주)코크렙제7호위탁관리부동산투자회사 저장됨
# [53/3837] 엔빅스(주) 저장됨
# [54/3837] (주)선팩테크 저장됨
# [55/3837] 마이크로닉스(주) 저장됨
# [56/3837] (주)블루스톤디앤아이 저장됨
# [57/3837] (주)신지소프트 저장됨
# [58/3837] (주)맥쿼리센트럴오피스기업구조조정부동산투자회사 저장됨
# [59/3837] 테스텍(주) 저장됨
# [60/3837] (주)중앙디자인 저장됨
# [61/3837] (주)에코페트로시스템 저장됨
# [62/3837] 한림창업투자(주) 저장됨
# [63/3837] (주)헤쎄나 저장됨
# [64/3837] 미래에셋굿라이프혼합형자녀를위한투자회사10-1 저장됨
# [65/3837] (주)일공공일안경콘택트 저장됨
# [66/3837] (주)지앤알 저장됨
# [67/3837] (주)셀런 저장됨
# [68/3837] 한국 베트남15-1유전 해외자원개발투자회사 저장됨
# [69/3837] (주)에이치원바이오 저장됨
# [70/3837] (주)씨앤중공업 저장됨
# [71/3837] FnC코오롱(주) 저장됨
# [72/3837] (주)제너비오믹스 저장됨
# [73/3837] (주)케드콤 저장됨
# [74/3837] (주)지엔텍홀딩스 저장됨
# [75/3837] 동부씨엔아이(주) 저장됨
# [76/3837] (주)아이피에스 저장됨
# [77/3837] (주)에스브이에이치 저장됨
# [78/3837] (주)제이콤 저장됨
# [79/3837] (주)옥션 저장됨
# [80/3837] (주)네이쳐글로벌 저장됨
# [81/3837] GB 블루오션베트남주식혼합형 투자회사 1호 저장됨
# [82/3837] 엠씨티티코어(주) 저장됨
# [83/3837] (주)에이스 앤 파트너스 저장됨
# [84/3837] (주)지앤디윈텍 저장됨
# [85/3837] 인터피온반도체 저장됨
# [86/3837] (주)솔로몬저축은행 저장됨
# [87/3837] (주)엠트론스토리지테크놀로지 저장됨
# [88/3837] (주)에스티앤아이 저장됨
# [89/3837] (주)유퍼트 저장됨
# [90/3837] (주)엑스로드 저장됨
# [91/3837] (주)선우중공업 저장됨
# [92/3837] (주)남양 저장됨
# [93/3837] (주)엘지데이콤 저장됨
# [94/3837] (주)LG파워콤 저장됨
# [95/3837] 동산진흥(주) 저장됨
# [96/3837] 티이씨(주) 저장됨
# [97/3837] 한국기술산업(주) 저장됨
# [98/3837] (주)스타맥스 저장됨
# [99/3837] (주)유성티에스아이 저장됨
# [100/3837] (주)네오리소스 저장됨
# [101/3837] (주)케이알 저장됨
# [102/3837] (주)씨앤상선 저장됨
# [103/3837] (주)투미비티 저장됨
# [104/3837] (주)코아정보시스템 저장됨
# [105/3837] (주)케이에스리소스 저장됨
# [106/3837] (주)세계투어 저장됨
# [107/3837] 동양밸류오션기업인수목적(주) 저장됨
# [108/3837] 케이이엔지(주) 저장됨
# [109/3837] (주)사이버패스 저장됨
# [110/3837] 산양전기(주) 저장됨
# [111/3837] (주)으뜸상호저축은행 저장됨
# [112/3837] (주)국제개발 저장됨
# [113/3837] 세신(주) 저장됨
# [114/3837] 골든브릿지더블유엠경매부동산일호투자회사 저장됨
# [115/3837] (주)엘앤피아너스 저장됨
# [116/3837] (주)에이스일렉트로닉스 저장됨
# [117/3837] (주)디앤샵 저장됨
# [118/3837] (주)더 체인지 저장됨
# [119/3837] (주)다산자기관리부동산투자회사 저장됨
# [120/3837] (주)써니트렌드 저장됨
# [121/3837] (주)뉴젠비아이티 저장됨
# [122/3837] (주)룩소네이트 저장됨
# [123/3837] (주)현대오토넷 저장됨
# [124/3837] LG마이크론(주) 저장됨
# [125/3837] (주)서광건설산업 저장됨
# [126/3837] (주)플러스프로핏 저장됨
# [127/3837] (주)한와이어리스 저장됨
# [128/3837] (주)포휴먼 저장됨
# [129/3837] (주)알이네트웍스 저장됨
# [130/3837] (주)케이알제2호개발전문위탁관리부동산투자회사 저장됨
# [131/3837] 미래에셋맵스 오퍼튜니티 베트남 주식혼합형 투자회사 1호 저장됨
# [132/3837] (주)씨티엘테크 저장됨
# [133/3837] 이디디컴퍼니(주) 저장됨
# [134/3837] (주)케이티프리텔 저장됨
# [135/3837] (주)메카포럼 저장됨
# [136/3837] (주)에스피코프 저장됨
# [137/3837] (주)이롬텍 저장됨
# [138/3837] (주)이앤텍 저장됨
# [139/3837] (주)맥스브로 저장됨
# [140/3837] 토자이홀딩스 주식회사 저장됨
# [141/3837] (주)우방 저장됨
# [142/3837] 동양매직(주) 저장됨
# [143/3837] 코웰이홀딩스유한공사 저장됨
# [144/3837] (주)아구스 저장됨
# [145/3837] (주)대한은박지 저장됨
# [146/3837] (주)인스프리트 저장됨
# [147/3837] (주)하이럭스 저장됨
# [148/3837] (주)트리니티 저장됨
# [149/3837] (주)카라반케이디이 저장됨
# [150/3837] (주)더존디지털웨어 저장됨
# [151/3837] (주)디보스 저장됨
# [152/3837] (주)포네이처 저장됨
# [153/3837] (주)테이크시스템즈 저장됨
# [154/3837] (주)폴켐 저장됨
# [155/3837] 유리이에스(주) 저장됨
# [156/3837] (주)에프아이투어 저장됨
# [157/3837] (주)모빌탑 저장됨
# [158/3837] (주)올리브나인 저장됨
# [159/3837] (주)디패션 저장됨
# [160/3837] (주)알덱스 저장됨
# [161/3837] (주)오라바이오틱스 저장됨
# [162/3837] (주)시노펙스그린테크 저장됨
# [163/3837] (주)야호커뮤니케이션 저장됨
# [164/3837] 브이케이(주) 저장됨
# [165/3837] (주)팬택앤큐리텔 저장됨
# [166/3837] (주)팬텀엔터테인먼트그룹 저장됨
# [167/3837] (주)삼성수산 저장됨
# [168/3837] 동북아15호선박투자회사 저장됨
# [169/3837] (주)쌈지 저장됨
# [170/3837] 브이오산업(주) 저장됨
# [171/3837] 코디콤(주) 저장됨
# [172/3837] (주)제네시스엔알디 저장됨
# [173/3837] 동북아6호선박투자회사 저장됨
# [174/3837] (주)인네트 저장됨
# [175/3837] 한국월드와이드아시아태평양특별자산1호투자회사 저장됨
# [176/3837] (주)헤파호프코리아 저장됨
# [177/3837] (주)휴리프 저장됨
# [178/3837] (주)하이스마텍 저장됨
# [179/3837] 삼성디지털이미징(주) 저장됨
# [180/3837] 씨제이인터넷(주) 저장됨
# [181/3837] 엠넷미디어(주) 저장됨
# [182/3837] (주)온미디어 저장됨
# [183/3837] (주)유니텍전자 저장됨
# [184/3837] 위더스기술금융(주) 저장됨
# [185/3837] (주)클라스타 저장됨
# [186/3837] (주)아시아미디어홀딩스 저장됨
# [187/3837] 아이스테이션(주) 저장됨
# [188/3837] 동북아21호 선박투자회사 저장됨
# [189/3837] (주)에이스디지텍 저장됨
# [190/3837] (주)부산저축은행 저장됨
# [191/3837] (주)에피밸리 저장됨
# [192/3837] 오페스(주) 저장됨
# [193/3837] (주)액티투오 저장됨
# [194/3837] (주)에이치에스씨홀딩스 저장됨
# [195/3837] 한국고덴시(주) 저장됨
# [196/3837] (주)나리지*온 저장됨
# [197/3837] (주)프로비타 저장됨
# [198/3837] (주)제로원인터랙티브 저장됨
# [199/3837] 제일화재해상보험(주) 저장됨
# [200/3837] 동북아9호선박투자회사 저장됨
# [201/3837] (주)굿이엠지 저장됨
# [202/3837] (주)아이드림 저장됨
# [203/3837] (주)조인에너지 저장됨
# [204/3837] (주)태광이엔시 저장됨
# [205/3837] (주)렉스엘이앤지 저장됨
# [206/3837] 코리아퍼시픽05호 선박투자회사 저장됨
# [207/3837] (주)엑큐리스 저장됨
# [208/3837] 우경(주) 저장됨
# [209/3837] 세미텍(주) 저장됨
# [210/3837] 그린손해보험(주) 저장됨
# [211/3837] (주)대양글로벌 저장됨
# [212/3837] 엔하이테크(주) 저장됨
# [213/3837] (주)제너시스템즈 저장됨
# [214/3837] (주)엘트온 저장됨
# [215/3837] 태산엘시디(주) 저장됨
# [216/3837] 성원건설(주) 저장됨
# [217/3837] 대우송도개발(주) 저장됨
# [218/3837] (주)현대금속 저장됨
# [219/3837] (주)트라이써클 저장됨
# [220/3837] 아이비케이에스스마트에스엠이기업인수목적1호(주) 저장됨
# [221/3837] 네스테크(주) 저장됨
# [222/3837] 동북아5호선박투자회사 저장됨
# [223/3837] (주)파브코 저장됨
# [224/3837] 우리기업인수목적1호(주) 저장됨
# [225/3837] (주)뉴젠아이씨티 저장됨
# [226/3837] (주)인젠 저장됨
# [227/3837] (주)지앤에스티 저장됨
# [228/3837] (주)코크렙제8호위탁관리부동산투자회사 저장됨
# [229/3837] 유니온스틸(주) 저장됨
# [230/3837] 경남모직(주) 저장됨
# [231/3837] (주)대우증권그린코리아기업인수목적회사 저장됨
# [232/3837] (주)지노시스템 저장됨
# [233/3837] (주)한국투자신성장1호기업인수목적회사 저장됨
# [234/3837] (주)휴먼텍코리아 저장됨
# [235/3837] 에스에스씨피(주) 저장됨
# [236/3837] (주)평산 저장됨
# [237/3837] (주)지디코프 저장됨
# [238/3837] 아시아퍼시픽2호선박투자회사 저장됨
# [239/3837] 무한투자(주) 저장됨
# [240/3837] 동부티에스블랙펄기업인수목적(주) 저장됨
# [241/3837] (주)블루젬디앤씨 저장됨
# [242/3837] 부국퓨쳐스타즈기업인수목적주식회사 저장됨
# [243/3837] (주)예당컴퍼니 저장됨
# [244/3837] (주)터보테크 저장됨
# [245/3837] 케이비물산(주) 저장됨
# [246/3837] 연합과기공고유한공사 저장됨
# [247/3837] 글로스텍(주) 저장됨
# [248/3837] 중국고섬공고유한공사 저장됨
# [249/3837] 코리아퍼시픽06호 선박투자회사 저장됨
# [250/3837] (주)나노트로닉스 저장됨
# [251/3837] 미래에셋제1호기업인수목적(주) 저장됨
# [252/3837] (주)에이원마이크로 저장됨
# [253/3837] (주)에이프로테크놀로지 저장됨
# [254/3837] (주)모린스 저장됨
# [255/3837] (주)디지텍시스템스 저장됨
# [256/3837] (주)배명금속 저장됨
# [257/3837] 동북아4호선박투자회사 저장됨
# [258/3837] (주)사라콤 저장됨
# [259/3837] (주)폴리플러스 저장됨
# [260/3837] (주)영찬테크 저장됨
# [261/3837] (주)케이비부국제1호개발전문위탁관리부동산투자회사 저장됨
# [262/3837] 아시아퍼시픽8호선박투자회사 저장됨
# [263/3837] 진흥저축은행(주) 저장됨
# [264/3837] (주)에듀언스 저장됨
# [265/3837] 성융광전투자유한공사 저장됨
# [266/3837] (주)샤인시스템 저장됨
# [267/3837] (주)씨모텍 저장됨
# [268/3837] (주)에스컴 저장됨
# [269/3837] 아시아퍼시픽1호선박투자회사 저장됨
# [270/3837] 아시아퍼시픽3호선박투자회사 저장됨
# [271/3837] 한국저축은행(주) 저장됨
# [272/3837] 미리넷(주) 저장됨
# [273/3837] 3노드디지탈그룹유한공사 저장됨
# [274/3837] (주)유일엔시스 저장됨
# [275/3837] (주)케이피케미칼 저장됨
# [276/3837] (주)이루넷 저장됨
# [277/3837] 대신증권그로쓰알파기업인수목적(주) 저장됨
# [278/3837] (주)유에이블 저장됨
# [279/3837] (주)경윤하이드로에너지 저장됨
# [280/3837] (주)롯데미도파 저장됨
# [281/3837] 한화에스브이명장제1호기업인수목적(주) 저장됨
# [282/3837] (주)셀텍 저장됨
# [283/3837] 에스비아이앤솔로몬드림기업인수목적(주) 저장됨
# [284/3837] (주)위다스 저장됨
# [285/3837] (주)에스와이코퍼레이션 저장됨
# [286/3837] 어울림 네트웍스(주) 저장됨
# [287/3837] (주)에이디모터스 저장됨
# [288/3837] 평안물산(주) 저장됨
# [289/3837] (주)아큐텍 저장됨
# [290/3837] 히든챔피언제1호기업인수목적(주) 저장됨
# [291/3837] 동북아2호선박투자회사 저장됨
# [292/3837] 금강제강(주) 저장됨
# [293/3837] (주)아라온테크 저장됨
# [294/3837] (주)대국 저장됨
# [295/3837] 글로웍스(주) 저장됨
# [296/3837] 중국식품포장유한공사 저장됨
# [297/3837] 동북아3호선박투자회사 저장됨
# [298/3837] (주)지아이바이오 저장됨
# [299/3837] 주식회사 알에스넷 저장됨
# [300/3837] 나이스메탈(주) 저장됨
# [301/3837] 하나IB증권 주식회사 저장됨
# [302/3837] 퓨쳐비젼(주) 저장됨
# [303/3837] 이레전자산업(주) 저장됨
# [304/3837] (주)레이더스컴퍼니 저장됨
# [305/3837] (주)포이보스 저장됨
# [306/3837] (주)미디어코프 저장됨
# [307/3837] (주)케이디세코 저장됨
# [308/3837] (주)이노블루 저장됨
# [309/3837] (주)도움 저장됨
# [310/3837] (주)엑스씨이 저장됨
# [311/3837] 코오롱유화(주) 저장됨
# [312/3837] (주)세라온홀딩스 저장됨
# [313/3837] 현대경매부동산일호투자회사 저장됨
# [314/3837] 우수씨엔에스(주) 저장됨
# [315/3837] 동북아31호선박투자회사 저장됨
# [316/3837] 후야인포넷(주) 저장됨
# [317/3837] (주)이레아이엔씨 저장됨
# [318/3837] (주)카스코 저장됨
# [319/3837] (주)모델라인 저장됨
# [320/3837] (주)청람디지탈 저장됨
# [321/3837] (주)한텔 저장됨
# [322/3837] (주)코스모스피엘씨 저장됨
# [323/3837] (주)나노하이텍 저장됨
# [324/3837] (주)쓰리소프트 저장됨
# [325/3837] (주)트라이콤 저장됨
# [326/3837] 케이엔에스홀딩스(주) 저장됨
# [327/3837] (주)지비에스 저장됨
# [328/3837] (주)피더블유제네틱스 저장됨
# [329/3837] 엠텍반도체(주) 저장됨
# [330/3837] (주)세니콘 저장됨
# [331/3837] 유씨아이콜스(주) 저장됨
# [332/3837] 코크렙제3호CR리츠 저장됨
# [333/3837] (주)아이티센네트웍스 저장됨
# [334/3837] 리얼티코리아제1호기업구조조정부동산투자(주) 저장됨
# [335/3837] (주)BHK 저장됨
# [336/3837] (주)포넷 저장됨
# [337/3837] 맥슨텔레콤(주) 저장됨
# [338/3837] 엔토리노(주) 저장됨
# [339/3837] (주)두림티앤씨 저장됨
# [340/3837] 동북아27호선박투자회사 저장됨
# [341/3837] 동북아28호선박투자회사 저장됨
# [342/3837] 동북아30호선박투자회사 저장됨
# [343/3837] 동북아29호선박투자회사 저장됨
# [344/3837] 현주컴퓨터(주) 저장됨
# [345/3837] LG석유화학(주) 저장됨
# [346/3837] (주)오브제 저장됨
# [347/3837] (주)휴닉스 저장됨
# [348/3837] 세이프아시아(주) 저장됨
# [349/3837] (주)코크렙제1호기업구조조정부동산투자회사 저장됨
# [350/3837] (주)위너스인프라인 저장됨
# [351/3837] AP우주통신(주) 저장됨
# [352/3837] (주)조이토토 저장됨
# [353/3837] (주)한도하이테크 저장됨
# [354/3837] (주)에너윈 저장됨
# [355/3837] 유레스메리츠제1호 저장됨
# [356/3837] 교보메리츠퍼스트기업구조조정부동산투자회사 저장됨
# [357/3837] 굿앤리치부동산공경매투자회사1호 저장됨
# [358/3837] 한국합섬(주) 저장됨
# [359/3837] 굿앤리치부동산공경매투자회사2호 저장됨
# [360/3837] (주)디에스피이엔티 저장됨
# [361/3837] (주)시큐어소프트 저장됨
# [362/3837] 동부일렉트로닉스(주) 저장됨
# [363/3837] 고려시멘트(주) 저장됨
# [364/3837] (주)베스트플로우 저장됨
# [365/3837] (주)쿨투 저장됨
# [366/3837] (주)우영 저장됨
# [367/3837] 모빌링크텔레콤(주) 저장됨
# [368/3837] 극동제혁(주) 저장됨
# [369/3837] (주)한마음상호저축은행 저장됨
# [370/3837] 그로웰전자(주) 저장됨
# [371/3837] (주)부흥 저장됨
# [372/3837] (주)퍼시픽글라스 저장됨
# [373/3837] (주)아이인프라 저장됨
# [374/3837] (주)씨크롭 저장됨
# [375/3837] 외환신용카드주식회사 저장됨
# [376/3837] 삼화기연(주) 저장됨
# [377/3837] 대흥멀티미디어통신(주) 저장됨
# [378/3837] 텔슨정보통신(주) 저장됨
# [379/3837] (주)비이티 저장됨
# [380/3837] 코오롱인터내셔널(주) 저장됨
# [381/3837] 엔써커뮤니티 주식회사 저장됨
# [382/3837] 써미트테크놀로지 저장됨
# [383/3837] 코리아이앤디(주) 저장됨
# [384/3837] (주)트래픽아이티에스 저장됨
# [385/3837] 주식회사 호성 저장됨
# [386/3837] (주)넥스텔 저장됨
# [387/3837] 쓰리알(주) 저장됨
# [388/3837] (주)그로웰텔레콤 저장됨
# [389/3837] (주)서통 저장됨
# [390/3837] (주)테크메이트 저장됨
# [391/3837] (주)한아시스템 저장됨
# [392/3837] (주)엔에스아이 저장됨
# [393/3837] (주)케이티씨텔레콤 저장됨
# [394/3837] 주식회사 신한SIT 저장됨
# [395/3837] (주)스마텔 저장됨
# [396/3837] (주)동방라이텍 저장됨
# [397/3837] (주)아이텍스필 저장됨
# [398/3837] 이수세라믹(주) 저장됨
# [399/3837] (주)코크렙제2호기업구조조정부동산투자회사 저장됨
# [400/3837] 영풍산업주식회사 저장됨
# [401/3837] 주식회사 모닷텔 저장됨
# [402/3837] 광덕물산(주) 저장됨
# [403/3837] 동원증권(주) 저장됨
# [404/3837] (주)우주통신 저장됨
# [405/3837] 기라정보통신(주) 저장됨
# [406/3837] 텔슨전자(주) 저장됨
# [407/3837] (주)하이콤정보통신 저장됨
# [408/3837] 미래에셋굿라이프혼합형자녀를위한펀드5-1 저장됨
# [409/3837] (주)한메엔에스 저장됨
# [410/3837] (주)이지클럽 저장됨
# [411/3837] 넷컴스토리지 저장됨
# [412/3837] (주)모디아 저장됨
# [413/3837] (주)성진산업 저장됨
# [414/3837] (주)아이엠아이티 저장됨
# [415/3837] (주)맥시스템 저장됨
# [416/3837] (주)슈마일렉트론 저장됨
# [417/3837] (주)센추리 저장됨
# [418/3837] (주)베네데스하이텍 저장됨
# [419/3837] (주)에스오케이 저장됨
# [420/3837] 세원텔레콤(주) 저장됨
# [421/3837] 한강구조조정기금 저장됨
# [422/3837] (주)케이엔티 저장됨
# [423/3837] 대아리드선(주) 저장됨
# [424/3837] (주)월드텔레콤 저장됨
# [425/3837] (주)업필 저장됨
# [426/3837] (주)화림모드 저장됨
# [427/3837] 대아건설(주) 저장됨
# [428/3837] (주)창민테크 저장됨
# [429/3837] 씨제이엔터테인먼트(주) 저장됨
# [430/3837] (주)대백쇼핑 저장됨
# [431/3837] (주)지니웍스 저장됨
# [432/3837] 신광기업(주) 저장됨
# [433/3837] 유진종합개발(주) 저장됨
# [434/3837] (주)휘튼 저장됨
# [435/3837] 엠바이엔(주) 저장됨
# [436/3837] (주)대호 저장됨
# [437/3837] (주)한신코퍼레이션 저장됨
# [438/3837] 금강화섬(주) 저장됨
# [439/3837] 우리증권(주) 저장됨
# [440/3837] 주식회사 피코소프트 저장됨
# [441/3837] 바이오시스 저장됨
# [442/3837] (주)윌텍정보통신 저장됨
# [443/3837] 삼도물산(주) 저장됨
# [444/3837] (주)현대멀티캡 저장됨
# [445/3837] 코리아퍼시픽01호선박투자회사 저장됨
# [446/3837] 코리아퍼시픽02호선박투자회사 저장됨
# [447/3837] (주)신양오라컴디스플레이 저장됨
# [448/3837] (주)이룸지엔지 저장됨
# [449/3837] (주)에스와이이노베이션 저장됨
# [450/3837] 코리아퍼시픽03호선박투자회사 저장됨
# [451/3837] 코리아퍼시픽04호선박투자회사 저장됨
# [452/3837] (주)유아이에너지 저장됨
# [453/3837] 아시아퍼시픽14호선박투자회사 저장됨
# [454/3837] 아시아퍼시픽13호선박투자회사 저장됨
# [455/3837] 아시아퍼시픽10호선박투자회사 저장됨
# [456/3837] 현대에이블기업인수목적1호(주) 저장됨
# [457/3837] 아시아퍼시픽11호선박투자회사 저장됨
# [458/3837] 아시아퍼시픽12호선박투자회사 저장됨
# [459/3837] 주식회사 호반산업 저장됨
# [460/3837] (주)실리콘화일 저장됨
# [461/3837] (주)비엔씨컴퍼니 저장됨
# [462/3837] 동북아11호선박투자회사 저장됨
# [463/3837] 동북아14호선박투자회사 저장됨
# [464/3837] (주)디아이디 저장됨
# [465/3837] 부산방직공업(주) 저장됨
# [466/3837] (주)현대에이치씨엔동작방송 저장됨
# [467/3837] (주)플렉스컴 저장됨
# [468/3837] (주)웹솔루스 저장됨
# [469/3837] (주)마이스코 저장됨
# [470/3837] (주)솔트웍스 저장됨
# [471/3837] 현대페인트(주) 저장됨
# [472/3837] (주)한진해운 저장됨
# [473/3837] (주)글라소울 저장됨
# [474/3837] 주식회사 팬택자산관리 저장됨
# [475/3837] (주)케이엔씨글로벌 저장됨
# [476/3837] (주)아이디에스 저장됨
# [477/3837] (주)훈영 저장됨
# [478/3837] 한솔아트원제지㈜ 저장됨
# [479/3837] (주)엠제이비 저장됨
# [480/3837] 바다로3호선박투자회사 저장됨
# [481/3837] (주)아이팩토리 저장됨
# [482/3837] 거북선5호선박투자회사 저장됨
# [483/3837] 거북선6호선박투자회사 저장됨
# [484/3837] (주)피엘에이 저장됨
# [485/3837] 닉스테크(주) 저장됨
# [486/3837] 아시아퍼시픽9호선박투자회사 저장됨
# [487/3837] 거북선4호선박투자회사 저장됨
# [488/3837] (주)중앙건설 저장됨
# [489/3837] 미래에셋새천년코리아벤처펀드일호 저장됨
# [490/3837] 에이스하이텍(주) 저장됨
# [491/3837] (주)태창파로스 저장됨
# [492/3837] 평산차업집단유한공사 저장됨
# [493/3837] 스탠다드펌(주) 저장됨
# [494/3837] 벽산건설(주) 저장됨
# [495/3837] NH농협증권(주) 저장됨
# [496/3837] 아시아퍼시픽4호선박투자회사 저장됨
# [497/3837] 한화화인케미칼(주) 저장됨
# [498/3837] (주)지오엠씨 저장됨
# [499/3837] (주)에듀패스 저장됨
# [500/3837] (주)아이디에이치 저장됨
# [501/3837] 거북선7호선박투자회사 저장됨
# [502/3837] (주)서울상호저축은행 저장됨
# [503/3837] (주)와이즈파워 저장됨
# [504/3837] (주)코크렙제15호기업구조조정부동산투자회사 저장됨
# [505/3837] (주)티브로드 한빛방송 저장됨
# [506/3837] 거북선3호 선박투자회사 저장됨
# [507/3837] (주)동성하이켐 저장됨
# [508/3837] (주)클루넷 저장됨
# [509/3837] 코리아퍼시픽07호 선박투자회사 저장됨
# [510/3837] (주)씨유전자 저장됨
# [511/3837] 삼목강업(주) 저장됨
# [512/3837] (주)에스비엠 저장됨
# [513/3837] (주)솔빛미디어 저장됨
# [514/3837] (주)에프지엔개발전문자기관리부동산투자회사 저장됨
# [515/3837] 현대하이스코(주) 저장됨
# [516/3837] 거북선1호선박투자회사 저장됨
# [517/3837] (주)코아에스앤아이 저장됨
# [518/3837] 주식회사 자원메디칼 저장됨
# [519/3837] (주)삼우이엠씨 저장됨
# [520/3837] 어울림정보기술(주) 저장됨
# [521/3837] (주)티브로드도봉강북방송 저장됨
# [522/3837] (주)티이씨앤코 저장됨
# [523/3837] (주)화인자산관리 저장됨
# [524/3837] (주)로케트전기 저장됨
# [525/3837] (주)신일건업 저장됨
# [526/3837] 제일모직(주) 저장됨
# [527/3837] (주)퓨얼셀파워 저장됨
# [528/3837] 아루히 주식회사 저장됨
# [529/3837] (주)지티앤티 저장됨
# [530/3837] (주)모아에스앤에스 저장됨
# [531/3837] 어울림엘시스(주) 저장됨
# [532/3837] (주)이코리아자기관리부동산투자회사 저장됨
# [533/3837] (주)에이치앤아이 저장됨
# [534/3837] (주)디에스 저장됨
# [535/3837] (주)유니드코리아 저장됨
# [536/3837] (주)아이레보 저장됨
# [537/3837] (주)포스코티엠씨 저장됨
# [538/3837] 거북선2호 선박투자회사 저장됨
# [539/3837] 아시아퍼시픽5호선박투자회사 저장됨
# [540/3837] 아시아퍼시픽7호선박투자회사 저장됨
# [541/3837] 아시아퍼시픽6호선박투자회사 저장됨
# [542/3837] 에스케이제1호기업인수목적(주) 저장됨
# [543/3837] 대우기업인수목적3호(주) 저장됨
# [544/3837] 엔에이치에스엘기업인수목적(주) 저장됨
# [545/3837] 케이티비기업인수목적1호(주) 저장됨
# [546/3837] 미래에셋제3호기업인수목적(주) 저장됨
# [547/3837] (주)넥솔론 저장됨
# [548/3837] (주)디피앤케이 저장됨
# [549/3837] (주)비앤에스미디어 저장됨
# [550/3837] 에스지에이시스템즈(주) 저장됨
# [551/3837] 웨이포트유한공사 저장됨
# [552/3837] 아스팩오일(주) 저장됨
# [553/3837] 하이골드오션2호 선박투자회사 저장됨
# [554/3837] 골든브릿지제2호기업인수목적(주) 저장됨
# [555/3837] (주)대성합동지주 저장됨
# [556/3837] 중국원양자원유한공사 저장됨
# [557/3837] 아시아퍼시픽15호선박투자회사 저장됨
# [558/3837] 하나머스트3호기업인수목적(주) 저장됨
# [559/3837] (주)신성에프에이 저장됨
# [560/3837] (주)한진피앤씨 저장됨
# [561/3837] (주)나이코 저장됨
# [562/3837] 대우기업인수목적2호(주) 저장됨
# [563/3837] (주)에스에스컴텍 저장됨
# [564/3837] 동북아10호선박투자회사 저장됨
# [565/3837] 골든브릿지제3호기업인수목적(주) 저장됨
# [566/3837] (주)제이앤유글로벌 저장됨
# [567/3837] 케이비제8호기업인수목적 주식회사 저장됨
# [568/3837] 키움제3호기업인수목적주식회사 저장됨
# [569/3837] 유진기업인수목적3호(주) 저장됨
# [570/3837] 한화에이스기업인수목적2호(주) 저장됨
# [571/3837] 엔에이치기업인수목적7호 주식회사 저장됨
# [572/3837] 교보5호기업인수목적(주) 저장됨
# [573/3837] 케이비드림투게더제3호기업인수목적 주식회사 저장됨
# [574/3837] 유안타제2호기업인수목적(주) 저장됨
# [575/3837] 에스엠로보틱스(주) 저장됨
# [576/3837] (주)시냅스엠 저장됨
# [577/3837] 동부제4호기업인수목적주식회사 저장됨
# [578/3837] (주)태경피엔에스 저장됨
# [579/3837] (주)카카오엠 저장됨
# [580/3837] (주)썬코어 저장됨
# [581/3837] 키움 제4호 기업인수목적 주식회사 저장됨
# [582/3837] 도레이케미칼(주) 저장됨
# [583/3837] 디와이엘엔제이(주) 저장됨
# [584/3837] (주)엔에스브이 저장됨
# [585/3837] (주)심팩메탈 저장됨
# [586/3837] 씨제이이앤엠(주) 저장됨
# [587/3837] 이베스트기업인수목적3호(주) 저장됨
# [588/3837] 완리인터내셔널홀딩스 저장됨
# [589/3837] 하림홀딩스 저장됨
# [590/3837] 대덕GDS(주) 저장됨
# [591/3837] (주)위너지스 저장됨
# [592/3837] (주)스틸플라워 저장됨
# [593/3837] 그레이트리치과기유한공사 저장됨
# [594/3837] (주)트레이스 저장됨
# [595/3837] 케이비제9호기업인수목적(주) 저장됨
# [596/3837] 하이에이아이1호기업인수목적(주) 저장됨
# [597/3837] 넥스콘테크놀러지(주) 저장됨
# [598/3837] 덴소코리아주식회사 저장됨
# [599/3837] (주)프렉코 저장됨
# [600/3837] 차이나하오란리사이클링유한공사 저장됨
# [601/3837] (주)원익테라세미콘 저장됨
# [602/3837] 한국제4호기업인수목적(주) 저장됨
# [603/3837] (주)씨그널엔터테인먼트그룹 저장됨
# [604/3837] (주)극동자동화 저장됨
# [605/3837] 세원화성(주) 저장됨
# [606/3837] 미래에셋맵스 아시아퍼시픽 부동산공모 1호 투자회사 저장됨
# [607/3837] (주)세왕 저장됨
# [608/3837] (주)에스와이제이 저장됨
# [609/3837] (주)피엠디아카데미 저장됨
# [610/3837] 트러스와이제7호위탁관리부동산투자회사 저장됨
# [611/3837] (주)중앙바이오텍 저장됨
# [612/3837] (주)보진재 저장됨
# [613/3837] 로스웰인터내셔널유한회사 저장됨
# [614/3837] (주)제이에스피브이 저장됨
# [615/3837] 미래에셋대우기업인수목적1호(주) 저장됨
# [616/3837] 세종머티리얼즈(주) 저장됨
# [617/3837] 신한제3호기업인수목적 주식회사 저장됨
# [618/3837] 줌인터넷(주) 저장됨
# [619/3837] (주)인프라웨어테크놀러지 저장됨
# [620/3837] 한화에이스기업인수목적3호(주) 저장됨
# [621/3837] (주)씨앤케이인터내셔널 저장됨
# [622/3837] 주식회사 아이엘사이언스 저장됨
# [623/3837] (주)한컴지엠디 저장됨
# [624/3837] 아이이(주) 저장됨
# [625/3837] (주)에스티씨 라이프 저장됨
# [626/3837] 한화수성기업인수목적(주) 저장됨
# [627/3837] 현대정보기술(주) 저장됨
# [628/3837] 에스케이제3호기업인수목적(주) 저장됨
# [629/3837] (주)영현무역 저장됨
# [630/3837] 대신밸런스제4호기업인수목적(주) 저장됨
# [631/3837] (주)썬테크놀로지스 저장됨
# [632/3837] 동양텔레콤(주) 저장됨
# [633/3837] (주)유쎌 저장됨
# [634/3837] (주)에임하이글로벌 저장됨
# [635/3837] 한국제5호기업인수목적(주) 저장됨
# [636/3837] (주)해피드림 저장됨
# [637/3837] 동북아13호선박투자회사 저장됨
# [638/3837] 디케이씨(주) 저장됨
# [639/3837] (주)다린 저장됨
# [640/3837] 하이골드오션8호국제선박투자회사 저장됨
# [641/3837] (주)더스텔라 저장됨
# [642/3837] 차이나그레이트스타인터내셔널리미티드 저장됨
# [643/3837] (주)보루네오가구 저장됨
# [644/3837] (주)케미메디 저장됨
# [645/3837] (주)씨티네트웍스 저장됨
# [646/3837] (주)이푸른 저장됨
# [647/3837] SBI핀테크솔루션즈(주) 저장됨
# [648/3837] (주)미성포리테크 저장됨
# [649/3837] (주)파인넥스 저장됨
# [650/3837] 고려개발(주) 저장됨
# [651/3837] 아이비케이에스제7호기업인수목적주식회사 저장됨
# [652/3837] (주)티에스트릴리온 저장됨
# [653/3837] (주)드림티엔터테인먼트 저장됨
# [654/3837] 동북아12호선박투자회사 저장됨
# [655/3837] 맥쿼리한국인프라투융자회사 저장됨
# [656/3837] (주)인터파크 저장됨
# [657/3837] 신한제4호기업인수목적(주) 저장됨
# [658/3837] 차이나크리스탈신소재홀딩스 저장됨
# [659/3837] 코리아오토글라스(주) 저장됨
# [660/3837] 하나유비에스암바토비니켈해외자원개발2호 저장됨
# [661/3837] 하나유비에스암바토비니켈해외자원개발1호 저장됨
# [662/3837] 한국제7호기업인수목적 주식회사 저장됨
# [663/3837] (주)에스마크 저장됨
# [664/3837] (주)글로앤웰 저장됨
# [665/3837] 한화에이스기업인수목적4호(주) 저장됨
# [666/3837] 한국제6호기업인수목적 주식회사 저장됨
# [667/3837] (주)신텍 저장됨
# [668/3837] (주)리드 저장됨
# [669/3837] (주)위노바 저장됨
# [670/3837] (주)이매진아시아 저장됨
# [671/3837] 주식회사 한국아트라스비엑스 저장됨
# [672/3837] (주)동성화학 저장됨
# [673/3837] 주식회사 구스앤홈 저장됨
# [674/3837] 엔에이치기업인수목적13호 주식회사 저장됨
# [675/3837] 웅진에너지(주) 저장됨
# [676/3837] (주)홈센타홀딩스 저장됨
# [677/3837] (주)우진 저장됨
# [678/3837] 에스앤씨엔진그룹리미티드 저장됨
# [679/3837] 인화정공(주) 저장됨
# [680/3837] 대원산업(주) 저장됨
# [681/3837] (주)대동 저장됨
# [682/3837] 일화모직공업(주) 저장됨
# [683/3837] 키움제5호기업인수목적 주식회사 저장됨
# [684/3837] 삼화콘덴서공업(주) 저장됨
# [685/3837] (주)유니온 저장됨
# [686/3837] (주)우진플라임 저장됨
# [687/3837] (주)라임 저장됨
# [688/3837] (주)케이엔엔 저장됨
# [689/3837] 삼보판지(주) 저장됨
# [690/3837] (주)대성파인텍 저장됨
# [691/3837] 하이골드오션12호국제선박투자회사 저장됨
# [692/3837] (주)서연이화 저장됨
# [693/3837] (주)금빛 저장됨
# [694/3837] 대한방직(주) 저장됨
# [695/3837] (주)갤럭시아 에스엠 저장됨
# [696/3837] 대선조선(주) 저장됨
# [697/3837] (주)러셀 저장됨
# [698/3837] (주)유디피 저장됨
# [699/3837] 케이비제17호기업인수목적 주식회사 저장됨
# [700/3837] 하나머스트제6호기업인수목적(주) 저장됨
# [701/3837] 컬러레이홀딩스 저장됨
# [702/3837] 다이노나(주) 저장됨
# [703/3837] (주)미래테크놀로지 저장됨
# [704/3837] SBS미디어홀딩스(주) 저장됨
# [705/3837] (주)특수건설 저장됨
# [706/3837] 오가닉티코스메틱스홀딩스컴퍼니리미티드 저장됨
# [707/3837] (주)유수홀딩스 저장됨
# [708/3837] (주)코너스톤네트웍스 저장됨
# [709/3837] (주)지에스홈쇼핑 저장됨
# [710/3837] (주)세동 저장됨
# [711/3837] 에스지에이클라우드서비스 주식회사 저장됨
# [712/3837] (주)성광벤드 저장됨
# [713/3837] 이스트아시아홀딩스인베스트먼트리미티드 저장됨
# [714/3837] 유안타제4호기업인수목적 주식회사 저장됨
# [715/3837] 한화에스비아이기업인수목적 주식회사 저장됨
# [716/3837] 대원전선(주) 저장됨
# [717/3837] 이엘케이(주) 저장됨
# [718/3837] (주)다원시스 저장됨
# [719/3837] 케이비제18호기업인수목적 주식회사 저장됨
# [720/3837] 태림포장(주) 저장됨
# [721/3837] 지니언스(주) 저장됨
# [722/3837] 보성파워텍(주) 저장됨
# [723/3837] 이베스트이안기업인수목적1호 주식회사 저장됨
# [724/3837] 극동유화(주) 저장됨
# [725/3837] (주)루트락 저장됨
# [726/3837] 그린기술투자(주) 저장됨
# [727/3837] 에스케이에이씨피씨제4호기업인수목적(주) 저장됨
# [728/3837] 오렌지라이프생명보험(주) 저장됨
# [729/3837] (주)에스제이케이 저장됨
# [730/3837] (주)세코닉스 저장됨
# [731/3837] (주)티로보틱스 저장됨
# [732/3837] 주식회사 넥스피안 저장됨
# [733/3837] (주)보광산업 저장됨
# [734/3837] (주)엘피케이로보틱스 저장됨
# [735/3837] 일진홀딩스(주) 저장됨
# [736/3837] (주)하나기술 저장됨
# [737/3837] 제일파마홀딩스(주) 저장됨
# [738/3837] (주)플래티어 저장됨
# [739/3837] 조광피혁(주) 저장됨
# [740/3837] (주)디알젬 저장됨
# [741/3837] 팅크웨어(주) 저장됨
# [742/3837] (주)레이크머티리얼즈 저장됨
# [743/3837] (주)인텔리안테크놀로지스 저장됨
# [744/3837] (주)라파스 저장됨
# [745/3837] 아이디피(주) 저장됨
# [746/3837] 주식회사 삼영에스앤씨 저장됨
# [747/3837] (주)에스피컴텍 저장됨
# [748/3837] (주)진매트릭스 저장됨
# [749/3837] (주)씨앤에스자산관리 저장됨
# [750/3837] (주)엠로 저장됨
# [751/3837] (주)액트로 저장됨
# [752/3837] (주)테스 저장됨
# [753/3837] (주)힘스 저장됨
# [754/3837] 잘만테크(주) 저장됨
# [755/3837] 모바일어플라이언스 주식회사 저장됨
# [756/3837] (주)미래컴퍼니 저장됨
# [757/3837] 오토앤(주) 저장됨
# [758/3837] 동일금속(주) 저장됨
# [759/3837] (주)아바코 저장됨
# [760/3837] (주)큐에스아이 저장됨
# [761/3837] 프리시젼바이오(주) 저장됨
# [762/3837] (주)영림원소프트랩 저장됨
# [763/3837] 주식회사 원준 저장됨
# [764/3837] (주)파크시스템스 저장됨
# [765/3837] 미원스페셜티케미칼(주) 저장됨
# [766/3837] (주)코스메카코리아 저장됨
# [767/3837] 럭스피아(주) 저장됨
# [768/3837] (주)아바텍 저장됨
# [769/3837] 위월드(주) 저장됨
# [770/3837] (주)유니크 저장됨
# [771/3837] 에이비온(주) 저장됨
# [772/3837] (주)오비고 저장됨
# [773/3837] (주)씨디네트웍스 저장됨
# [774/3837] 한일화학공업(주) 저장됨
# [775/3837] (주)디에스케이 저장됨
# [776/3837] (주)화승코퍼레이션 저장됨
# [777/3837] (주)금오하이텍 저장됨
# [778/3837] (주)동양건설산업 저장됨
# [779/3837] (주)피엔에스커튼월 저장됨
# [780/3837] (주)제노텍 저장됨
# [781/3837] (주)애드바이오텍 저장됨
# [782/3837] (주)제네시스디벨롭먼트홀딩스 저장됨
# [783/3837] 대주코레스(주) 저장됨
# [784/3837] (주)로보티즈 저장됨
# [785/3837] (주)범양사 저장됨
# [786/3837] (주)부산도시가스 저장됨
# [787/3837] (주)티피씨메카트로닉스 저장됨
# [788/3837] (주)우리기술 저장됨
# [789/3837] (주)뷰웍스 저장됨
# [790/3837] 주식회사 아이티아이즈 저장됨
# [791/3837] (주)원림 저장됨
# [792/3837] 주식회사 캐리소프트 저장됨
# [793/3837] 한일건설(주) 저장됨
# [794/3837] 케이디지엠텍(주) 저장됨
# [795/3837] 케이씨더블류 (주) 저장됨
# [796/3837] 주식회사 에스제이켐 저장됨
# [797/3837] 에이자기관리부동산투자회사(주) 저장됨
# [798/3837] (주)프로이천 저장됨
# [799/3837] 율촌화학(주) 저장됨
# [800/3837] (주)티에이치엔 저장됨
# [801/3837] 삼륭물산(주) 저장됨
# [802/3837] 한국철강(주) 저장됨
# [803/3837] 카페24(주) 저장됨
# [804/3837] 아이케이세미콘(주) 저장됨
# [805/3837] 코리아에셋투자증권(주) 저장됨
# [806/3837] (주)웰크론 저장됨
# [807/3837] (주)셀리드 저장됨
# [808/3837] (주)파마리서치바이오 저장됨
# [809/3837] 주식회사 알비더블유 저장됨
# [810/3837] 주식회사 무진메디 저장됨
# [811/3837] 주식회사 퀀타매트릭스 저장됨
# [812/3837] (주)엔지켐생명과학 저장됨
# [813/3837] 주식회사 이지스밸류플러스위탁관리부동산투자회사 저장됨
# [814/3837] 동원금속(주) 저장됨
# [815/3837] (주)아스플로 저장됨
# [816/3837] 쿠쿠홀딩스(주) 저장됨
# [817/3837] 국제엘렉트릭코리아(주) 저장됨
# [818/3837] (주)엔스퍼트 저장됨
# [819/3837] 성지건설(주) 저장됨
# [820/3837] 풍원정밀(주) 저장됨
# [821/3837] (주)안트로젠 저장됨
# [822/3837] (주)씨엠에스에듀 저장됨
# [823/3837] (주)한국전자홀딩스 저장됨
# [824/3837] 하나금융14호기업인수목적 주식회사 저장됨
# [825/3837] 에스케이제5호기업인수목적 주식회사 저장됨
# [826/3837] 에스케이제6호기업인수목적 주식회사 저장됨
# [827/3837] (주)마이크로디지탈 저장됨
# [828/3837] 효성오앤비(주) 저장됨
# [829/3837] 전진바이오팜(주) 저장됨
# [830/3837] (주)제이엠멀티 저장됨
# [831/3837] (주)금비 저장됨
# [832/3837] (주)셰프라인 저장됨
# [833/3837] 상상인이안제2호기업인수목적 주식회사 저장됨
# [834/3837] SNT에너지(주) 저장됨
# [835/3837] (주)인터엠 저장됨
# [836/3837] 넥슨지티(주) 저장됨
# [837/3837] 자안바이오 주식회사 저장됨
# [838/3837] (주)나인테크 저장됨
# [839/3837] 주식회사 에스앤케이 저장됨
# [840/3837] 이삭엔지니어링(주) 저장됨
# [841/3837] 신성통상(주) 저장됨
# [842/3837] (주)배럴 저장됨
# [843/3837] (주)이엔에프테크놀로지 저장됨
# [844/3837] (주)에스알바이오텍 저장됨
# [845/3837] 바디텍메드(주) 저장됨
# [846/3837] (주)스포츠서울 저장됨
# [847/3837] 하이즈항공(주) 저장됨
# [848/3837] 에스브이인베스트먼트 주식회사 저장됨
# [849/3837] 주식회사 화승알앤에이 저장됨
# [850/3837] 주식회사 고바이오랩 저장됨
# [851/3837] (주)남선알미늄 저장됨
# [852/3837] (주)한프 저장됨
# [853/3837] 비지스틸(주) 저장됨
# [854/3837] (주)세영디앤씨 저장됨
# [855/3837] (주)비엘사이언스 저장됨
# [856/3837] 주식회사 이십일스토어 저장됨
# [857/3837] (주)엔바이오니아 저장됨
# [858/3837] (주)제이알글로벌위탁관리부동산투자회사 저장됨
# [859/3837] 에이치비솔루션(주) 저장됨
# [860/3837] 대영포장(주) 저장됨
# [861/3837] (주)황금에스티 저장됨
# [862/3837] 앱클론(주) 저장됨
# [863/3837] 주식회사 티티씨디펜스 저장됨
# [864/3837] 남화산업(주) 저장됨
# [865/3837] (주)세원정공 저장됨
# [866/3837] (주)엠앤씨생명과학 저장됨
# [867/3837] 비씨엔씨(주) 저장됨
# [868/3837] 케이비제19호기업인수목적 주식회사 저장됨
# [869/3837] 주식회사 미래오토스 저장됨
# [870/3837] 한화생명보험(주) 저장됨
# [871/3837] (주)양지사 저장됨
# [872/3837] (주)케이씨티시 저장됨
# [873/3837] (주)인터코스 저장됨
# [874/3837] 만호제강(주) 저장됨
# [875/3837] (주)수프로 저장됨
# [876/3837] 주식회사 바이오에프디엔씨 저장됨
# [877/3837] 럭슬(주) 저장됨
# [878/3837] 주식회사 압타머사이언스 저장됨
# [879/3837] 쿠쿠홈시스 주식회사 저장됨
# [880/3837] (주)에이스토리 저장됨
# [881/3837] 테라셈(주) 저장됨
# [882/3837] 하이제5호기업인수목적 주식회사 저장됨
# [883/3837] 대동전자(주) 저장됨
# [884/3837] 하이골드오션3호선박투자회사 저장됨
# [885/3837] (주)서남 저장됨
# [886/3837] 주식회사 레이 저장됨
# [887/3837] (주)LS네트웍스 저장됨
# [888/3837] (주)방림 저장됨
# [889/3837] (주)자이언트스텝 저장됨
# [890/3837] (주)진로발효 저장됨
# [891/3837] (주)썬테크 저장됨
# [892/3837] (주)덱스터스튜디오 저장됨
# [893/3837] (주)국전약품 저장됨
# [894/3837] 신대양제지(주) 저장됨
# [895/3837] (주)미애부 저장됨
# [896/3837] (주)데이타솔루션 저장됨
# [897/3837] (주)에스앤에스텍 저장됨
# [898/3837] 삼영전자공업(주) 저장됨
# [899/3837] (주)전방 저장됨
# [900/3837] (주)지앤엘 저장됨
# [901/3837] 금강철강(주) 저장됨
# [902/3837] (주)전북은행 저장됨
# [903/3837] 이구산업(주) 저장됨
# [904/3837] (주)에치에프알 저장됨
# [905/3837] 태경케미컬 주식회사 저장됨
# [906/3837] (주)오디텍 저장됨
# [907/3837] (주)경방 저장됨
# [908/3837] (주)토니모리 저장됨
# [909/3837] 로체시스템즈(주) 저장됨
# [910/3837] (주)미래SCI 저장됨
# [911/3837] 한국화장품(주) 저장됨
# [912/3837] 한국컴퓨터(주) 저장됨
# [913/3837] (주)클래시스 저장됨
# [914/3837] 린드먼아시아인베스트먼트(주) 저장됨
# [915/3837] 유성기업(주) 저장됨
# [916/3837] (주)테라텍 저장됨
# [917/3837] (주)큐브엔터테인먼트 저장됨
# [918/3837] (주)오이솔루션 저장됨
# [919/3837] (주)넥스트엔터테인먼트월드 저장됨
# [920/3837] (주)보락 저장됨
# [921/3837] (주)디모아 저장됨
# [922/3837] (주)레이언스 저장됨
# [923/3837] (주)광주신세계 저장됨
# [924/3837] (주)혜인 저장됨
# [925/3837] (주)제일테크노스 저장됨
# [926/3837] (주)하이텍팜 저장됨
# [927/3837] 한전KPS(주) 저장됨
# [928/3837] (주)상보 저장됨
# [929/3837] (주)제이와이피엔터테인먼트 저장됨
# [930/3837] (주)나눔테크 저장됨
# [931/3837] KG케미칼(주) 저장됨
# [932/3837] (주)인포바인 저장됨
# [933/3837] (주)코리아써키트 저장됨
# [934/3837] 한일홀딩스(주) 저장됨
# [935/3837] 부산산업(주) 저장됨
# [936/3837] (주)서진오토모티브 저장됨
# [937/3837] 이화산업(주) 저장됨
# [938/3837] (주)유비쿼스홀딩스 저장됨
# [939/3837] 옵티시스(주) 저장됨
# [940/3837] (주)위지트 저장됨
# [941/3837] (주)슈프리마 저장됨
# [942/3837] (주)제이에스코퍼레이션 저장됨
# [943/3837] (주)지어소프트 저장됨
# [944/3837] (주)네오위즈홀딩스 저장됨
# [945/3837] SNT모티브(주) 저장됨
# [946/3837] 조광페인트(주) 저장됨
# [947/3837] (주)네오셈 저장됨
# [948/3837] (주)엘오티베큠 저장됨
# [949/3837] ㈜미래에셋맵스제1호위탁관리부동산투자회사 저장됨
# [950/3837] (주)신원 저장됨
# [951/3837] (주)풍강 저장됨
# [952/3837] 디케이락(주) 저장됨
# [953/3837] 고려신용정보(주) 저장됨
# [954/3837] (주)신화다이나믹스 저장됨
# [955/3837] (주)SH에너지화학 저장됨
# [956/3837] 대양전기공업(주) 저장됨
# [957/3837] 대봉엘에스(주) 저장됨
# [958/3837] 한국전기초자(주) 저장됨
# [959/3837] (주)플랜티넷 저장됨
# [960/3837] (주)이노메트리 저장됨
# [961/3837] (주)맥스로텍 저장됨
# [962/3837] (주)에스피지 저장됨
# [963/3837] (주)파버나인 저장됨
# [964/3837] (주)썸에이지 저장됨
# [965/3837] 아비코전자(주) 저장됨
# [966/3837] 지스마트글로벌(주) 저장됨
# [967/3837] (주)하림 저장됨
# [968/3837] 코리아에프티(주) 저장됨
# [969/3837] (주)현대에버다임 저장됨
# [970/3837] 디아이동일(주) 저장됨
# [971/3837] 바이오플러스 주식회사 저장됨
# [972/3837] 에프엔에스테크(주) 저장됨
# [973/3837] (주)모나미 저장됨
# [974/3837] 유진기업인수목적9호 주식회사 저장됨
# [975/3837] 일신방직(주) 저장됨
# [976/3837] (주)바이오빌 저장됨
# [977/3837] (주)대한과학 저장됨
# [978/3837] KB오토시스(주) 저장됨
# [979/3837] (주)그리티 저장됨
# [980/3837] 샘표(주) 저장됨
# [981/3837] 아세아제지(주) 저장됨
# [982/3837] (주)유진테크 저장됨
# [983/3837] (주)핑거스토리 저장됨
# [984/3837] 동일산업(주) 저장됨
# [985/3837] (주)와이비엠넷 저장됨
# [986/3837] (주)인터플렉스 저장됨
# [987/3837] (주)천일고속 저장됨
# [988/3837] 에이팸(주) 저장됨
# [989/3837] (주)예스티 저장됨
# [990/3837] (주)스튜디오 산타클로스 엔터테인먼트 저장됨
# [991/3837] (주)크라운해태홀딩스 저장됨
# [992/3837] (주)에스에이엠티 저장됨
# [993/3837] (주)인지소프트 저장됨
# [994/3837] (주)뉴프렉스 저장됨
# [995/3837] (주)에프에스티 저장됨
# [996/3837] (주)서한 저장됨
# [997/3837] (주)웹스 저장됨
# [998/3837] (주)아이티엠반도체 저장됨
# [999/3837] (주)세화피앤씨 저장됨
# [1000/3837] (주)서부티엔디 저장됨
# [1001/3837] (주)일지테크 저장됨
# [1002/3837] (주)프로텍 저장됨
# [1003/3837] (주)에프엔씨엔터테인먼트 저장됨
# [1004/3837] (주)비아트론 저장됨
# [1005/3837] (주)노브메타파마 저장됨
# [1006/3837] (주)이엠네트웍스 저장됨
# [1007/3837] (주)차백신연구소 저장됨
# [1008/3837] 엔에이치기업인수목적27호(주) 저장됨
# [1009/3837] 주식회사 진에어 저장됨
# [1010/3837] (주)한솔홈데코 저장됨
# [1011/3837] (주)로보로보 저장됨
# [1012/3837] 주식회사 필옵틱스 저장됨
# [1013/3837] 대정화금(주) 저장됨
# [1014/3837] (주)슈프리마에이치큐 저장됨
# [1015/3837] 주식회사 하스코 저장됨
# [1016/3837] (주)E1 저장됨
# [1017/3837] (주)메리츠금융지주 저장됨
# [1018/3837] 엔에이치기업인수목적26호 저장됨
# [1019/3837] SK텔레콤(주) 저장됨
# [1020/3837] 주식회사 엘엑스홀딩스 저장됨
# [1021/3837] (주)STX 저장됨
# [1022/3837] (주)한국큐빅 저장됨
# [1023/3837] (주)한국카본 저장됨
# [1024/3837] 신흥에스이씨(주) 저장됨
# [1025/3837] 진원생명과학(주) 저장됨
# [1026/3837] (주)엘에이티 저장됨
# [1027/3837] (주)LS 저장됨
# [1028/3837] (주)케이씨산업 저장됨
# [1029/3837] (주)케이에이치바텍 저장됨
# [1030/3837] (주)천보 저장됨
# [1031/3837] 경남스틸(주) 저장됨
# [1032/3837] (주)한국화장품제조 저장됨
# [1033/3837] 미래에셋벤처투자 주식회사 저장됨
# [1034/3837] 우원개발(주) 저장됨
# [1035/3837] 대상홀딩스(주) 저장됨
# [1036/3837] (주)이글벳 저장됨
# [1037/3837] (주)케이피티유 저장됨
# [1038/3837] (주)아이윈 저장됨
# [1039/3837] (주)코람코더원위탁관리부동산투자회사 저장됨
# [1040/3837] 신원종합개발(주) 저장됨
# [1041/3837] 씨유테크 주식회사 저장됨
# [1042/3837] (주)큐라클 저장됨
# [1043/3837] 아이비케이에스제13호기업인수목적 주식회사 저장됨
# [1044/3837] (주)예선테크 저장됨
# [1045/3837] (주)원티드랩 저장됨
# [1046/3837] 제이엠티(주) 저장됨
# [1047/3837] 큐캐피탈파트너스(주) 저장됨
# [1048/3837] (주)웹젠 저장됨
# [1049/3837] (주)시노펙스 저장됨
# [1050/3837] 주식회사 비스토스 저장됨
# [1051/3837] (주)티쓰리엔터테인먼트 저장됨
# [1052/3837] 교보13호기업인수목적 주식회사 저장됨
# [1053/3837] (주)성도이엔지 저장됨
# [1054/3837] (주)에스티아이 저장됨
# [1055/3837] 주식회사 카카오페이 저장됨
# [1056/3837] (주)한국씨티은행 저장됨
# [1057/3837] 하이트진로(주) 저장됨
# [1058/3837] (주)자비스 저장됨
# [1059/3837] 케이엠제약(주) 저장됨
# [1060/3837] (주)마이크로엔엑스 저장됨
# [1061/3837] 서암기계공업(주) 저장됨
# [1062/3837] (주)대구백화점 저장됨
# [1063/3837] 알에스오토메이션(주) 저장됨
# [1064/3837] 현대에이치티(주) 저장됨
# [1065/3837] 퍼스텍(주) 저장됨
# [1066/3837] (주)오픈베이스 저장됨
# [1067/3837] 송원산업(주) 저장됨
# [1068/3837] (주)멕아이씨에스 저장됨
# [1069/3837] 주식회사 카카오뱅크 저장됨
# [1070/3837] (주)케이씨에스 저장됨
# [1071/3837] 삼화페인트공업(주) 저장됨
# [1072/3837] (주)삼일 저장됨
# [1073/3837] 인포뱅크(주) 저장됨
# [1074/3837] (주)빅솔론 저장됨
# [1075/3837] 신영해피투모로우제6호기업인수목적 주식회사 저장됨
# [1076/3837] (주)광주은행 저장됨
# [1077/3837] (주)에코솔루션 저장됨
# [1078/3837] 케이비제20호기업인수목적 주식회사 저장됨
# [1079/3837] (주)조비 저장됨
# [1080/3837] 주식회사 핌스 저장됨
# [1081/3837] (주)데이터스트림즈 저장됨
# [1082/3837] 부산주공(주) 저장됨
# [1083/3837] 한국단자공업(주) 저장됨
# [1084/3837] 엔젯 주식회사 저장됨
# [1085/3837] (주)아이퀘스트 저장됨
# [1086/3837] (주)코셋 저장됨
# [1087/3837] (주)파이버프로 저장됨
# [1088/3837] 주식회사 제노코 저장됨
# [1089/3837] (주)자유투어 저장됨
# [1090/3837] 와이엠씨(주) 저장됨
# [1091/3837] (주)브이씨 저장됨
# [1092/3837] (주)피델릭스 저장됨
# [1093/3837] 주식회사 파워넷 저장됨
# [1094/3837] 두산밥캣 주식회사 저장됨
# [1095/3837] 지에이치신소재(주) 저장됨
# [1096/3837] 에스케이위탁관리부동산투자회사 주식회사 저장됨
# [1097/3837] 주식회사 디티앤씨알오 저장됨
# [1098/3837] 에스텍(주) 저장됨
# [1099/3837] (주)동양에스텍 저장됨
# [1100/3837] (주)아이컴포넌트 저장됨
# [1101/3837] (주)휴맥스홀딩스 저장됨
# [1102/3837] (주)쎄니트 저장됨
# [1103/3837] (주)성원 저장됨
# [1104/3837] (주)오리온홀딩스 저장됨
# [1105/3837] 유안타제7호기업인수목적 주식회사 저장됨
# [1106/3837] (주)대성하이텍 저장됨
# [1107/3837] (주)노루홀딩스 저장됨
# [1108/3837] 태양금속공업(주) 저장됨
# [1109/3837] 성신양회(주) 저장됨
# [1110/3837] 주식회사 에스제이그룹 저장됨
# [1111/3837] 이에스알켄달스퀘어위탁관리부동산투자회사주식회사 저장됨
# [1112/3837] 주식회사 플레이디 저장됨
# [1113/3837] 현대위아(주) 저장됨
# [1114/3837] (주)케이피에프 저장됨
# [1115/3837] (주)엔터미디어 저장됨
# [1116/3837] (주)진성티이씨 저장됨
# [1117/3837] 영화테크(주) 저장됨
# [1118/3837] 헝셩그룹유한회사 저장됨
# [1119/3837] (주) 탈로스 저장됨
# [1120/3837] (주)에이치비테크놀러지 저장됨
# [1121/3837] (주)우진아이엔에스 저장됨
# [1122/3837] (주)한농화성 저장됨
# [1123/3837] (주)덕성 저장됨
# [1124/3837] (주)상아프론테크 저장됨
# [1125/3837] (주)가온칩스 저장됨
# [1126/3837] (주)모보 저장됨
# [1127/3837] (주)세진중공업 저장됨
# [1128/3837] (주)신한 저장됨
# [1129/3837] 램테크놀러지(주) 저장됨
# [1130/3837] (주)서린바이오사이언스 저장됨
# [1131/3837] 아세아시멘트(주) 저장됨
# [1132/3837] (주)아이엠텍 저장됨
# [1133/3837] (주)호텔신라 저장됨
# [1134/3837] 한국정보통신(주) 저장됨
# [1135/3837] (주)선익시스템 저장됨
# [1136/3837] 한국정밀기계(주) 저장됨
# [1137/3837] (주)핸디소프트 저장됨
# [1138/3837] (주)금화피에스시 저장됨
# [1139/3837] (주)풍산 저장됨
# [1140/3837] 삼성전기(주) 저장됨
# [1141/3837] 하이트진로홀딩스(주) 저장됨
# [1142/3837] (주)이노션 저장됨
# [1143/3837] (주)파인엠텍 저장됨
# [1144/3837] (주)제이엘케이 저장됨
# [1145/3837] 에이치디씨영창 주식회사 저장됨
# [1146/3837] (주)LF 저장됨
# [1147/3837] (주)SG세계물산 저장됨
# [1148/3837] 유니퀘스트(주) 저장됨
# [1149/3837] 동아화성(주) 저장됨
# [1150/3837] 유엔젤(주) 저장됨
# [1151/3837] (주)경동도시가스 저장됨
# [1152/3837] 경인전자(주) 저장됨
# [1153/3837] (주)에스씨디 저장됨
# [1154/3837] (주)나노엔텍 저장됨
# [1155/3837] (주)정상제이엘에스 저장됨
# [1156/3837] (주)이엠비 저장됨
# [1157/3837] 미스터블루(주) 저장됨
# [1158/3837] (주)테크트랜스 저장됨
# [1159/3837] (주)이노진 저장됨
# [1160/3837] 갤럭시아머니트리(주) 저장됨
# [1161/3837] (주)부-스타 저장됨
# [1162/3837] (주)케이에스피 저장됨
# [1163/3837] 피에이치에이(주) 저장됨
# [1164/3837] (주)경동인베스트 저장됨
# [1165/3837] (주)블루탑 저장됨
# [1166/3837] (주)아가방앤컴퍼니 저장됨
# [1167/3837] 와이더블유 주식회사 저장됨
# [1168/3837] (주)파워로직스 저장됨
# [1169/3837] 성우테크론(주) 저장됨
# [1170/3837] (주)국순당 저장됨
# [1171/3837] (주)비지에프 저장됨
# [1172/3837] (주)삼일기업공사 저장됨
# [1173/3837] 태원물산(주) 저장됨
# [1174/3837] (주)네오티스 저장됨
# [1175/3837] SK가스(주) 저장됨
# [1176/3837] (주)더네이쳐홀딩스 저장됨
# [1177/3837] 한국주강(주) 저장됨
# [1178/3837] (주)와이솔 저장됨
# [1179/3837] (주)디아이씨 저장됨
# [1180/3837] (주)서원인텍 저장됨
# [1181/3837] 효성티앤씨(주) 저장됨
# [1182/3837] (주)엘지헬로비전 저장됨
# [1183/3837] 대덕전자(주) 저장됨
# [1184/3837] 신영해피투모로우제8호기업인수목적 주식회사 저장됨
# [1185/3837] (주)에이엔피 저장됨
# [1186/3837] 아세아(주) 저장됨
# [1187/3837] 엔에이치엔(주) 저장됨
# [1188/3837] 성우전자(주) 저장됨
# [1189/3837] (주)한네트 저장됨
# [1190/3837] 대원화성(주) 저장됨
# [1191/3837] (주)안랩 저장됨
# [1192/3837] 주식회사 유엑스엔 저장됨
# [1193/3837] (주)코메론 저장됨
# [1194/3837] 현대로템(주) 저장됨
# [1195/3837] 경남에너지(주) 저장됨
# [1196/3837] (주)폴루스바이오팜 저장됨
# [1197/3837] 금강공업(주) 저장됨
# [1198/3837] 대신증권(주) 저장됨
# [1199/3837] 신영해피투모로우제9호기업인수목적 주식회사 저장됨
# [1200/3837] 효성화학(주) 저장됨
# [1201/3837] (주)원익머트리얼즈 저장됨
# [1202/3837] DB손해보험(주) 저장됨
# [1203/3837] (주)주노콜렉션 저장됨
# [1204/3837] 인탑스(주) 저장됨
# [1205/3837] (주)벽산 저장됨
# [1206/3837] 패션플랫폼(주) 저장됨
# [1207/3837] (주)신세계톰보이 저장됨
# [1208/3837] 주식회사 라닉스 저장됨
# [1209/3837] (주)아이앤씨테크놀로지 저장됨
# [1210/3837] (주)메지온 저장됨
# [1211/3837] 한국월드와이드베트남부동산개발특별자산1호투자회사 저장됨
# [1212/3837] 한국콜마(주) 저장됨
# [1213/3837] 우수AMS(주) 저장됨
# [1214/3837] (주)원익 저장됨
# [1215/3837] (주)우리로 저장됨
# [1216/3837] 우리산업(주) 저장됨
# [1217/3837] 롯데관광개발(주) 저장됨
# [1218/3837] (주)하츠 저장됨
# [1219/3837] (주)아나패스 저장됨
# [1220/3837] 삼화전기(주) 저장됨
# [1221/3837] 현대코퍼레이션(주) 저장됨
# [1222/3837] (주)포메탈 저장됨
# [1223/3837] (주)지에프씨생명과학 저장됨
# [1224/3837] 하나금융15호기업인수목적 주식회사 저장됨
# [1225/3837] (주)웨이브일렉트로닉스 저장됨
# [1226/3837] (주)한독크린텍 저장됨
# [1227/3837] (주)씨엔플러스 저장됨
# [1228/3837] (주)켐온 저장됨
# [1229/3837] (주)코리아센터 저장됨
# [1230/3837] (주)씨앤에스링크 저장됨
# [1231/3837] (주)더존비즈온 저장됨
# [1232/3837] (주)이엘피 저장됨
# [1233/3837] 주식회사 스튜디오미르 저장됨
# [1234/3837] 주식회사 박셀바이오 저장됨
# [1235/3837] (주)이노와이어리스 저장됨
# [1236/3837] (주)이엠넷 저장됨
# [1237/3837] (주)현대리바트 저장됨
# [1238/3837] (주)링크제니시스 저장됨
# [1239/3837] 오픈엣지테크놀로지 주식회사 저장됨
# [1240/3837] (주)한섬 저장됨
# [1241/3837] 금호석유화학(주) 저장됨
# [1242/3837] 위즈코프(주) 저장됨
# [1243/3837] (주)육일씨엔에쓰 저장됨
# [1244/3837] CS 홀딩스(주) 저장됨
# [1245/3837] 유아이엘(주) 저장됨
# [1246/3837] 흥구석유(주) 저장됨
# [1247/3837] (주)이랜시스 저장됨
# [1248/3837] (주)피앤텔 저장됨
# [1249/3837] (주)대창스틸 저장됨
# [1250/3837] (주)제닉 저장됨
# [1251/3837] 부국철강(주) 저장됨
# [1252/3837] (주)에스디시스템 저장됨
# [1253/3837] 그린케미칼(주) 저장됨
# [1254/3837] 풍림산업(주) 저장됨
# [1255/3837] (주)알에프텍 저장됨
# [1256/3837] (주)미코 저장됨
# [1257/3837] 한국가스공사(주) 저장됨
# [1258/3837] 더블유씨피(주) 저장됨
# [1259/3837] (주)우성아이비 저장됨
# [1260/3837] 디와이씨(주) 저장됨
# [1261/3837] (주)유티아이 저장됨
# [1262/3837] (주)비츠로셀 저장됨
# [1263/3837] (주)파인디앤씨 저장됨
# [1264/3837] (주)디와이홀딩스 저장됨
# [1265/3837] 삼목에스폼(주) 저장됨
# [1266/3837] (주)서흥 저장됨
# [1267/3837] 팬오션(주) 저장됨
# [1268/3837] 메가스터디(주) 저장됨
# [1269/3837] (주)비비안 저장됨
# [1270/3837] (주) 유진로봇 저장됨
# [1271/3837] 이화공영(주) 저장됨
# [1272/3837] (주)에이치시티 저장됨
# [1273/3837] (주)솔본 저장됨
# [1274/3837] DSR(주) 저장됨
# [1275/3837] 미래나노텍(주) 저장됨
# [1276/3837] (주)네온테크 저장됨
# [1277/3837] 디와이파워(주) 저장됨
# [1278/3837] 두함지개발 주식회사 저장됨
# [1279/3837] 휴림로봇(주) 저장됨
# [1280/3837] (주)디지털대성 저장됨
# [1281/3837] (주)엠소닉 저장됨
# [1282/3837] (주)원익큐브 저장됨
# [1283/3837] 케어룸의료산업 주식회사 저장됨
# [1284/3837] (주) DB Inc. 저장됨
# [1285/3837] 해원에스티(주) 저장됨
# [1286/3837] (주)퍼시스 저장됨
# [1287/3837] 옴니시스템(주) 저장됨
# [1288/3837] 아이텍주식회사 저장됨
# [1289/3837] (주)액토즈소프트 저장됨
# [1290/3837] (주)네오펙트 저장됨
# [1291/3837] 에이펙스인텍(주) 저장됨
# [1292/3837] (주)레인보우로보틱스 저장됨
# [1293/3837] 펌텍코리아 주식회사 저장됨
# [1294/3837] (주)바이오노트 저장됨
# [1295/3837] 주식회사 지디 저장됨
# [1296/3837] 신송홀딩스(주) 저장됨
# [1297/3837] 이베스트기업인수목적5호 주식회사 저장됨
# [1298/3837] 풍국주정공업(주) 저장됨
# [1299/3837] (주)덕산테코피아 저장됨
# [1300/3837] 성창기업지주(주) 저장됨
# [1301/3837] (주)심팩인더스트리 저장됨
# [1302/3837] 유니온머티리얼(주) 저장됨
# [1303/3837] 유진투자증권(주) 저장됨
# [1304/3837] 주식회사 실리콘투 저장됨
# [1305/3837] 인터지스(주) 저장됨
# [1306/3837] 제룡전기(주) 저장됨
# [1307/3837] (주)이엠티 저장됨
# [1308/3837] 한국지역난방공사 저장됨
# [1309/3837] 삼천리(주) 저장됨
# [1310/3837] 대창단조(주) 저장됨
# [1311/3837] (주)선광 저장됨
# [1312/3837] (주)퓨전 저장됨
# [1313/3837] (주)큐리언트 저장됨
# [1314/3837] (주)브리지텍 저장됨
# [1315/3837] (주)나노신소재 저장됨
# [1316/3837] (주)씨엔알리서치 저장됨
# [1317/3837] 한국내화(주) 저장됨
# [1318/3837] (주)네오위즈 저장됨
# [1319/3837] 디젠스(주) 저장됨
# [1320/3837] 코위버(주) 저장됨
# [1321/3837] (주)피엔풍년 저장됨
# [1322/3837] (주)얼라인드제네틱스 저장됨
# [1323/3837] 일레덱스홀딩스(주) 저장됨
# [1324/3837] 삼화전자공업(주) 저장됨
# [1325/3837] (주)오리엔탈정공 저장됨
# [1326/3837] (주)다함이텍 저장됨
# [1327/3837] (주)아진엑스텍 저장됨
# [1328/3837] (주) 승일 저장됨
# [1329/3837] 피에스케이 주식회사 저장됨
# [1330/3837] (주)SNT홀딩스 저장됨
# [1331/3837] 대한유화(주) 저장됨
# [1332/3837] 티이엠씨 주식회사 저장됨
# [1333/3837] (주)칩스앤미디어 저장됨
# [1334/3837] (주)질경이 저장됨
# [1335/3837] (주)이글루코퍼레이션 저장됨
# [1336/3837] (주)아이디스 저장됨
# [1337/3837] 금호전기(주) 저장됨
# [1338/3837] (주)다산네트웍스 저장됨
# [1339/3837] (주)윌비스 저장됨
# [1340/3837] (주)인터로조 저장됨
# [1341/3837] (주)진바이오텍 저장됨
# [1342/3837] (주)쿠첸 저장됨
# [1343/3837] (주)무학 저장됨
# [1344/3837] (주)아이디스홀딩스 저장됨
# [1345/3837] (주)유한양행 저장됨
# [1346/3837] (주)엔이능률 저장됨
# [1347/3837] (주)아즈텍더블유비이 저장됨
# [1348/3837] (주)신화콘텍 저장됨
# [1349/3837] (주)한국스탠다드차타드은행 저장됨
# [1350/3837] 성문전자(주) 저장됨
# [1351/3837] 주식회사 엠게임 저장됨
# [1352/3837] (주)알테오젠 저장됨
# [1353/3837] (주)엘리비젼 저장됨
# [1354/3837] 엘티씨(주) 저장됨
# [1355/3837] (주)코텍 저장됨
# [1356/3837] (주)한미글로벌건축사사무소 저장됨
# [1357/3837] (주)크린앤사이언스 저장됨
# [1358/3837] (주)안지오랩 저장됨
# [1359/3837] (주)우신시스템 저장됨
# [1360/3837] (주)코맥스 저장됨
# [1361/3837] (주)지앤이헬스케어 저장됨
# [1362/3837] (주)아난티 저장됨
# [1363/3837] (주)노랑풍선 저장됨
# [1364/3837] ㈜에스티오 저장됨
# [1365/3837] (주)JB금융지주 저장됨
# [1366/3837] (주)휴엠앤씨 저장됨
# [1367/3837] (주)하이딥 저장됨
# [1368/3837] 대신밸런스제14호기업인수목적(주) 저장됨
# [1369/3837] (주)에스앤더블류 저장됨
# [1370/3837] (주)에스티큐브 저장됨
# [1371/3837] (주)디아이 저장됨
# [1372/3837] (주)에이치케이 저장됨
# [1373/3837] (주)코이즈 저장됨
# [1374/3837] (주)동방아그로 저장됨
# [1375/3837] (주)소리바다 저장됨
# [1376/3837] (주)세보엠이씨 저장됨
# [1377/3837] (주)케이옥션 저장됨
# [1378/3837] 한국자산신탁(주) 저장됨
# [1379/3837] (주)GS 저장됨
# [1380/3837] 교보증권(주) 저장됨
# [1381/3837] (주)현대바이오랜드 저장됨
# [1382/3837] (주)파인디지털 저장됨
# [1383/3837] (주)링네트 저장됨
# [1384/3837] (주)유니트론텍 저장됨
# [1385/3837] (주)디지아이 저장됨
# [1386/3837] (주)태양 저장됨
# [1387/3837] 대주전자재료(주) 저장됨
# [1388/3837] 대원미디어(주) 저장됨
# [1389/3837] 제일연마공업(주) 저장됨
# [1390/3837] (주)바이오프로테크 저장됨
# [1391/3837] 재영솔루텍(주) 저장됨
# [1392/3837] (주)아이씨디 저장됨
# [1393/3837] 에스지이(주) 저장됨
# [1394/3837] 주식회사 엔에이치프라임위탁관리부동산투자회사 저장됨
# [1395/3837] 디씨엠(주) 저장됨
# [1396/3837] (주)대륙제관 저장됨
# [1397/3837] 한세예스24홀딩스(주) 저장됨
# [1398/3837] (주)유에스티 저장됨
# [1399/3837] (주)바이오톡스텍 저장됨
# [1400/3837] (주)중앙에너비스 저장됨
# [1401/3837] 감성코퍼레이션(주) 저장됨
# [1402/3837] (주)티엘엔지니어링 저장됨
# [1403/3837] (주)화신 저장됨
# [1404/3837] (주)제이스텍 저장됨
# [1405/3837] 툴코리아(주) 저장됨
# [1406/3837] 동양철관(주) 저장됨
# [1407/3837] 현진소재(주) 저장됨
# [1408/3837] (주)하이스틸 저장됨
# [1409/3837] (주)드림씨아이에스 저장됨
# [1410/3837] 주식회사 덴티스 저장됨
# [1411/3837] 주식회사 오션스톤 저장됨
# [1412/3837] 주식회사 켈스 저장됨
# [1413/3837] (주)이오테크닉스 저장됨
# [1414/3837] (주)제주항공 저장됨
# [1415/3837] 주식회사 바이오다인 저장됨
# [1416/3837] (주)세진티에스 저장됨
# [1417/3837] (주)LG 저장됨
# [1418/3837] (주)제낙스 저장됨
# [1419/3837] 주식회사 에스지피엠 저장됨
# [1420/3837] 한국투자금융지주(주) 저장됨
# [1421/3837] 우리기술투자(주) 저장됨
# [1422/3837] (주)대한항공 저장됨
# [1423/3837] (주)동남합성 저장됨
# [1424/3837] 주식회사 석경에이티 저장됨
# [1425/3837] 한일단조공업(주) 저장됨
# [1426/3837] (주)파루 저장됨
# [1427/3837] 리노공업(주) 저장됨
# [1428/3837] 삼보모터스(주) 저장됨
# [1429/3837] 비나텍주식회사 저장됨
# [1430/3837] 우리엔터프라이즈(주) 저장됨
# [1431/3837] 코웨이(주) 저장됨
# [1432/3837] (주)하나투어 저장됨
# [1433/3837] (주)엑사이엔씨 저장됨
# [1434/3837] 코스모신소재(주) 저장됨
# [1435/3837] (주)한글과컴퓨터 저장됨
# [1436/3837] (주)쎌바이오텍 저장됨
# [1437/3837] (주)와이지-원 저장됨
# [1438/3837] (주)파세코 저장됨
# [1439/3837] (주)기산텔레콤 저장됨
# [1440/3837] (주)신테카바이오 저장됨
# [1441/3837] (주)LG화학 저장됨
# [1442/3837] (주)서울옥션 저장됨
# [1443/3837] 엔시트론(주) 저장됨
# [1444/3837] 주식회사 미래에셋글로벌위탁관리부동산투자회사 저장됨
# [1445/3837] (주)디알텍 저장됨
# [1446/3837] (주)매직마이크로 저장됨
# [1447/3837] CJ(주) 저장됨
# [1448/3837] 우리산업홀딩스(주) 저장됨
# [1449/3837] (주)에이원알폼 저장됨
# [1450/3837] 엘컴텍(주) 저장됨
# [1451/3837] (주)바이오스마트 저장됨
# [1452/3837] (주)상상인 저장됨
# [1453/3837] (주)에쎈테크 저장됨
# [1454/3837] (주)에이티넘인베스트먼트 저장됨
# [1455/3837] 기아(주) 저장됨
# [1456/3837] 코오롱글로벌(주) 저장됨
# [1457/3837] (주)SIMPAC 저장됨
# [1458/3837] 롯데지주(주) 저장됨
# [1459/3837] (주)일진파워 저장됨
# [1460/3837] (주)레드캡투어 저장됨
# [1461/3837] 현대엘리베이터(주) 저장됨
# [1462/3837] (주)텔레칩스 저장됨
# [1463/3837] 주식회사 폭스소프트 저장됨
# [1464/3837] (주)디지틀조선일보 저장됨
# [1465/3837] (주)헥토이노베이션 저장됨
# [1466/3837] (주)와이지플러스 저장됨
# [1467/3837] (주)티에프이 저장됨
# [1468/3837] (주)신도기연 저장됨
# [1469/3837] (주)하림지주 저장됨
# [1470/3837] 삼지전자(주) 저장됨
# [1471/3837] (주)에스에이티 저장됨
# [1472/3837] 케이프이에스제4호기업인수목적 주식회사 저장됨
# [1473/3837] 참존글로벌(주) 저장됨
# [1474/3837] 두산에너빌리티(주) 저장됨
# [1475/3837] (주)코미코 저장됨
# [1476/3837] (주)동운아나텍 저장됨
# [1477/3837] (주)에넥스 저장됨
# [1478/3837] (주)푸른기술 저장됨
# [1479/3837] (주)한솔케미칼 저장됨
# [1480/3837] (주)팍스넷 저장됨
# [1481/3837] (주)엔비티 저장됨
# [1482/3837] 삼현철강(주) 저장됨
# [1483/3837] 아이쓰리시스템(주) 저장됨
# [1484/3837] (주)에이스침대 저장됨
# [1485/3837] 현우산업(주) 저장됨
# [1486/3837] (주)전우정밀 저장됨
# [1487/3837] 주식회사 타임기술 저장됨
# [1488/3837] (주)휴코드홀딩스 저장됨
# [1489/3837] (주)금호에이치티 저장됨
# [1490/3837] 세기상사(주) 저장됨
# [1491/3837] ㈜핑거 저장됨
# [1492/3837] (주)유라테크 저장됨
# [1493/3837] 빛샘전자(주) 저장됨
# [1494/3837] 비엔케이제1호기업인수목적(주) 저장됨
# [1495/3837] 세방(주) 저장됨
# [1496/3837] (주)셀바스에이아이 저장됨
# [1497/3837] (주)에이루트 저장됨
# [1498/3837] (주)엔솔바이오사이언스 저장됨
# [1499/3837] (주)엘디티 저장됨
# [1500/3837] 한창산업(주) 저장됨
# [1501/3837] 인바이오주식회사 저장됨
# [1502/3837] 피씨엘(주) 저장됨
# [1503/3837] 부국증권(주) 저장됨
# [1504/3837] (주)이씨에스텔레콤 저장됨
# [1505/3837] 한국수출포장공업(주) 저장됨
# [1506/3837] 주식회사 루닛 저장됨
# [1507/3837] (주)네오리진 저장됨
# [1508/3837] 아진산업(주) 저장됨
# [1509/3837] 한일철강(주) 저장됨
# [1510/3837] (주)녹십자홀딩스 저장됨
# [1511/3837] (주)사조대림 저장됨
# [1512/3837] (주)나노 저장됨
# [1513/3837] 티제이미디어(주) 저장됨
# [1514/3837] 강남제비스코(주) 저장됨
# [1515/3837] (주)셀바스헬스케어 저장됨
# [1516/3837] (주)한국비엔씨 저장됨
# [1517/3837] (주)영우디에스피 저장됨
# [1518/3837] (주)삼성출판사 저장됨
# [1519/3837] (주)카스 저장됨
# [1520/3837] (주)휴비츠 저장됨
# [1521/3837] (주)이브이첨단소재 저장됨
# [1522/3837] (주)유비온 저장됨
# [1523/3837] (주)이미지스테크놀로지 저장됨
# [1524/3837] (주)에스폴리텍 저장됨
# [1525/3837] (주)골프존 저장됨
# [1526/3837] (주)오파스넷 저장됨
# [1527/3837] (주)SG글로벌 저장됨
# [1528/3837] KPX홀딩스(주) 저장됨
# [1529/3837] 켄코아에어로스페이스(주) 저장됨
# [1530/3837] 영화금속(주) 저장됨
# [1531/3837] 풀무원식품 (주) 저장됨
# [1532/3837] 키네마스터(주) 저장됨
# [1533/3837] 동양파일(주) 저장됨
# [1534/3837] (주)동방 저장됨
# [1535/3837] 주식회사 화승엔터프라이즈 저장됨
# [1536/3837] 씨제이바이오사이언스(주) 저장됨
# [1537/3837] 두산건설(주) 저장됨
# [1538/3837] 조선선재(주) 저장됨
# [1539/3837] 유진기업인수목적6호 주식회사 저장됨
# [1540/3837] 다스코(주) 저장됨
# [1541/3837] (주)클리오 저장됨
# [1542/3837] 하나29호기업인수목적 주식회사 저장됨
# [1543/3837] 엘비세미콘(주) 저장됨
# [1544/3837] (주)피엠티 저장됨
# [1545/3837] 주식회사 크래프톤 저장됨
# [1546/3837] 청광건설(주) 저장됨
# [1547/3837] 인크로스(주) 저장됨
# [1548/3837] (주)BYC 저장됨
# [1549/3837] 코츠테크놀로지(주) 저장됨
# [1550/3837] 주식회사 데이드림엔터테인먼트 저장됨
# [1551/3837] 더이앤엠(주) 저장됨
# [1552/3837] (주)제이아이테크 저장됨
# [1553/3837] 잉글우드랩 주식회사 저장됨
# [1554/3837] 레이저쎌 주식회사 저장됨
# [1555/3837] (주)에스제이엠 저장됨
# [1556/3837] 하나28호기업인수목적 주식회사 저장됨
# [1557/3837] (주)에스에프에이반도체 저장됨
# [1558/3837] 큐렉소(주) 저장됨
# [1559/3837] (주)에이텍모빌리티 저장됨
# [1560/3837] 지엠비코리아(주) 저장됨
# [1561/3837] (주)네오팜 저장됨
# [1562/3837] 주식회사 필에너지 저장됨
# [1563/3837] 미래산업(주) 저장됨
# [1564/3837] (주)에이블씨엔씨 저장됨
# [1565/3837] 한전산업개발(주) 저장됨
# [1566/3837] 에스케이증권제10호기업인수목적 주식회사 저장됨
# [1567/3837] 엔에이치기업인수목적29호 주식회사 저장됨
# [1568/3837] 케이비제25호기업인수목적 주식회사 저장됨
# [1569/3837] (주)유투바이오 저장됨
# [1570/3837] (주)비지에프리테일 저장됨
# [1571/3837] 아이비케이에스제17호기업인수목적 주식회사 저장됨
# [1572/3837] 주식회사 디에스단석 저장됨
# [1573/3837] 하나30호기업인수목적 주식회사 저장됨
# [1574/3837] 삼성기업인수목적4호(주) 저장됨
# [1575/3837] (주)티케이케미칼 저장됨
# [1576/3837] 콜마비앤에이치(주) 저장됨
# [1577/3837] (주)신한은행 저장됨
# [1578/3837] (주)케이엔더블유 저장됨
# [1579/3837] 케이비제23호기업인수목적 주식회사 저장됨
# [1580/3837] (주)세니젠 저장됨
# [1581/3837] 케이비제27호기업인수목적(주) 저장됨
# [1582/3837] (주)쏘닉스 저장됨
# [1583/3837] 데코앤에프 저장됨
# [1584/3837] 에이치엠씨아이비제4호기업인수목적 주식회사 저장됨
# [1585/3837] (주)트레스 저장됨
# [1586/3837] 미래에셋드림기업인수목적1호 주식회사 저장됨
# [1587/3837] SNT다이내믹스(주) 저장됨
# [1588/3837] S-Oil(주) 저장됨
# [1589/3837] 한국무브넥스(주) 저장됨
# [1590/3837] 하나금융19호기업인수목적 주식회사 저장됨
# [1591/3837] 팸텍주식회사 저장됨
# [1592/3837] (주)이수화학                              저장됨
# [1593/3837] 케이엔솔(주) 저장됨
# [1594/3837] (주)흥국 저장됨
# [1595/3837] 도이치모터스(주) 저장됨
# [1596/3837] (주)디엔오토모티브 저장됨
# [1597/3837] (주)삼진엘앤디 저장됨
# [1598/3837] (주)주연테크 저장됨
# [1599/3837] (주)다이오진 저장됨
# [1600/3837] 대보마그네틱(주) 저장됨
# [1601/3837] (주) 스맥 저장됨
# [1602/3837] (주)세아메탈 저장됨
# [1603/3837] (주)에코앤드림 저장됨
# [1604/3837] (주)캐스텍코리아 저장됨
# [1605/3837] (주)마니커에프앤지 저장됨
# [1606/3837] 브릿지바이오테라퓨틱스 주식회사 저장됨
# [1607/3837] 에이치엠씨아이비제6호기업인수목적 주식회사 저장됨
# [1608/3837] 넥스틸(주) 저장됨
# [1609/3837] (주)에스에이엠지엔터테인먼트 저장됨
# [1610/3837] 태양3C(주) 저장됨
# [1611/3837] 윙입푸드홀딩스 저장됨
# [1612/3837] 대동금속(주) 저장됨
# [1613/3837] (주)씨티케이 저장됨
# [1614/3837] (주)다우기술 저장됨
# [1615/3837] 주식회사 대원모방 저장됨
# [1616/3837] 대신밸런스제11호기업인수목적 저장됨
# [1617/3837] 유안타제8호기업인수목적 주식회사 저장됨
# [1618/3837] (주)율촌 저장됨
# [1619/3837] (주)휴맥스 저장됨
# [1620/3837] (주)한화갤러리아타임월드 저장됨
# [1621/3837] (주)LX인터내셔널 저장됨
# [1622/3837] (주)피씨디렉트 저장됨
# [1623/3837] 엠케이전자(주) 저장됨
# [1624/3837] (주)케이에스에스 해운 저장됨
# [1625/3837] 인베니아(주) 저장됨
# [1626/3837] LG전자(주) 저장됨
# [1627/3837] (주)크레버스 저장됨
# [1628/3837] (주)산돌 저장됨
# [1629/3837] SK디앤디(주) 저장됨
# [1630/3837] 유일에너테크(주) 저장됨
# [1631/3837] (주)디케이앤디 저장됨
# [1632/3837] (주)케스피온 저장됨
# [1633/3837] (주)마음에이아이 저장됨
# [1634/3837] (주)엑셈 저장됨
# [1635/3837] (주)아이비김영 저장됨
# [1636/3837] (주)누리플랜 저장됨
# [1637/3837] (주)제이에스티나 저장됨
# [1638/3837] 메가엠디(주) 저장됨
# [1639/3837] 스톤브릿지벤처스(주) 저장됨
# [1640/3837] (주)엘엠에스 저장됨
# [1641/3837] 주식회사 오픈놀 저장됨
# [1642/3837] 미래에셋증권(주) 저장됨
# [1643/3837] 에코바이오홀딩스(주) 저장됨
# [1644/3837] 나무기술(주) 저장됨
# [1645/3837] 엠아이큐브솔루션 주식회사 저장됨
# [1646/3837] 디에스티(주) 저장됨
# [1647/3837] (주)파두 저장됨
# [1648/3837] (주)에스엠벡셀 저장됨
# [1649/3837] (주)케이알엠 저장됨
# [1650/3837] 제이에스전선(주) 저장됨
# [1651/3837] 에이치엠씨아이비제5호기업인수목적 주식회사 저장됨
# [1652/3837] 하나26호기업인수목적 주식회사 저장됨
# [1653/3837] (주)멀티캠퍼스 저장됨
# [1654/3837] 대신밸런스제10호기업인수목적 주식회사 저장됨
# [1655/3837] 화성밸브(주) 저장됨
# [1656/3837] 삼정펄프(주) 저장됨
# [1657/3837] 엔에이치기업인수목적30호 주식회사 저장됨
# [1658/3837] 주식회사 넥스틴 저장됨
# [1659/3837] (주)세림비앤지 저장됨
# [1660/3837] (주)하우리 저장됨
# [1661/3837] 케이에이치필룩스(주) 저장됨
# [1662/3837] 주식회사 아센디오 저장됨
# [1663/3837] 한국제13호기업인수목적 주식회사 저장됨
# [1664/3837] (주)강원랜드 저장됨
# [1665/3837] (주)엘아이에스 저장됨
# [1666/3837] (주)케이엔에스 저장됨
# [1667/3837] 웰킵스하이텍(주) 저장됨
# [1668/3837] (주)NICE홀딩스 저장됨
# [1669/3837] (주)아모레퍼시픽 저장됨
# [1670/3837] 엔에이치기업인수목적19호 주식회사 저장됨
# [1671/3837] 압타바이오(주) 저장됨
# [1672/3837] 지니너스 주식회사 저장됨
# [1673/3837] 나라셀라(주) 저장됨
# [1674/3837] 에스지신성건설주식회사 저장됨
# [1675/3837] 우진비앤지(주) 저장됨
# [1676/3837] 롯데에너지머티리얼즈(주) 저장됨
# [1677/3837] (주)원풍 저장됨
# [1678/3837] 동화기업(주) 저장됨
# [1679/3837] STX엔진(주) 저장됨
# [1680/3837] 신화인터텍(주) 저장됨
# [1681/3837] 씨큐브(주) 저장됨
# [1682/3837] 뿌리깊은나무들(주) 저장됨
# [1683/3837] 에스와이스틸텍(주) 저장됨
# [1684/3837] 세명전기공업(주) 저장됨
# [1685/3837] (주)모베이스전자 저장됨
# [1686/3837] 라온시큐어(주) 저장됨
# [1687/3837] (주)다날 저장됨
# [1688/3837] 와이엠티(주) 저장됨
# [1689/3837] (주)디에스앤엘 저장됨
# [1690/3837] (주)서울리거 저장됨
# [1691/3837] 미원홀딩스(주) 저장됨
# [1692/3837] (주)디엠에스 저장됨
# [1693/3837] (주)한컴위드 저장됨
# [1694/3837] 이비테크(주) 저장됨
# [1695/3837] 디엑스앤브이엑스(주) 저장됨
# [1696/3837] (주)디지피 저장됨
# [1697/3837] 동양이엔피(주) 저장됨
# [1698/3837] (주)라온테크 저장됨
# [1699/3837] 금호건설(주) 저장됨
# [1700/3837] (주)토비스 저장됨
# [1701/3837] 한주라이트메탈(주) 저장됨
# [1702/3837] (주)제이엔비 저장됨
# [1703/3837] (주)코세스 저장됨
# [1704/3837] 주식회사 청담글로벌 저장됨
# [1705/3837] (주)파인테크닉스 저장됨
# [1706/3837] 대성산업(주) 저장됨
# [1707/3837] (주)에스엘에스바이오 저장됨
# [1708/3837] (주)체시스 저장됨
# [1709/3837] (주)유비쿼스 저장됨
# [1710/3837] (주)골드앤에스 저장됨
# [1711/3837] 현대제철(주) 저장됨
# [1712/3837] 이성씨엔아이(주) 저장됨
# [1713/3837] 디비금융제10호기업인수목적 주식회사 저장됨
# [1714/3837] (주)한빛레이저 저장됨
# [1715/3837] (주)까뮤이앤씨 저장됨
# [1716/3837] 미원화학(주) 저장됨
# [1717/3837] (주)이퓨쳐 저장됨
# [1718/3837] (주)케이엑스넥스지 저장됨
# [1719/3837] (주)메디젠휴먼케어 저장됨
# [1720/3837] (주)티사이언티픽 저장됨
# [1721/3837] (주)알멕 저장됨
# [1722/3837] 롯데위탁관리부동산투자회사 주식회사 저장됨
# [1723/3837] 주식회사 라온텍 저장됨
# [1724/3837] 가온그룹(주) 저장됨
# [1725/3837] 와이씨켐(주) 저장됨
# [1726/3837] 주식회사 프로티아 저장됨
# [1727/3837] (주)프로젠 저장됨
# [1728/3837] 캡스톤파트너스(주) 저장됨
# [1729/3837] (주)폴라리스오피스 저장됨
# [1730/3837] 동부건설(주) 저장됨
# [1731/3837] 한화손해보험(주) 저장됨
# [1732/3837] (주)동국알앤에스 저장됨
# [1733/3837] (주)삼원강재 저장됨
# [1734/3837] 주식회사 삼양패키징 저장됨
# [1735/3837] 엔에이치기업인수목적22호 주식회사 저장됨
# [1736/3837] 슈어소프트테크 주식회사 저장됨
# [1737/3837] (주)이노시뮬레이션 저장됨
# [1738/3837] 교보14호기업인수목적 주식회사 저장됨
# [1739/3837] 에이치엘비테라퓨틱스(주) 저장됨
# [1740/3837] (주)모두투어네트워크 저장됨
# [1741/3837] 주식회사 맘스터치앤컴퍼니 저장됨
# [1742/3837] 에스케이오션플랜트(주) 저장됨
# [1743/3837] (주)삼영 저장됨
# [1744/3837] (주)톱텍 저장됨
# [1745/3837] (주)매커스 저장됨
# [1746/3837] 미래에셋대우기업인수목적 5호 주식회사 저장됨
# [1747/3837] 주식회사 트루엔 저장됨
# [1748/3837] KG스틸(주) 저장됨
# [1749/3837] (주)넥슨게임즈 저장됨
# [1750/3837] 대신밸런스제12호기업인수목적 주식회사 저장됨
# [1751/3837] (주)넥스트아이 저장됨
# [1752/3837] 바다로19호선박투자회사 저장됨
# [1753/3837] 씨엑스아이헬스케어테크놀리지그룹리미티드 저장됨
# [1754/3837] 디비금융제9호기업인수목적 주식회사 저장됨
# [1755/3837] (주)도화엔지니어링 저장됨
# [1756/3837] (주)NI스틸 저장됨
# [1757/3837] (주)모헨즈 저장됨
# [1758/3837] 디와이(주) 저장됨
# [1759/3837] (주)대성미생물연구소 저장됨
# [1760/3837] 문배철강(주) 저장됨
# [1761/3837] (주)제이브이엠 저장됨
# [1762/3837] (주)WISCOM 저장됨
# [1763/3837] (주)파트론 저장됨
# [1764/3837] 한선엔지니어링(주) 저장됨
# [1765/3837] (주)SBS 저장됨
# [1766/3837] (주)아세아텍 저장됨
# [1767/3837] 해성옵틱스(주) 저장됨
# [1768/3837] (주)제이웨이 저장됨
# [1769/3837] (주)동성화인텍 저장됨
# [1770/3837] 주식회사 엠투아이코퍼레이션 저장됨
# [1771/3837] (주)세아특수강 저장됨
# [1772/3837] (주)우진엔텍 저장됨
# [1773/3837] 대신밸런스제17호기업인수목적 주식회사 저장됨
# [1774/3837] (주)케이티알파 저장됨
# [1775/3837] (주)에이치와이티씨 저장됨
# [1776/3837] 대신밸런스제16호기업인수목적(주) 저장됨
# [1777/3837] (주)웅진 저장됨
# [1778/3837] 주식회사 티에스인베스트먼트 저장됨
# [1779/3837] (주)앱코 저장됨
# [1780/3837] 에이치엘만도(주) 저장됨
# [1781/3837] (주)우리금융지주 저장됨
# [1782/3837] (주)티비씨 저장됨
# [1783/3837] (주)한진 저장됨
# [1784/3837] (주)모비데이즈 저장됨
# [1785/3837] (주)인팩 저장됨
# [1786/3837] (주)비엠티 저장됨
# [1787/3837] (주)진양홀딩스 저장됨
# [1788/3837] (주)애니플러스 저장됨
# [1789/3837] (주)아이오바이오 저장됨
# [1790/3837] (주)엠씨넥스 저장됨
# [1791/3837] (주)케이비스타위탁관리부동산투자회사 저장됨
# [1792/3837] (주)길교이앤씨 저장됨
# [1793/3837] 한화플러스제4호기업인수목적(주) 저장됨
# [1794/3837] 하이제6호기업인수목적 주식회사 저장됨
# [1795/3837] 삼보오토(주) 저장됨
# [1796/3837] (주)엘앤에프 저장됨
# [1797/3837] 한국투자ANKOR유전해외자원개발특별자산투자회사1호(지분증권) 저장됨
# [1798/3837] (주)뉴인텍 저장됨
# [1799/3837] (주)정원엔시스 저장됨
# [1800/3837] (주)케이프 저장됨
# [1801/3837] (주) 소프트센 저장됨
# [1802/3837] (주)부방 저장됨
# [1803/3837] (주)디에이피 저장됨
# [1804/3837] (주)키이스트 저장됨
# [1805/3837] (주)유성티엔에스 저장됨
# [1806/3837] (주)한빛소프트 저장됨
# [1807/3837] (주)포스뱅크 저장됨
# [1808/3837] 하나27호기업인수목적 주식회사 저장됨
# [1809/3837] 아퓨어스 주식회사 저장됨
# [1810/3837] (주)로지스몬 저장됨
# [1811/3837] (주)프럼파스트 저장됨
# [1812/3837] 에이치엘비생명과학(주) 저장됨
# [1813/3837] 무송지오씨(주) 저장됨
# [1814/3837] (주)자연과환경 저장됨
# [1815/3837] 한국항공우주산업(주) 저장됨
# [1816/3837] (주)에이디칩스 저장됨
# [1817/3837] 주식회사 센코 저장됨
# [1818/3837] 한국제10호기업인수목적 주식회사 저장됨
# [1819/3837] 에이치비인베스트먼트(주) 저장됨
# [1820/3837] (주)메카로 저장됨
# [1821/3837] (주)케이엔제이 저장됨
# [1822/3837] (주)협진 저장됨
# [1823/3837] (주)지노믹트리 저장됨
# [1824/3837] (주)모다 저장됨
# [1825/3837] 주식회사 카이노스메드 저장됨
# [1826/3837] (주)경인양행 저장됨
# [1827/3837] 이연제약(주) 저장됨
# [1828/3837] (주)이상네트웍스 저장됨
# [1829/3837] 나노캠텍(주) 저장됨
# [1830/3837] (주)코스텍시스 저장됨
# [1831/3837] (주)베노티앤알 저장됨
# [1832/3837] (주)티비에이치글로벌 저장됨
# [1833/3837] (주)손오공 저장됨
# [1834/3837] (주)나우코스 저장됨
# [1835/3837] (주)우리넷 저장됨
# [1836/3837] 하나금융23호기업인수목적 주식회사 저장됨
# [1837/3837] 어보브반도체(주) 저장됨
# [1838/3837] 주식회사 진코스텍 저장됨
# [1839/3837] 써니전자(주) 저장됨
# [1840/3837] (주)퓨쳐켐 저장됨
# [1841/3837] 씨앤지하이테크(주) 저장됨
# [1842/3837] 디엘 주식회사 저장됨
# [1843/3837] (주)연우 저장됨
# [1844/3837] 컴퍼니케이파트너스(주) 저장됨
# [1845/3837] (주)앤씨앤 저장됨
# [1846/3837] 에스케이증권제11호기업인수목적 주식회사 저장됨
# [1847/3837] (주)비올 저장됨
# [1848/3837] (주)원익큐엔씨 저장됨
# [1849/3837] (주)지유온 저장됨
# [1850/3837] 유니셈(주) 저장됨
# [1851/3837] 한화위탁관리부동산투자회사(주) 저장됨
# [1852/3837] 케이씨그린홀딩스(주) 저장됨
# [1853/3837] 주식회사 파로스아이바이오 저장됨
# [1854/3837] 주식회사 퓨런티어 저장됨
# [1855/3837] 주식회사 에코아이 저장됨
# [1856/3837] (주)내츄럴엔도텍 저장됨
# [1857/3837] (주)제놀루션 저장됨
# [1858/3837] 유진기업인수목적10호 주식회사 저장됨
# [1859/3837] 제이더블유신약(주) 저장됨
# [1860/3837] 하나31호기업인수목적 주식회사 저장됨
# [1861/3837] 비엔케이제2호기업인수목적(주) 저장됨
# [1862/3837] 케이에이치건설 주식회사 저장됨
# [1863/3837] (주)동인기연 저장됨
# [1864/3837] (주)인텍플러스 저장됨
# [1865/3837] 메리츠화재해상보험(주) 저장됨
# [1866/3837] (주)미래아이앤지 저장됨
# [1867/3837] (주)아모그린텍 저장됨
# [1868/3837] (주)경농 저장됨
# [1869/3837] (주)미래엔에듀파트너 저장됨
# [1870/3837] 화일약품(주) 저장됨
# [1871/3837] (주)이스트소프트 저장됨
# [1872/3837] (주)제이오 저장됨
# [1873/3837] 상상인제4호기업인수목적 주식회사 저장됨
# [1874/3837] 주식회사 싸이버원 저장됨
# [1875/3837] (주)아이패밀리에스씨 저장됨
# [1876/3837] (주)지에스이 저장됨
# [1877/3837] 대림통상(주) 저장됨
# [1878/3837] 지투파워(주) 저장됨
# [1879/3837] (주)펨트론 저장됨
# [1880/3837] 삼성공조(주) 저장됨
# ...
# [2175/3837] (주)비큐에이아이 저장됨
# [2176/3837] (주)에이치브이엠 저장됨
# [2177/3837] (주)세븐코스프 저장됨
# [2178/3837] (주)고제 저장됨
# [2179/3837] (주)쏘카 저장됨
# [2180/3837] 케이비아이동국실업(주) 저장됨
# [2181/3837] (주)에이피알 저장됨
# [2182/3837] 한솔아이원스(주) 저장됨
# [2183/3837] 알보젠코리아(주) 저장됨
# [2184/3837] (주)기린 저장됨
# [2185/3837] 남한제지(주) 저장됨
# [2186/3837] 에스케이 머티리얼즈(주) 저장됨
# [2187/3837] 대양제지공업(주) 저장됨
# [2188/3837] (주)에이엠에스 저장됨
# [2189/3837] (주)아이비진 저장됨
# [2190/3837] (주)성우하이텍 저장됨
# [2191/3837] 웰바이오텍(주) 저장됨
# [2192/3837] 태경산업(주) 저장됨
# [2193/3837] (주)제이티 저장됨
# [2194/3837] (주)디에이테크놀로지 저장됨
# [2195/3837] (주)카카오게임즈 저장됨
# [2196/3837] 주식회사 시지트로닉스 저장됨
# [2197/3837] 아이비케이에스제23호기업인수목적 주식회사 저장됨
# [2198/3837] 한국제11호기업인수목적 주식회사 저장됨
# [2199/3837] (주)차이커뮤니케이션 저장됨
# [2200/3837] (주)알루코 저장됨
# [2201/3837] 현대에이디엠바이오(주) 저장됨
# [2202/3837] 한국지주 주식회사 저장됨
# [2203/3837] 대웅바이오(주) 저장됨
# [2204/3837] (주)신동방CP 저장됨
# [2205/3837] 동신제약(주) 저장됨
# [2206/3837] 에스엠화진 주식회사 저장됨
# [2207/3837] (주)한창 저장됨
# [2208/3837] 에스트래픽 주식회사 저장됨
# [2209/3837] SK이터닉스(주) 저장됨
# [2210/3837] 브이엠(주) 저장됨
# [2211/3837] 하나33호기업인수목적 주식회사 저장됨
# [2212/3837] (주)엔에이치엔벅스 저장됨
# [2213/3837] 태림페이퍼(주) 저장됨
# [2214/3837] 롯데푸드(주) 저장됨
# [2215/3837] (주)네오퍼플 저장됨
# [2216/3837] (주)삼양엔텍 저장됨
# [2217/3837] (주)사조해표 저장됨
# [2218/3837] 대신정보통신(주) 저장됨
# [2219/3837] 노을 주식회사 저장됨
# [2220/3837] (주)삼양제넥스 저장됨
# [2221/3837] (주)선진지주 저장됨
# [2222/3837] (주)캐로스 저장됨
# [2223/3837] (주)쎄라텍 저장됨
# [2224/3837] 동국제강(주) 저장됨
# [2225/3837] 아세아페이퍼텍(주) 저장됨
# [2226/3837] 중앙제지(주) 저장됨
# [2227/3837] 주식회사 휴네시온 저장됨
# [2228/3837] 이베스트기업인수목적6호 주식회사 저장됨
# [2229/3837] 메리츠증권(주) 저장됨
# [2230/3837] (주)에스트라 저장됨
# [2231/3837] (주)아스트 저장됨
# [2232/3837] 교보16호기업인수목적 주식회사 저장됨
# [2233/3837] 이트론(주) 저장됨
# [2234/3837] 엔에이치투자증권(주) 저장됨
# [2235/3837] (주)엔피케이 저장됨
# [2236/3837] 진흥기업(주) 저장됨
# [2237/3837] 에스케이하이닉스(주) 저장됨
# [2238/3837] (주)에스엠엔터테인먼트 저장됨
# [2239/3837] 한솔홀딩스(주) 저장됨
# [2240/3837] 한국정보인증(주) 저장됨
# [2241/3837] SK(주) 저장됨
# [2242/3837] JW홀딩스(주) 저장됨
# [2243/3837] (주)엠아이텍 저장됨
# [2244/3837] (주)녹십자셀 저장됨
# [2245/3837] (주)로지시스 저장됨
# [2246/3837] (주)유일로보틱스 저장됨
# [2247/3837] (주)예림당 저장됨
# [2248/3837] (주)솔트룩스 저장됨
# [2249/3837] 한일약품공업(주) 저장됨
# [2250/3837] 주식회사 동원데어리푸드 저장됨
# [2251/3837] (주)행남사 저장됨
# [2252/3837] (주)성우몰드 저장됨
# [2253/3837] (주)예일바이오텍 저장됨
# [2254/3837] (주)미래자원엠엘 저장됨
# [2255/3837] 효성아이티엑스(주) 저장됨
# [2256/3837] (주)코썬바이오 저장됨
# [2257/3837] 주식회사 탑머티리얼 저장됨
# [2258/3837] 하나금융24호기업인수목적 주식회사 저장됨
# [2259/3837] (주)세중 저장됨
# [2260/3837] 아이진(주) 저장됨
# [2261/3837] (주)신한알파위탁관리부동산투자회사 저장됨
# [2262/3837] (주)디오 저장됨
# [2263/3837] (주)에이프로 저장됨
# [2264/3837] (주)젬 저장됨
# [2265/3837] (주)제이엠피 저장됨
# [2266/3837] 삼성이앤에이(주) 저장됨
# [2267/3837] (주)빛과전자 저장됨
# [2268/3837] (주)모아라이프플러스 저장됨
# [2269/3837] (주)윈팩 저장됨
# [2270/3837] (주)뉴보텍 저장됨
# [2271/3837] (주)서연 저장됨
# [2272/3837] (주)씨모스 저장됨
# [2273/3837] (주)메가터치 저장됨
# [2274/3837] 이에스산업(주) 저장됨
# [2275/3837] (주)인콘 저장됨
# [2276/3837] (주)하이로닉 저장됨
# [2277/3837] 에스지에이 솔루션즈(주) 저장됨
# [2278/3837] (주)화신정공 저장됨
# [2279/3837] 주식회사 시알홀딩스 저장됨
# [2280/3837] (주)나이스디앤비 저장됨
# [2281/3837] 유안타제15호기업인수목적 주식회사 저장됨
# [2282/3837] (주)인바이오젠 저장됨
# [2283/3837] 주식회사 지에스엔텍 저장됨
# [2284/3837] 코리언일랙트로닉스파워소스(주) 저장됨
# [2285/3837] 삼영무역(주) 저장됨
# [2286/3837] 주식회사 원바이오젠 저장됨
# [2287/3837] 케이이엠텍(주) 저장됨
# [2288/3837] (주)보령 저장됨
# [2289/3837] (주)사람인 저장됨
# [2290/3837] (주)일월지엠엘 저장됨
# [2291/3837] (주)레뷰코퍼레이션 저장됨
# [2292/3837] (주)듀켐바이오 저장됨
# [2293/3837] (주)경보제약 저장됨
# [2294/3837] (주)판타지오 저장됨
# [2295/3837] 드림라인(주) 저장됨
# [2296/3837] (주)한진칼 저장됨
# [2297/3837] 프레스티지바이오파마 저장됨
# [2298/3837] 디엘이앤씨 주식회사 저장됨
# [2299/3837] 에스케이스퀘어 주식회사 저장됨
# [2300/3837] (주)에스엠비나 저장됨
# [2301/3837] (주)티디에스팜 저장됨
# [2302/3837] 원풍물산(주) 저장됨
# [2303/3837] (주)비에프랩스 저장됨
# [2304/3837] (주)케이씨 저장됨
# [2305/3837] (주)플래스크 저장됨
# [2306/3837] (주)엘앤씨바이오 저장됨
# [2307/3837] (주)대산에프앤비 저장됨
# [2308/3837] 동국생명과학(주) 저장됨
# [2309/3837] (주)한텍 저장됨
# [2310/3837] (주)대유에이텍 저장됨
# [2311/3837] (주)씨제이이엔엠 저장됨
# [2312/3837] (주)비즈니스온커뮤니케이션 저장됨
# [2313/3837] 오름테라퓨틱 주식회사 저장됨
# [2314/3837] 주식회사 공구우먼 저장됨
# [2315/3837] (주)프리엠스 저장됨
# [2316/3837] 케이비제28호기업인수목적 주식회사 저장됨
# [2317/3837] 주식회사 아진카인텍 저장됨
# [2318/3837] (주)시큐브 저장됨
# [2319/3837] (주)플럼라인생명과학 저장됨
# [2320/3837] 신성델타테크(주) 저장됨
# [2321/3837] 우리벤처파트너스(주) 저장됨
# [2322/3837] (주)엑시온그룹 저장됨
# [2323/3837] (주)덕신이피씨 저장됨
# [2324/3837] 링세오코리아 주식회사 저장됨
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1963, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962     if not evt_handled:
# -> 1963         self.dialect.do_execute(
#    1964             cursor, str_statement, effective_parameters, context
#    1965         )
#    1967 if self._has_events or self.engine._has_events:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\default.py:943, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     942 def do_execute(self, cursor, statement, parameters, context=None):
# --> 943     cursor.execute(statement, parameters)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1198 try:
# -> 1199     first_packet = self.connection._read_packet()
#    1201     if first_packet.is_ok_packet():
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# DataError: (1406, "Data too long for column 'ceo_nm' at row 1")
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[6], line 111
#     107             print(f"[{i+1}/{len(corp_codes)}] {corp_code}: 정보 없음")
#     109         time.sleep(0.6)  # 100건/분 제한 고려
# --> 111 run_bulk_fetch()
#
# Cell In[6], line 104, in run_bulk_fetch()
#     102 data = fetch_overview(corp_code)
#     103 if data:
# --> 104     insert_or_update_overview(data)
#     105     print(f"[{i+1}/{len(corp_codes)}] {data.get('corp_name')} 저장됨")
#     106 else:
#
# Cell In[6], line 95, in insert_or_update_overview(data)
#      67 insert_query = """
#      68 INSERT INTO company_overview_row (
#      69     corp_code, corp_name, stock_code, ceo_nm, corp_cls, jurir_no,
#    (...)     92     acc_mt = VALUES(acc_mt);
#      93 """
#      94 with engine.begin() as conn:
# ---> 95     conn.execute(text(insert_query), safe_data)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1415, in Connection.execute(self, statement, parameters, execution_options)
#    1413     raise exc.ObjectNotExecutableError(statement) from err
#    1414 else:
# -> 1415     return meth(
#    1416         self,
#    1417         distilled_parameters,
#    1418         execution_options or NO_OPTIONS,
#    1419     )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\sql\elements.py:523, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     521     if TYPE_CHECKING:
#     522         assert isinstance(self, Executable)
# --> 523     return connection._execute_clauseelement(
#     524         self, distilled_params, execution_options
#     525     )
#     526 else:
#     527     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1637, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1625 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1626     "compiled_cache", self.engine._compiled_cache
#    1627 )
#    1629 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1630     dialect=dialect,
#    1631     compiled_cache=compiled_cache,
#    (...)   1635     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1636 )
# -> 1637 ret = self._execute_context(
#    1638     dialect,
#    1639     dialect.execution_ctx_cls._init_compiled,
#    1640     compiled_sql,
#    1641     distilled_parameters,
#    1642     execution_options,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     elem,
#    1646     extracted_params,
#    1647     cache_hit=cache_hit,
#    1648 )
#    1649 if has_events:
#    1650     self.dispatch.after_execute(
#    1651         self,
#    1652         elem,
#    (...)   1656         ret,
#    1657     )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1842, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1840     return self._exec_insertmany_context(dialect, context)
#    1841 else:
# -> 1842     return self._exec_single_context(
#    1843         dialect, context, statement, parameters
#    1844     )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1982, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1979     result = context._setup_result_proxy()
#    1981 except BaseException as e:
# -> 1982     self._handle_dbapi_exception(
#    1983         e, str_statement, effective_parameters, cursor, context
#    1984     )
#    1986 return result
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:2351, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2349 elif should_wrap:
#    2350     assert sqlalchemy_exception is not None
# -> 2351     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2352 else:
#    2353     assert exc_info[1] is not None
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1963, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1961                 break
#    1962     if not evt_handled:
# -> 1963         self.dialect.do_execute(
#    1964             cursor, str_statement, effective_parameters, context
#    1965         )
#    1967 if self._has_events or self.engine._has_events:
#    1968     self.dispatch.after_cursor_execute(
#    1969         self,
#    1970         cursor,
#    (...)   1974         context.executemany,
#    1975     )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\default.py:943, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     942 def do_execute(self, cursor, statement, parameters, context=None):
# --> 943     cursor.execute(statement, parameters)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# DataError: (pymysql.err.DataError) (1406, "Data too long for column 'ceo_nm' at row 1")
# [SQL:
#     INSERT INTO company_overview_row (
#         corp_code, corp_name, stock_code, ceo_nm, corp_cls, jurir_no,
#         bizr_no, adres, hm_url, ir_url, phn_no, fax_no,
#         induty_code, induty_name, est_dt, acc_mt
#     ) VALUES (
#         %(corp_code)s, %(corp_name)s, %(stock_code)s, %(ceo_nm)s, %(corp_cls)s, %(jurir_no)s,
#         %(bizr_no)s, %(adres)s, %(hm_url)s, %(ir_url)s, %(phn_no)s, %(fax_no)s,
#         %(induty_code)s, %(induty_name)s, %(est_dt)s, %(acc_mt)s
#     )
#     ON DUPLICATE KEY UPDATE
#         corp_name = VALUES(corp_name),
#         stock_code = VALUES(stock_code),
#         ceo_nm = VALUES(ceo_nm),
#         corp_cls = VALUES(corp_cls),
#         jurir_no = VALUES(jurir_no),
#         bizr_no = VALUES(bizr_no),
#         adres = VALUES(adres),
#         hm_url = VALUES(hm_url),
#         ir_url = VALUES(ir_url),
#         phn_no = VALUES(phn_no),
#         fax_no = VALUES(fax_no),
#         induty_code = VALUES(induty_code),
#         induty_name = VALUES(induty_name),
#         est_dt = VALUES(est_dt),
#         acc_mt = VALUES(acc_mt);
#     ]
# [parameters: {'corp_code': '00562245', 'corp_name': '주식회사 태웅로직스', 'stock_code': '124560', 'ceo_nm': 'Han Jae dong and Cho Yong jun (individual representative directors)', 'corp_cls': 'K', 'jurir_no': '1101111234543', 'bizr_no': '2028153193', 'adres': '서울특별시 서초구 서초대로42길 95 5층(서초동, 태웅빌딩)', 'hm_url': 'www.e-tgl.com', 'ir_url': '', 'phn_no': '02-2029-4300', 'fax_no': '02-2029-4699', 'induty_code': '5299', 'induty_name': '그 외 기타 운송관련 서비스업', 'est_dt': '19960120', 'acc_mt': '12'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)

# %%
import requests
import time
from sqlalchemy import create_engine, text
import pymysql
import pandas as pd

API_KEY = "4643bd437d383b208294914ce72d693589458062"
BASE_URL = "https://opendart.fss.or.kr/api/company.json"
DB_URL = "mysql+pymysql://root:1234@localhost:3310/stock_db"

engine = create_engine(DB_URL)

def fetch_corp_codes():
    query = "SELECT DISTINCT corp_code FROM dart_code"
    with engine.connect() as conn:
        result = conn.execute(text(query))
        return [row[0] for row in result.fetchall()]

def fetch_overview(corp_code):
    try:
        res = requests.get(BASE_URL, params={"crtfc_key": API_KEY, "corp_code": corp_code})
        if res.status_code == 200:
            json_data = res.json()
            if json_data.get("status") == "013":
                return None  # 기업 없음
            return json_data
    except Exception as e:
        print(f"API 오류: {corp_code}, {e}")
    return None

def get_industry_name(induty_code):
    try:
        return code_data[code_data['산업코드'] == int(induty_code)]['산업코드명'].values[0]
    except:
        return ""

def truncate(value, max_len):
    return str(value)[:max_len] if pd.notnull(value) else ""

def insert_or_update_overview(data):
    try:
        induty_code = data.get("induty_code", "")
        induty_name = get_industry_name(induty_code) if induty_code else ""

        # 컬럼별 최대 길이 (테이블 정의 기준)
        col_lens = {
            "corp_code": 10, "corp_name": 100, "stock_code": 20, "ceo_nm": 50,
            "corp_cls": 5, "jurir_no": 20, "bizr_no": 20, "adres": 200,
            "hm_url": 200, "ir_url": 200, "phn_no": 50, "fax_no": 50,
            "induty_code": 20, "induty_name": 100, "est_dt": 10, "acc_mt": 5
        }

        safe_data = {
            k: truncate(data.get(k, ""), col_lens[k])
            for k in col_lens
        }
        safe_data["induty_name"] = truncate(induty_name, 100)

        insert_query = """
        INSERT INTO company_overview_row (
            corp_code, corp_name, stock_code, ceo_nm, corp_cls, jurir_no,
            bizr_no, adres, hm_url, ir_url, phn_no, fax_no,
            induty_code, induty_name, est_dt, acc_mt
        ) VALUES (
            :corp_code, :corp_name, :stock_code, :ceo_nm, :corp_cls, :jurir_no,
            :bizr_no, :adres, :hm_url, :ir_url, :phn_no, :fax_no,
            :induty_code, :induty_name, :est_dt, :acc_mt
        )
        ON DUPLICATE KEY UPDATE
            corp_name = VALUES(corp_name),
            stock_code = VALUES(stock_code),
            ceo_nm = VALUES(ceo_nm),
            corp_cls = VALUES(corp_cls),
            jurir_no = VALUES(jurir_no),
            bizr_no = VALUES(bizr_no),
            adres = VALUES(adres),
            hm_url = VALUES(hm_url),
            ir_url = VALUES(ir_url),
            phn_no = VALUES(phn_no),
            fax_no = VALUES(fax_no),
            induty_code = VALUES(induty_code),
            induty_name = VALUES(induty_name),
            est_dt = VALUES(est_dt),
            acc_mt = VALUES(acc_mt);
        """

        with engine.begin() as conn:
            conn.execute(text(insert_query), safe_data)

    except Exception as e:
        print(f"DB 삽입 오류: {data.get('corp_code')} - {e}")

def run_bulk_fetch():
    corp_codes = fetch_corp_codes()
    print(f"{len(corp_codes)}개 기업 조회 시작")

    for i, corp_code in enumerate(corp_codes):
        try:
            data = fetch_overview(corp_code)
            if data:
                insert_or_update_overview(data)
                print(f"[{i+1}/{len(corp_codes)}] {data.get('corp_name')} 저장됨")
            else:
                print(f"[{i+1}/{len(corp_codes)}] {corp_code}: 정보 없음")
        except Exception as e:
            print(f"[{i+1}/{len(corp_codes)}] {corp_code} 처리 중 오류 발생: {e}")
        time.sleep(0.6)

# 실행
run_bulk_fetch()
# Out:
# 3837개 기업 조회 시작
# [1/3837] 한빛네트 저장됨
# [2/3837] (주)엔플렉스 저장됨
# [3/3837] (주)동서정보기술 저장됨
# [4/3837] 주식회사 애드모바일 저장됨
# [5/3837] (주)리더컴 저장됨
# [6/3837] (주)허메스홀딩스 저장됨
# [7/3837] (주)유티엑스 저장됨
# [8/3837] (주)글로포스트 저장됨
# [9/3837] (주)쏠라엔텍 저장됨
# [10/3837] (주)보홍 저장됨
# [11/3837] 동북아1호선박투자회사 저장됨
# [12/3837] 에듀아크 저장됨
# [13/3837] (주)데코 저장됨
# [14/3837] (주)엘앤씨피 저장됨
# [15/3837] (주)희훈디앤지 저장됨
# [16/3837] (주)퓨쳐인포넷 저장됨
# [17/3837] (주)쓰리디넷 저장됨
# [18/3837] (주)제일저축은행 저장됨
# [19/3837] 제일창업투자(주) 저장됨
# [20/3837] (주)현대DSF 저장됨
# [21/3837] (주)네프로아이티 저장됨
# [22/3837] (주)자강 저장됨
# [23/3837] 케이엠에스(주) 저장됨
# [24/3837] (주)에버리소스 저장됨
# [25/3837] 제이에스(주) 저장됨
# [26/3837] 태창기업(주) 저장됨
# [27/3837] (주)에이치비이에너지 저장됨
# [28/3837] (주)코어비트 저장됨
# [29/3837] 동북아8호선박투자회사 저장됨
# [30/3837] 한국통신데이타(주) 저장됨
# [31/3837] (주)케너텍 저장됨
# [32/3837] (주)다휘 저장됨
# [33/3837] 코오롱아이넷(주) 저장됨
# [34/3837] 캠브리지코오롱(주) 저장됨
# [35/3837] 네오세미테크(주) 저장됨
# [36/3837] (주)디에이치패션 저장됨
# [37/3837] 케이엠에이치(주) 저장됨
# [38/3837] (주)씨엘엘씨디 저장됨
# [39/3837] (주)현대푸드시스템 저장됨
# [40/3837] 메리츠종합금융(주) 저장됨
# [41/3837] 제넥셀세인(주) 저장됨
# [42/3837] (주)쓰리디월드 저장됨
# [43/3837] (주)스톰이앤에프 저장됨
# [44/3837] (주)소예 저장됨
# [45/3837] (주)엠엔에프씨 저장됨
# [46/3837] 하이트맥주(주) 저장됨
# [47/3837] (주)보광티에스 저장됨
# [48/3837] (주)아인스엠앤엠 저장됨
# [49/3837] 씨엔씨엔터프라이즈(주) 저장됨
# [50/3837] (주)아이알디 저장됨
# [51/3837] (주)바이나믹 저장됨
# [52/3837] (주)코크렙제7호위탁관리부동산투자회사 저장됨
# [53/3837] 엔빅스(주) 저장됨
# [54/3837] (주)선팩테크 저장됨
# [55/3837] 마이크로닉스(주) 저장됨
# [56/3837] (주)블루스톤디앤아이 저장됨
# [57/3837] (주)신지소프트 저장됨
# [58/3837] (주)맥쿼리센트럴오피스기업구조조정부동산투자회사 저장됨
# [59/3837] 테스텍(주) 저장됨
# [60/3837] (주)중앙디자인 저장됨
# [61/3837] (주)에코페트로시스템 저장됨
# [62/3837] 한림창업투자(주) 저장됨
# [63/3837] (주)헤쎄나 저장됨
# [64/3837] 미래에셋굿라이프혼합형자녀를위한투자회사10-1 저장됨
# [65/3837] (주)일공공일안경콘택트 저장됨
# [66/3837] (주)지앤알 저장됨
# [67/3837] (주)셀런 저장됨
# [68/3837] 한국 베트남15-1유전 해외자원개발투자회사 저장됨
# [69/3837] (주)에이치원바이오 저장됨
# [70/3837] (주)씨앤중공업 저장됨
# [71/3837] FnC코오롱(주) 저장됨
# [72/3837] (주)제너비오믹스 저장됨
# [73/3837] (주)케드콤 저장됨
# [74/3837] (주)지엔텍홀딩스 저장됨
# [75/3837] 동부씨엔아이(주) 저장됨
# [76/3837] (주)아이피에스 저장됨
# [77/3837] (주)에스브이에이치 저장됨
# [78/3837] (주)제이콤 저장됨
# [79/3837] (주)옥션 저장됨
# [80/3837] (주)네이쳐글로벌 저장됨
# [81/3837] GB 블루오션베트남주식혼합형 투자회사 1호 저장됨
# [82/3837] 엠씨티티코어(주) 저장됨
# [83/3837] (주)에이스 앤 파트너스 저장됨
# [84/3837] (주)지앤디윈텍 저장됨
# [85/3837] 인터피온반도체 저장됨
# [86/3837] (주)솔로몬저축은행 저장됨
# [87/3837] (주)엠트론스토리지테크놀로지 저장됨
# [88/3837] (주)에스티앤아이 저장됨
# [89/3837] (주)유퍼트 저장됨
# [90/3837] (주)엑스로드 저장됨
# [91/3837] (주)선우중공업 저장됨
# [92/3837] (주)남양 저장됨
# [93/3837] (주)엘지데이콤 저장됨
# [94/3837] (주)LG파워콤 저장됨
# [95/3837] 동산진흥(주) 저장됨
# [96/3837] 티이씨(주) 저장됨
# [97/3837] 한국기술산업(주) 저장됨
# [98/3837] (주)스타맥스 저장됨
# [99/3837] (주)유성티에스아이 저장됨
# [100/3837] (주)네오리소스 저장됨
# [101/3837] (주)케이알 저장됨
# [102/3837] (주)씨앤상선 저장됨
# [103/3837] (주)투미비티 저장됨
# [104/3837] (주)코아정보시스템 저장됨
# [105/3837] (주)케이에스리소스 저장됨
# [106/3837] (주)세계투어 저장됨
# [107/3837] 동양밸류오션기업인수목적(주) 저장됨
# [108/3837] 케이이엔지(주) 저장됨
# [109/3837] (주)사이버패스 저장됨
# [110/3837] 산양전기(주) 저장됨
# [111/3837] (주)으뜸상호저축은행 저장됨
# [112/3837] (주)국제개발 저장됨
# [113/3837] 세신(주) 저장됨
# [114/3837] 골든브릿지더블유엠경매부동산일호투자회사 저장됨
# [115/3837] (주)엘앤피아너스 저장됨
# [116/3837] (주)에이스일렉트로닉스 저장됨
# [117/3837] (주)디앤샵 저장됨
# [118/3837] (주)더 체인지 저장됨
# [119/3837] (주)다산자기관리부동산투자회사 저장됨
# [120/3837] (주)써니트렌드 저장됨
# [121/3837] (주)뉴젠비아이티 저장됨
# [122/3837] (주)룩소네이트 저장됨
# [123/3837] (주)현대오토넷 저장됨
# [124/3837] LG마이크론(주) 저장됨
# [125/3837] (주)서광건설산업 저장됨
# [126/3837] (주)플러스프로핏 저장됨
# [127/3837] (주)한와이어리스 저장됨
# [128/3837] (주)포휴먼 저장됨
# [129/3837] (주)알이네트웍스 저장됨
# [130/3837] (주)케이알제2호개발전문위탁관리부동산투자회사 저장됨
# [131/3837] 미래에셋맵스 오퍼튜니티 베트남 주식혼합형 투자회사 1호 저장됨
# [132/3837] (주)씨티엘테크 저장됨
# [133/3837] 이디디컴퍼니(주) 저장됨
# [134/3837] (주)케이티프리텔 저장됨
# [135/3837] (주)메카포럼 저장됨
# [136/3837] (주)에스피코프 저장됨
# [137/3837] (주)이롬텍 저장됨
# [138/3837] (주)이앤텍 저장됨
# [139/3837] (주)맥스브로 저장됨
# [140/3837] 토자이홀딩스 주식회사 저장됨
# [141/3837] (주)우방 저장됨
# [142/3837] 동양매직(주) 저장됨
# [143/3837] 코웰이홀딩스유한공사 저장됨
# [144/3837] (주)아구스 저장됨
# [145/3837] (주)대한은박지 저장됨
# [146/3837] (주)인스프리트 저장됨
# [147/3837] (주)하이럭스 저장됨
# [148/3837] (주)트리니티 저장됨
# [149/3837] (주)카라반케이디이 저장됨
# [150/3837] (주)더존디지털웨어 저장됨
# [151/3837] (주)디보스 저장됨
# [152/3837] (주)포네이처 저장됨
# [153/3837] (주)테이크시스템즈 저장됨
# [154/3837] (주)폴켐 저장됨
# [155/3837] 유리이에스(주) 저장됨
# [156/3837] (주)에프아이투어 저장됨
# [157/3837] (주)모빌탑 저장됨
# [158/3837] (주)올리브나인 저장됨
# [159/3837] (주)디패션 저장됨
# [160/3837] (주)알덱스 저장됨
# [161/3837] (주)오라바이오틱스 저장됨
# [162/3837] (주)시노펙스그린테크 저장됨
# [163/3837] (주)야호커뮤니케이션 저장됨
# [164/3837] 브이케이(주) 저장됨
# [165/3837] (주)팬택앤큐리텔 저장됨
# [166/3837] (주)팬텀엔터테인먼트그룹 저장됨
# [167/3837] (주)삼성수산 저장됨
# [168/3837] 동북아15호선박투자회사 저장됨
# [169/3837] (주)쌈지 저장됨
# [170/3837] 브이오산업(주) 저장됨
# [171/3837] 코디콤(주) 저장됨
# [172/3837] (주)제네시스엔알디 저장됨
# [173/3837] 동북아6호선박투자회사 저장됨
# [174/3837] (주)인네트 저장됨
# [175/3837] 한국월드와이드아시아태평양특별자산1호투자회사 저장됨
# [176/3837] (주)헤파호프코리아 저장됨
# [177/3837] (주)휴리프 저장됨
# [178/3837] (주)하이스마텍 저장됨
# [179/3837] 삼성디지털이미징(주) 저장됨
# [180/3837] 씨제이인터넷(주) 저장됨
# [181/3837] 엠넷미디어(주) 저장됨
# [182/3837] (주)온미디어 저장됨
# [183/3837] (주)유니텍전자 저장됨
# [184/3837] 위더스기술금융(주) 저장됨
# [185/3837] (주)클라스타 저장됨
# [186/3837] (주)아시아미디어홀딩스 저장됨
# [187/3837] 아이스테이션(주) 저장됨
# [188/3837] 동북아21호 선박투자회사 저장됨
# [189/3837] (주)에이스디지텍 저장됨
# [190/3837] (주)부산저축은행 저장됨
# [191/3837] (주)에피밸리 저장됨
# [192/3837] 오페스(주) 저장됨
# [193/3837] (주)액티투오 저장됨
# [194/3837] (주)에이치에스씨홀딩스 저장됨
# [195/3837] 한국고덴시(주) 저장됨
# [196/3837] (주)나리지*온 저장됨
# [197/3837] (주)프로비타 저장됨
# [198/3837] (주)제로원인터랙티브 저장됨
# [199/3837] 제일화재해상보험(주) 저장됨
# [200/3837] 동북아9호선박투자회사 저장됨
# [201/3837] (주)굿이엠지 저장됨
# [202/3837] (주)아이드림 저장됨
# [203/3837] (주)조인에너지 저장됨
# [204/3837] (주)태광이엔시 저장됨
# [205/3837] (주)렉스엘이앤지 저장됨
# [206/3837] 코리아퍼시픽05호 선박투자회사 저장됨
# [207/3837] (주)엑큐리스 저장됨
# [208/3837] 우경(주) 저장됨
# [209/3837] 세미텍(주) 저장됨
# [210/3837] 그린손해보험(주) 저장됨
# [211/3837] (주)대양글로벌 저장됨
# [212/3837] 엔하이테크(주) 저장됨
# [213/3837] (주)제너시스템즈 저장됨
# [214/3837] (주)엘트온 저장됨
# [215/3837] 태산엘시디(주) 저장됨
# [216/3837] 성원건설(주) 저장됨
# [217/3837] 대우송도개발(주) 저장됨
# [218/3837] (주)현대금속 저장됨
# [219/3837] (주)트라이써클 저장됨
# [220/3837] 아이비케이에스스마트에스엠이기업인수목적1호(주) 저장됨
# [221/3837] 네스테크(주) 저장됨
# [222/3837] 동북아5호선박투자회사 저장됨
# [223/3837] (주)파브코 저장됨
# [224/3837] 우리기업인수목적1호(주) 저장됨
# [225/3837] (주)뉴젠아이씨티 저장됨
# [226/3837] (주)인젠 저장됨
# [227/3837] (주)지앤에스티 저장됨
# [228/3837] (주)코크렙제8호위탁관리부동산투자회사 저장됨
# [229/3837] 유니온스틸(주) 저장됨
# [230/3837] 경남모직(주) 저장됨
# [231/3837] (주)대우증권그린코리아기업인수목적회사 저장됨
# [232/3837] (주)지노시스템 저장됨
# [233/3837] (주)한국투자신성장1호기업인수목적회사 저장됨
# [234/3837] (주)휴먼텍코리아 저장됨
# [235/3837] 에스에스씨피(주) 저장됨
# [236/3837] (주)평산 저장됨
# [237/3837] (주)지디코프 저장됨
# [238/3837] 아시아퍼시픽2호선박투자회사 저장됨
# [239/3837] 무한투자(주) 저장됨
# [240/3837] 동부티에스블랙펄기업인수목적(주) 저장됨
# [241/3837] (주)블루젬디앤씨 저장됨
# [242/3837] 부국퓨쳐스타즈기업인수목적주식회사 저장됨
# [243/3837] (주)예당컴퍼니 저장됨
# [244/3837] (주)터보테크 저장됨
# [245/3837] 케이비물산(주) 저장됨
# [246/3837] 연합과기공고유한공사 저장됨
# [247/3837] 글로스텍(주) 저장됨
# [248/3837] 중국고섬공고유한공사 저장됨
# [249/3837] 코리아퍼시픽06호 선박투자회사 저장됨
# [250/3837] (주)나노트로닉스 저장됨
# [251/3837] 미래에셋제1호기업인수목적(주) 저장됨
# [252/3837] (주)에이원마이크로 저장됨
# [253/3837] (주)에이프로테크놀로지 저장됨
# [254/3837] (주)모린스 저장됨
# [255/3837] (주)디지텍시스템스 저장됨
# [256/3837] (주)배명금속 저장됨
# [257/3837] 동북아4호선박투자회사 저장됨
# [258/3837] (주)사라콤 저장됨
# [259/3837] (주)폴리플러스 저장됨
# [260/3837] (주)영찬테크 저장됨
# [261/3837] (주)케이비부국제1호개발전문위탁관리부동산투자회사 저장됨
# [262/3837] 아시아퍼시픽8호선박투자회사 저장됨
# [263/3837] 진흥저축은행(주) 저장됨
# [264/3837] (주)에듀언스 저장됨
# [265/3837] 성융광전투자유한공사 저장됨
# [266/3837] (주)샤인시스템 저장됨
# [267/3837] (주)씨모텍 저장됨
# [268/3837] (주)에스컴 저장됨
# [269/3837] 아시아퍼시픽1호선박투자회사 저장됨
# [270/3837] 아시아퍼시픽3호선박투자회사 저장됨
# [271/3837] 한국저축은행(주) 저장됨
# [272/3837] 미리넷(주) 저장됨
# [273/3837] 3노드디지탈그룹유한공사 저장됨
# [274/3837] (주)유일엔시스 저장됨
# [275/3837] (주)케이피케미칼 저장됨
# [276/3837] (주)이루넷 저장됨
# [277/3837] 대신증권그로쓰알파기업인수목적(주) 저장됨
# [278/3837] (주)유에이블 저장됨
# [279/3837] (주)경윤하이드로에너지 저장됨
# [280/3837] (주)롯데미도파 저장됨
# [281/3837] 한화에스브이명장제1호기업인수목적(주) 저장됨
# [282/3837] (주)셀텍 저장됨
# [283/3837] 에스비아이앤솔로몬드림기업인수목적(주) 저장됨
# [284/3837] (주)위다스 저장됨
# [285/3837] (주)에스와이코퍼레이션 저장됨
# [286/3837] 어울림 네트웍스(주) 저장됨
# [287/3837] (주)에이디모터스 저장됨
# [288/3837] 평안물산(주) 저장됨
# [289/3837] (주)아큐텍 저장됨
# [290/3837] 히든챔피언제1호기업인수목적(주) 저장됨
# [291/3837] 동북아2호선박투자회사 저장됨
# [292/3837] 금강제강(주) 저장됨
# [293/3837] (주)아라온테크 저장됨
# [294/3837] (주)대국 저장됨
# [295/3837] 글로웍스(주) 저장됨
# [296/3837] 중국식품포장유한공사 저장됨
# [297/3837] 동북아3호선박투자회사 저장됨
# [298/3837] (주)지아이바이오 저장됨
# [299/3837] 주식회사 알에스넷 저장됨
# [300/3837] 나이스메탈(주) 저장됨
# [301/3837] 하나IB증권 주식회사 저장됨
# [302/3837] 퓨쳐비젼(주) 저장됨
# [303/3837] 이레전자산업(주) 저장됨
# [304/3837] (주)레이더스컴퍼니 저장됨
# [305/3837] (주)포이보스 저장됨
# [306/3837] (주)미디어코프 저장됨
# [307/3837] (주)케이디세코 저장됨
# [308/3837] (주)이노블루 저장됨
# [309/3837] (주)도움 저장됨
# [310/3837] (주)엑스씨이 저장됨
# [311/3837] 코오롱유화(주) 저장됨
# [312/3837] (주)세라온홀딩스 저장됨
# [313/3837] 현대경매부동산일호투자회사 저장됨
# [314/3837] 우수씨엔에스(주) 저장됨
# [315/3837] 동북아31호선박투자회사 저장됨
# [316/3837] 후야인포넷(주) 저장됨
# [317/3837] (주)이레아이엔씨 저장됨
# [318/3837] (주)카스코 저장됨
# [319/3837] (주)모델라인 저장됨
# [320/3837] (주)청람디지탈 저장됨
# [321/3837] (주)한텔 저장됨
# [322/3837] (주)코스모스피엘씨 저장됨
# [323/3837] (주)나노하이텍 저장됨
# [324/3837] (주)쓰리소프트 저장됨
# [325/3837] (주)트라이콤 저장됨
# [326/3837] 케이엔에스홀딩스(주) 저장됨
# [327/3837] (주)지비에스 저장됨
# [328/3837] (주)피더블유제네틱스 저장됨
# [329/3837] 엠텍반도체(주) 저장됨
# [330/3837] (주)세니콘 저장됨
# [331/3837] 유씨아이콜스(주) 저장됨
# [332/3837] 코크렙제3호CR리츠 저장됨
# [333/3837] (주)아이티센네트웍스 저장됨
# [334/3837] 리얼티코리아제1호기업구조조정부동산투자(주) 저장됨
# [335/3837] (주)BHK 저장됨
# [336/3837] (주)포넷 저장됨
# [337/3837] 맥슨텔레콤(주) 저장됨
# [338/3837] 엔토리노(주) 저장됨
# [339/3837] (주)두림티앤씨 저장됨
# [340/3837] 동북아27호선박투자회사 저장됨
# [341/3837] 동북아28호선박투자회사 저장됨
# [342/3837] 동북아30호선박투자회사 저장됨
# [343/3837] 동북아29호선박투자회사 저장됨
# [344/3837] 현주컴퓨터(주) 저장됨
# [345/3837] LG석유화학(주) 저장됨
# [346/3837] (주)오브제 저장됨
# [347/3837] (주)휴닉스 저장됨
# [348/3837] 세이프아시아(주) 저장됨
# [349/3837] (주)코크렙제1호기업구조조정부동산투자회사 저장됨
# [350/3837] (주)위너스인프라인 저장됨
# [351/3837] AP우주통신(주) 저장됨
# [352/3837] (주)조이토토 저장됨
# [353/3837] (주)한도하이테크 저장됨
# [354/3837] (주)에너윈 저장됨
# [355/3837] 유레스메리츠제1호 저장됨
# [356/3837] 교보메리츠퍼스트기업구조조정부동산투자회사 저장됨
# [357/3837] 굿앤리치부동산공경매투자회사1호 저장됨
# [358/3837] 한국합섬(주) 저장됨
# [359/3837] 굿앤리치부동산공경매투자회사2호 저장됨
# [360/3837] (주)디에스피이엔티 저장됨
# [361/3837] (주)시큐어소프트 저장됨
# [362/3837] 동부일렉트로닉스(주) 저장됨
# [363/3837] 고려시멘트(주) 저장됨
# [364/3837] (주)베스트플로우 저장됨
# [365/3837] (주)쿨투 저장됨
# [366/3837] (주)우영 저장됨
# [367/3837] 모빌링크텔레콤(주) 저장됨
# [368/3837] 극동제혁(주) 저장됨
# [369/3837] (주)한마음상호저축은행 저장됨
# [370/3837] 그로웰전자(주) 저장됨
# [371/3837] (주)부흥 저장됨
# [372/3837] (주)퍼시픽글라스 저장됨
# [373/3837] (주)아이인프라 저장됨
# [374/3837] (주)씨크롭 저장됨
# [375/3837] 외환신용카드주식회사 저장됨
# [376/3837] 삼화기연(주) 저장됨
# [377/3837] 대흥멀티미디어통신(주) 저장됨
# [378/3837] 텔슨정보통신(주) 저장됨
# [379/3837] (주)비이티 저장됨
# [380/3837] 코오롱인터내셔널(주) 저장됨
# [381/3837] 엔써커뮤니티 주식회사 저장됨
# [382/3837] 써미트테크놀로지 저장됨
# [383/3837] 코리아이앤디(주) 저장됨
# [384/3837] (주)트래픽아이티에스 저장됨
# [385/3837] 주식회사 호성 저장됨
# [386/3837] (주)넥스텔 저장됨
# [387/3837] 쓰리알(주) 저장됨
# [388/3837] (주)그로웰텔레콤 저장됨
# [389/3837] (주)서통 저장됨
# [390/3837] (주)테크메이트 저장됨
# [391/3837] (주)한아시스템 저장됨
# [392/3837] (주)엔에스아이 저장됨
# [393/3837] (주)케이티씨텔레콤 저장됨
# [394/3837] 주식회사 신한SIT 저장됨
# [395/3837] (주)스마텔 저장됨
# [396/3837] (주)동방라이텍 저장됨
# [397/3837] (주)아이텍스필 저장됨
# [398/3837] 이수세라믹(주) 저장됨
# [399/3837] (주)코크렙제2호기업구조조정부동산투자회사 저장됨
# [400/3837] 영풍산업주식회사 저장됨
# [401/3837] 주식회사 모닷텔 저장됨
# [402/3837] 광덕물산(주) 저장됨
# [403/3837] 동원증권(주) 저장됨
# [404/3837] (주)우주통신 저장됨
# [405/3837] 기라정보통신(주) 저장됨
# [406/3837] 텔슨전자(주) 저장됨
# [407/3837] (주)하이콤정보통신 저장됨
# [408/3837] 미래에셋굿라이프혼합형자녀를위한펀드5-1 저장됨
# [409/3837] (주)한메엔에스 저장됨
# [410/3837] (주)이지클럽 저장됨
# [411/3837] 넷컴스토리지 저장됨
# [412/3837] (주)모디아 저장됨
# [413/3837] (주)성진산업 저장됨
# [414/3837] (주)아이엠아이티 저장됨
# [415/3837] (주)맥시스템 저장됨
# [416/3837] (주)슈마일렉트론 저장됨
# [417/3837] (주)센추리 저장됨
# [418/3837] (주)베네데스하이텍 저장됨
# [419/3837] (주)에스오케이 저장됨
# [420/3837] 세원텔레콤(주) 저장됨
# [421/3837] 한강구조조정기금 저장됨
# [422/3837] (주)케이엔티 저장됨
# [423/3837] 대아리드선(주) 저장됨
# [424/3837] (주)월드텔레콤 저장됨
# [425/3837] (주)업필 저장됨
# [426/3837] (주)화림모드 저장됨
# [427/3837] 대아건설(주) 저장됨
# [428/3837] (주)창민테크 저장됨
# [429/3837] 씨제이엔터테인먼트(주) 저장됨
# [430/3837] (주)대백쇼핑 저장됨
# [431/3837] (주)지니웍스 저장됨
# [432/3837] 신광기업(주) 저장됨
# [433/3837] 유진종합개발(주) 저장됨
# [434/3837] (주)휘튼 저장됨
# [435/3837] 엠바이엔(주) 저장됨
# [436/3837] (주)대호 저장됨
# [437/3837] (주)한신코퍼레이션 저장됨
# [438/3837] 금강화섬(주) 저장됨
# [439/3837] 우리증권(주) 저장됨
# [440/3837] 주식회사 피코소프트 저장됨
# [441/3837] 바이오시스 저장됨
# [442/3837] (주)윌텍정보통신 저장됨
# [443/3837] 삼도물산(주) 저장됨
# [444/3837] (주)현대멀티캡 저장됨
# [445/3837] 코리아퍼시픽01호선박투자회사 저장됨
# [446/3837] 코리아퍼시픽02호선박투자회사 저장됨
# [447/3837] (주)신양오라컴디스플레이 저장됨
# [448/3837] (주)이룸지엔지 저장됨
# [449/3837] (주)에스와이이노베이션 저장됨
# [450/3837] 코리아퍼시픽03호선박투자회사 저장됨
# [451/3837] 코리아퍼시픽04호선박투자회사 저장됨
# [452/3837] (주)유아이에너지 저장됨
# [453/3837] 아시아퍼시픽14호선박투자회사 저장됨
# [454/3837] 아시아퍼시픽13호선박투자회사 저장됨
# [455/3837] 아시아퍼시픽10호선박투자회사 저장됨
# [456/3837] 현대에이블기업인수목적1호(주) 저장됨
# [457/3837] 아시아퍼시픽11호선박투자회사 저장됨
# [458/3837] 아시아퍼시픽12호선박투자회사 저장됨
# [459/3837] 주식회사 호반산업 저장됨
# [460/3837] (주)실리콘화일 저장됨
# [461/3837] (주)비엔씨컴퍼니 저장됨
# [462/3837] 동북아11호선박투자회사 저장됨
# [463/3837] 동북아14호선박투자회사 저장됨
# [464/3837] (주)디아이디 저장됨
# [465/3837] 부산방직공업(주) 저장됨
# [466/3837] (주)현대에이치씨엔동작방송 저장됨
# [467/3837] (주)플렉스컴 저장됨
# [468/3837] (주)웹솔루스 저장됨
# [469/3837] (주)마이스코 저장됨
# [470/3837] (주)솔트웍스 저장됨
# [471/3837] 현대페인트(주) 저장됨
# [472/3837] (주)한진해운 저장됨
# [473/3837] (주)글라소울 저장됨
# [474/3837] 주식회사 팬택자산관리 저장됨
# [475/3837] (주)케이엔씨글로벌 저장됨
# [476/3837] (주)아이디에스 저장됨
# [477/3837] (주)훈영 저장됨
# [478/3837] 한솔아트원제지㈜ 저장됨
# [479/3837] (주)엠제이비 저장됨
# [480/3837] 바다로3호선박투자회사 저장됨
# [481/3837] (주)아이팩토리 저장됨
# [482/3837] 거북선5호선박투자회사 저장됨
# [483/3837] 거북선6호선박투자회사 저장됨
# [484/3837] (주)피엘에이 저장됨
# [485/3837] 닉스테크(주) 저장됨
# [486/3837] 아시아퍼시픽9호선박투자회사 저장됨
# [487/3837] 거북선4호선박투자회사 저장됨
# [488/3837] (주)중앙건설 저장됨
# [489/3837] 미래에셋새천년코리아벤처펀드일호 저장됨
# [490/3837] 에이스하이텍(주) 저장됨
# [491/3837] (주)태창파로스 저장됨
# [492/3837] 평산차업집단유한공사 저장됨
# [493/3837] 스탠다드펌(주) 저장됨
# [494/3837] 벽산건설(주) 저장됨
# [495/3837] NH농협증권(주) 저장됨
# [496/3837] 아시아퍼시픽4호선박투자회사 저장됨
# [497/3837] 한화화인케미칼(주) 저장됨
# [498/3837] (주)지오엠씨 저장됨
# [499/3837] (주)에듀패스 저장됨
# [500/3837] (주)아이디에이치 저장됨
# [501/3837] 거북선7호선박투자회사 저장됨
# [502/3837] (주)서울상호저축은행 저장됨
# [503/3837] (주)와이즈파워 저장됨
# [504/3837] (주)코크렙제15호기업구조조정부동산투자회사 저장됨
# [505/3837] (주)티브로드 한빛방송 저장됨
# [506/3837] 거북선3호 선박투자회사 저장됨
# [507/3837] (주)동성하이켐 저장됨
# [508/3837] (주)클루넷 저장됨
# [509/3837] 코리아퍼시픽07호 선박투자회사 저장됨
# [510/3837] (주)씨유전자 저장됨
# [511/3837] 삼목강업(주) 저장됨
# [512/3837] (주)에스비엠 저장됨
# [513/3837] (주)솔빛미디어 저장됨
# [514/3837] (주)에프지엔개발전문자기관리부동산투자회사 저장됨
# [515/3837] 현대하이스코(주) 저장됨
# [516/3837] 거북선1호선박투자회사 저장됨
# [517/3837] (주)코아에스앤아이 저장됨
# [518/3837] 주식회사 자원메디칼 저장됨
# [519/3837] (주)삼우이엠씨 저장됨
# [520/3837] 어울림정보기술(주) 저장됨
# [521/3837] (주)티브로드도봉강북방송 저장됨
# [522/3837] (주)티이씨앤코 저장됨
# [523/3837] (주)화인자산관리 저장됨
# [524/3837] (주)로케트전기 저장됨
# [525/3837] (주)신일건업 저장됨
# [526/3837] 제일모직(주) 저장됨
# [527/3837] (주)퓨얼셀파워 저장됨
# [528/3837] 아루히 주식회사 저장됨
# [529/3837] (주)지티앤티 저장됨
# [530/3837] (주)모아에스앤에스 저장됨
# [531/3837] 어울림엘시스(주) 저장됨
# [532/3837] (주)이코리아자기관리부동산투자회사 저장됨
# [533/3837] (주)에이치앤아이 저장됨
# [534/3837] (주)디에스 저장됨
# [535/3837] (주)유니드코리아 저장됨
# [536/3837] (주)아이레보 저장됨
# [537/3837] (주)포스코티엠씨 저장됨
# [538/3837] 거북선2호 선박투자회사 저장됨
# [539/3837] 아시아퍼시픽5호선박투자회사 저장됨
# [540/3837] 아시아퍼시픽7호선박투자회사 저장됨
# [541/3837] 아시아퍼시픽6호선박투자회사 저장됨
# [542/3837] 에스케이제1호기업인수목적(주) 저장됨
# [543/3837] 대우기업인수목적3호(주) 저장됨
# [544/3837] 엔에이치에스엘기업인수목적(주) 저장됨
# [545/3837] 케이티비기업인수목적1호(주) 저장됨
# [546/3837] 미래에셋제3호기업인수목적(주) 저장됨
# [547/3837] (주)넥솔론 저장됨
# [548/3837] (주)디피앤케이 저장됨
# [549/3837] (주)비앤에스미디어 저장됨
# [550/3837] 에스지에이시스템즈(주) 저장됨
# [551/3837] 웨이포트유한공사 저장됨
# [552/3837] 아스팩오일(주) 저장됨
# [553/3837] 하이골드오션2호 선박투자회사 저장됨
# [554/3837] 골든브릿지제2호기업인수목적(주) 저장됨
# [555/3837] (주)대성합동지주 저장됨
# [556/3837] 중국원양자원유한공사 저장됨
# [557/3837] 아시아퍼시픽15호선박투자회사 저장됨
# [558/3837] 하나머스트3호기업인수목적(주) 저장됨
# [559/3837] (주)신성에프에이 저장됨
# [560/3837] (주)한진피앤씨 저장됨
# [561/3837] (주)나이코 저장됨
# [562/3837] 대우기업인수목적2호(주) 저장됨
# [563/3837] (주)에스에스컴텍 저장됨
# [564/3837] 동북아10호선박투자회사 저장됨
# [565/3837] 골든브릿지제3호기업인수목적(주) 저장됨
# [566/3837] (주)제이앤유글로벌 저장됨
# [567/3837] 케이비제8호기업인수목적 주식회사 저장됨
# [568/3837] 키움제3호기업인수목적주식회사 저장됨
# [569/3837] 유진기업인수목적3호(주) 저장됨
# [570/3837] 한화에이스기업인수목적2호(주) 저장됨
# [571/3837] 엔에이치기업인수목적7호 주식회사 저장됨
# [572/3837] 교보5호기업인수목적(주) 저장됨
# [573/3837] 케이비드림투게더제3호기업인수목적 주식회사 저장됨
# [574/3837] 유안타제2호기업인수목적(주) 저장됨
# [575/3837] 에스엠로보틱스(주) 저장됨
# [576/3837] (주)시냅스엠 저장됨
# [577/3837] 동부제4호기업인수목적주식회사 저장됨
# [578/3837] (주)태경피엔에스 저장됨
# [579/3837] (주)카카오엠 저장됨
# [580/3837] (주)썬코어 저장됨
# [581/3837] 키움 제4호 기업인수목적 주식회사 저장됨
# [582/3837] 도레이케미칼(주) 저장됨
# [583/3837] 디와이엘엔제이(주) 저장됨
# [584/3837] (주)엔에스브이 저장됨
# [585/3837] (주)심팩메탈 저장됨
# [586/3837] 씨제이이앤엠(주) 저장됨
# [587/3837] 이베스트기업인수목적3호(주) 저장됨
# [588/3837] 완리인터내셔널홀딩스 저장됨
# [589/3837] 하림홀딩스 저장됨
# [590/3837] 대덕GDS(주) 저장됨
# [591/3837] (주)위너지스 저장됨
# [592/3837] (주)스틸플라워 저장됨
# [593/3837] 그레이트리치과기유한공사 저장됨
# [594/3837] (주)트레이스 저장됨
# [595/3837] 케이비제9호기업인수목적(주) 저장됨
# [596/3837] 하이에이아이1호기업인수목적(주) 저장됨
# [597/3837] 넥스콘테크놀러지(주) 저장됨
# [598/3837] 덴소코리아주식회사 저장됨
# [599/3837] (주)프렉코 저장됨
# [600/3837] 차이나하오란리사이클링유한공사 저장됨
# [601/3837] (주)원익테라세미콘 저장됨
# [602/3837] 한국제4호기업인수목적(주) 저장됨
# [603/3837] (주)씨그널엔터테인먼트그룹 저장됨
# [604/3837] (주)극동자동화 저장됨
# [605/3837] 세원화성(주) 저장됨
# [606/3837] 미래에셋맵스 아시아퍼시픽 부동산공모 1호 투자회사 저장됨
# [607/3837] (주)세왕 저장됨
# [608/3837] (주)에스와이제이 저장됨
# [609/3837] (주)피엠디아카데미 저장됨
# [610/3837] 트러스와이제7호위탁관리부동산투자회사 저장됨
# [611/3837] (주)중앙바이오텍 저장됨
# [612/3837] (주)보진재 저장됨
# [613/3837] 로스웰인터내셔널유한회사 저장됨
# [614/3837] (주)제이에스피브이 저장됨
# [615/3837] 미래에셋대우기업인수목적1호(주) 저장됨
# [616/3837] 세종머티리얼즈(주) 저장됨
# [617/3837] 신한제3호기업인수목적 주식회사 저장됨
# [618/3837] 줌인터넷(주) 저장됨
# [619/3837] (주)인프라웨어테크놀러지 저장됨
# [620/3837] 한화에이스기업인수목적3호(주) 저장됨
# [621/3837] (주)씨앤케이인터내셔널 저장됨
# [622/3837] 주식회사 아이엘사이언스 저장됨
# [623/3837] (주)한컴지엠디 저장됨
# [624/3837] 아이이(주) 저장됨
# [625/3837] (주)에스티씨 라이프 저장됨
# [626/3837] 한화수성기업인수목적(주) 저장됨
# [627/3837] 현대정보기술(주) 저장됨
# [628/3837] 에스케이제3호기업인수목적(주) 저장됨
# [629/3837] (주)영현무역 저장됨
# [630/3837] 대신밸런스제4호기업인수목적(주) 저장됨
# [631/3837] (주)썬테크놀로지스 저장됨
# [632/3837] 동양텔레콤(주) 저장됨
# [633/3837] (주)유쎌 저장됨
# [634/3837] (주)에임하이글로벌 저장됨
# [635/3837] 한국제5호기업인수목적(주) 저장됨
# [636/3837] (주)해피드림 저장됨
# [637/3837] 동북아13호선박투자회사 저장됨
# [638/3837] 디케이씨(주) 저장됨
# [639/3837] (주)다린 저장됨
# [640/3837] 하이골드오션8호국제선박투자회사 저장됨
# [641/3837] (주)더스텔라 저장됨
# [642/3837] 차이나그레이트스타인터내셔널리미티드 저장됨
# [643/3837] (주)보루네오가구 저장됨
# [644/3837] (주)케미메디 저장됨
# [645/3837] (주)씨티네트웍스 저장됨
# [646/3837] (주)이푸른 저장됨
# [647/3837] SBI핀테크솔루션즈(주) 저장됨
# [648/3837] (주)미성포리테크 저장됨
# [649/3837] (주)파인넥스 저장됨
# [650/3837] 고려개발(주) 저장됨
# [651/3837] 아이비케이에스제7호기업인수목적주식회사 저장됨
# [652/3837] (주)티에스트릴리온 저장됨
# [653/3837] (주)드림티엔터테인먼트 저장됨
# [654/3837] 동북아12호선박투자회사 저장됨
# [655/3837] 맥쿼리한국인프라투융자회사 저장됨
# [656/3837] (주)인터파크 저장됨
# [657/3837] 신한제4호기업인수목적(주) 저장됨
# [658/3837] 차이나크리스탈신소재홀딩스 저장됨
# [659/3837] 코리아오토글라스(주) 저장됨
# [660/3837] 하나유비에스암바토비니켈해외자원개발2호 저장됨
# [661/3837] 하나유비에스암바토비니켈해외자원개발1호 저장됨
# [662/3837] 한국제7호기업인수목적 주식회사 저장됨
# [663/3837] (주)에스마크 저장됨
# [664/3837] (주)글로앤웰 저장됨
# [665/3837] 한화에이스기업인수목적4호(주) 저장됨
# [666/3837] 한국제6호기업인수목적 주식회사 저장됨
# [667/3837] (주)신텍 저장됨
# [668/3837] (주)리드 저장됨
# [669/3837] (주)위노바 저장됨
# [670/3837] (주)이매진아시아 저장됨
# [671/3837] 주식회사 한국아트라스비엑스 저장됨
# [672/3837] (주)동성화학 저장됨
# [673/3837] 주식회사 구스앤홈 저장됨
# [674/3837] 엔에이치기업인수목적13호 주식회사 저장됨
# [675/3837] 웅진에너지(주) 저장됨
# [676/3837] (주)홈센타홀딩스 저장됨
# [677/3837] (주)우진 저장됨
# [678/3837] 에스앤씨엔진그룹리미티드 저장됨
# [679/3837] 인화정공(주) 저장됨
# [680/3837] 대원산업(주) 저장됨
# [681/3837] (주)대동 저장됨
# [682/3837] 일화모직공업(주) 저장됨
# [683/3837] 키움제5호기업인수목적 주식회사 저장됨
# [684/3837] 삼화콘덴서공업(주) 저장됨
# [685/3837] (주)유니온 저장됨
# [686/3837] (주)우진플라임 저장됨
# [687/3837] (주)라임 저장됨
# [688/3837] (주)케이엔엔 저장됨
# [689/3837] 삼보판지(주) 저장됨
# [690/3837] (주)대성파인텍 저장됨
# [691/3837] 하이골드오션12호국제선박투자회사 저장됨
# [692/3837] (주)서연이화 저장됨
# [693/3837] (주)금빛 저장됨
# [694/3837] 대한방직(주) 저장됨
# [695/3837] (주)갤럭시아 에스엠 저장됨
# [696/3837] 대선조선(주) 저장됨
# [697/3837] (주)러셀 저장됨
# [698/3837] (주)유디피 저장됨
# [699/3837] 케이비제17호기업인수목적 주식회사 저장됨
# [700/3837] 하나머스트제6호기업인수목적(주) 저장됨
# [701/3837] 컬러레이홀딩스 저장됨
# [702/3837] 다이노나(주) 저장됨
# [703/3837] (주)미래테크놀로지 저장됨
# [704/3837] SBS미디어홀딩스(주) 저장됨
# [705/3837] (주)특수건설 저장됨
# [706/3837] 오가닉티코스메틱스홀딩스컴퍼니리미티드 저장됨
# [707/3837] (주)유수홀딩스 저장됨
# [708/3837] (주)코너스톤네트웍스 저장됨
# [709/3837] (주)지에스홈쇼핑 저장됨
# [710/3837] (주)세동 저장됨
# [711/3837] 에스지에이클라우드서비스 주식회사 저장됨
# [712/3837] (주)성광벤드 저장됨
# [713/3837] 이스트아시아홀딩스인베스트먼트리미티드 저장됨
# [714/3837] 유안타제4호기업인수목적 주식회사 저장됨
# [715/3837] 한화에스비아이기업인수목적 주식회사 저장됨
# [716/3837] 대원전선(주) 저장됨
# [717/3837] 이엘케이(주) 저장됨
# [718/3837] (주)다원시스 저장됨
# [719/3837] 케이비제18호기업인수목적 주식회사 저장됨
# [720/3837] 태림포장(주) 저장됨
# [721/3837] 지니언스(주) 저장됨
# [722/3837] 보성파워텍(주) 저장됨
# [723/3837] 이베스트이안기업인수목적1호 주식회사 저장됨
# [724/3837] 극동유화(주) 저장됨
# [725/3837] (주)루트락 저장됨
# [726/3837] 그린기술투자(주) 저장됨
# [727/3837] 에스케이에이씨피씨제4호기업인수목적(주) 저장됨
# [728/3837] 오렌지라이프생명보험(주) 저장됨
# [729/3837] (주)에스제이케이 저장됨
# [730/3837] (주)세코닉스 저장됨
# [731/3837] (주)티로보틱스 저장됨
# [732/3837] 주식회사 넥스피안 저장됨
# [733/3837] (주)보광산업 저장됨
# [734/3837] (주)엘피케이로보틱스 저장됨
# [735/3837] 일진홀딩스(주) 저장됨
# [736/3837] (주)하나기술 저장됨
# [737/3837] 제일파마홀딩스(주) 저장됨
# [738/3837] (주)플래티어 저장됨
# [739/3837] 조광피혁(주) 저장됨
# [740/3837] (주)디알젬 저장됨
# [741/3837] 팅크웨어(주) 저장됨
# [742/3837] (주)레이크머티리얼즈 저장됨
# [743/3837] (주)인텔리안테크놀로지스 저장됨
# [744/3837] (주)라파스 저장됨
# [745/3837] 아이디피(주) 저장됨
# [746/3837] 주식회사 삼영에스앤씨 저장됨
# [747/3837] (주)에스피컴텍 저장됨
# [748/3837] (주)진매트릭스 저장됨
# [749/3837] (주)씨앤에스자산관리 저장됨
# [750/3837] (주)엠로 저장됨
# [751/3837] (주)액트로 저장됨
# [752/3837] (주)테스 저장됨
# [753/3837] (주)힘스 저장됨
# [754/3837] 잘만테크(주) 저장됨
# [755/3837] 모바일어플라이언스 주식회사 저장됨
# [756/3837] (주)미래컴퍼니 저장됨
# [757/3837] 오토앤(주) 저장됨
# [758/3837] 동일금속(주) 저장됨
# [759/3837] (주)아바코 저장됨
# [760/3837] (주)큐에스아이 저장됨
# [761/3837] 프리시젼바이오(주) 저장됨
# [762/3837] (주)영림원소프트랩 저장됨
# [763/3837] 주식회사 원준 저장됨
# [764/3837] (주)파크시스템스 저장됨
# [765/3837] 미원스페셜티케미칼(주) 저장됨
# [766/3837] (주)코스메카코리아 저장됨
# [767/3837] 럭스피아(주) 저장됨
# [768/3837] (주)아바텍 저장됨
# [769/3837] 위월드(주) 저장됨
# [770/3837] (주)유니크 저장됨
# [771/3837] 에이비온(주) 저장됨
# [772/3837] (주)오비고 저장됨
# [773/3837] (주)씨디네트웍스 저장됨
# [774/3837] 한일화학공업(주) 저장됨
# [775/3837] (주)디에스케이 저장됨
# [776/3837] (주)화승코퍼레이션 저장됨
# [777/3837] (주)금오하이텍 저장됨
# [778/3837] (주)동양건설산업 저장됨
# [779/3837] (주)피엔에스커튼월 저장됨
# [780/3837] (주)제노텍 저장됨
# [781/3837] (주)애드바이오텍 저장됨
# [782/3837] (주)제네시스디벨롭먼트홀딩스 저장됨
# [783/3837] 대주코레스(주) 저장됨
# [784/3837] (주)로보티즈 저장됨
# [785/3837] (주)범양사 저장됨
# [786/3837] (주)부산도시가스 저장됨
# [787/3837] (주)티피씨메카트로닉스 저장됨
# [788/3837] (주)우리기술 저장됨
# [789/3837] (주)뷰웍스 저장됨
# [790/3837] 주식회사 아이티아이즈 저장됨
# [791/3837] (주)원림 저장됨
# [792/3837] 주식회사 캐리소프트 저장됨
# [793/3837] 한일건설(주) 저장됨
# [794/3837] 케이디지엠텍(주) 저장됨
# [795/3837] 케이씨더블류 (주) 저장됨
# [796/3837] 주식회사 에스제이켐 저장됨
# [797/3837] 에이자기관리부동산투자회사(주) 저장됨
# [798/3837] (주)프로이천 저장됨
# [799/3837] 율촌화학(주) 저장됨
# [800/3837] (주)티에이치엔 저장됨
# [801/3837] 삼륭물산(주) 저장됨
# [802/3837] 한국철강(주) 저장됨
# [803/3837] 카페24(주) 저장됨
# [804/3837] 아이케이세미콘(주) 저장됨
# [805/3837] 코리아에셋투자증권(주) 저장됨
# [806/3837] (주)웰크론 저장됨
# [807/3837] (주)셀리드 저장됨
# [808/3837] (주)파마리서치바이오 저장됨
# [809/3837] 주식회사 알비더블유 저장됨
# [810/3837] 주식회사 무진메디 저장됨
# [811/3837] 주식회사 퀀타매트릭스 저장됨
# [812/3837] (주)엔지켐생명과학 저장됨
# [813/3837] 주식회사 이지스밸류플러스위탁관리부동산투자회사 저장됨
# [814/3837] 동원금속(주) 저장됨
# [815/3837] (주)아스플로 저장됨
# [816/3837] 쿠쿠홀딩스(주) 저장됨
# [817/3837] 국제엘렉트릭코리아(주) 저장됨
# [818/3837] (주)엔스퍼트 저장됨
# [819/3837] 성지건설(주) 저장됨
# [820/3837] 풍원정밀(주) 저장됨
# [821/3837] (주)안트로젠 저장됨
# [822/3837] (주)씨엠에스에듀 저장됨
# [823/3837] (주)한국전자홀딩스 저장됨
# [824/3837] 하나금융14호기업인수목적 주식회사 저장됨
# [825/3837] 에스케이제5호기업인수목적 주식회사 저장됨
# [826/3837] 에스케이제6호기업인수목적 주식회사 저장됨
# [827/3837] (주)마이크로디지탈 저장됨
# [828/3837] 효성오앤비(주) 저장됨
# [829/3837] 전진바이오팜(주) 저장됨
# [830/3837] (주)제이엠멀티 저장됨
# [831/3837] (주)금비 저장됨
# [832/3837] (주)셰프라인 저장됨
# [833/3837] 상상인이안제2호기업인수목적 주식회사 저장됨
# [834/3837] SNT에너지(주) 저장됨
# [835/3837] (주)인터엠 저장됨
# [836/3837] 넥슨지티(주) 저장됨
# [837/3837] 자안바이오 주식회사 저장됨
# [838/3837] (주)나인테크 저장됨
# [839/3837] 주식회사 에스앤케이 저장됨
# [840/3837] 이삭엔지니어링(주) 저장됨
# [841/3837] 신성통상(주) 저장됨
# [842/3837] (주)배럴 저장됨
# [843/3837] (주)이엔에프테크놀로지 저장됨
# [844/3837] (주)에스알바이오텍 저장됨
# [845/3837] 바디텍메드(주) 저장됨
# [846/3837] (주)스포츠서울 저장됨
# [847/3837] 하이즈항공(주) 저장됨
# [848/3837] 에스브이인베스트먼트 주식회사 저장됨
# [849/3837] 주식회사 화승알앤에이 저장됨
# [850/3837] 주식회사 고바이오랩 저장됨
# [851/3837] (주)남선알미늄 저장됨
# [852/3837] (주)한프 저장됨
# [853/3837] 비지스틸(주) 저장됨
# [854/3837] (주)세영디앤씨 저장됨
# [855/3837] (주)비엘사이언스 저장됨
# [856/3837] 주식회사 이십일스토어 저장됨
# [857/3837] (주)엔바이오니아 저장됨
# [858/3837] (주)제이알글로벌위탁관리부동산투자회사 저장됨
# [859/3837] 에이치비솔루션(주) 저장됨
# [860/3837] 대영포장(주) 저장됨
# [861/3837] (주)황금에스티 저장됨
# [862/3837] 앱클론(주) 저장됨
# [863/3837] 주식회사 티티씨디펜스 저장됨
# [864/3837] 남화산업(주) 저장됨
# [865/3837] (주)세원정공 저장됨
# [866/3837] (주)엠앤씨생명과학 저장됨
# [867/3837] 비씨엔씨(주) 저장됨
# [868/3837] 케이비제19호기업인수목적 주식회사 저장됨
# [869/3837] 주식회사 미래오토스 저장됨
# [870/3837] 한화생명보험(주) 저장됨
# [871/3837] (주)양지사 저장됨
# [872/3837] (주)케이씨티시 저장됨
# [873/3837] (주)인터코스 저장됨
# [874/3837] 만호제강(주) 저장됨
# [875/3837] (주)수프로 저장됨
# [876/3837] 주식회사 바이오에프디엔씨 저장됨
# [877/3837] 럭슬(주) 저장됨
# [878/3837] 주식회사 압타머사이언스 저장됨
# [879/3837] 쿠쿠홈시스 주식회사 저장됨
# [880/3837] (주)에이스토리 저장됨
# [881/3837] 테라셈(주) 저장됨
# [882/3837] 하이제5호기업인수목적 주식회사 저장됨
# [883/3837] 대동전자(주) 저장됨
# [884/3837] 하이골드오션3호선박투자회사 저장됨
# [885/3837] (주)서남 저장됨
# [886/3837] 주식회사 레이 저장됨
# [887/3837] (주)LS네트웍스 저장됨
# [888/3837] (주)방림 저장됨
# [889/3837] (주)자이언트스텝 저장됨
# [890/3837] (주)진로발효 저장됨
# [891/3837] (주)썬테크 저장됨
# [892/3837] (주)덱스터스튜디오 저장됨
# [893/3837] (주)국전약품 저장됨
# [894/3837] 신대양제지(주) 저장됨
# [895/3837] (주)미애부 저장됨
# [896/3837] (주)데이타솔루션 저장됨
# [897/3837] (주)에스앤에스텍 저장됨
# [898/3837] 삼영전자공업(주) 저장됨
# [899/3837] (주)전방 저장됨
# [900/3837] (주)지앤엘 저장됨
# [901/3837] 금강철강(주) 저장됨
# [902/3837] (주)전북은행 저장됨
# [903/3837] 이구산업(주) 저장됨
# [904/3837] (주)에치에프알 저장됨
# [905/3837] 태경케미컬 주식회사 저장됨
# [906/3837] (주)오디텍 저장됨
# [907/3837] (주)경방 저장됨
# [908/3837] (주)토니모리 저장됨
# [909/3837] 로체시스템즈(주) 저장됨
# [910/3837] (주)미래SCI 저장됨
# [911/3837] 한국화장품(주) 저장됨
# [912/3837] 한국컴퓨터(주) 저장됨
# [913/3837] (주)클래시스 저장됨
# [914/3837] 린드먼아시아인베스트먼트(주) 저장됨
# [915/3837] 유성기업(주) 저장됨
# [916/3837] (주)테라텍 저장됨
# [917/3837] (주)큐브엔터테인먼트 저장됨
# [918/3837] (주)오이솔루션 저장됨
# [919/3837] (주)넥스트엔터테인먼트월드 저장됨
# [920/3837] (주)보락 저장됨
# [921/3837] (주)디모아 저장됨
# [922/3837] (주)레이언스 저장됨
# [923/3837] (주)광주신세계 저장됨
# [924/3837] (주)혜인 저장됨
# [925/3837] (주)제일테크노스 저장됨
# [926/3837] (주)하이텍팜 저장됨
# [927/3837] 한전KPS(주) 저장됨
# [928/3837] (주)상보 저장됨
# [929/3837] (주)제이와이피엔터테인먼트 저장됨
# [930/3837] (주)나눔테크 저장됨
# [931/3837] KG케미칼(주) 저장됨
# [932/3837] (주)인포바인 저장됨
# [933/3837] (주)코리아써키트 저장됨
# [934/3837] 한일홀딩스(주) 저장됨
# [935/3837] 부산산업(주) 저장됨
# [936/3837] (주)서진오토모티브 저장됨
# [937/3837] 이화산업(주) 저장됨
# [938/3837] (주)유비쿼스홀딩스 저장됨
# [939/3837] 옵티시스(주) 저장됨
# [940/3837] (주)위지트 저장됨
# [941/3837] (주)슈프리마 저장됨
# [942/3837] (주)제이에스코퍼레이션 저장됨
# [943/3837] (주)지어소프트 저장됨
# [944/3837] (주)네오위즈홀딩스 저장됨
# [945/3837] SNT모티브(주) 저장됨
# [946/3837] 조광페인트(주) 저장됨
# [947/3837] (주)네오셈 저장됨
# [948/3837] (주)엘오티베큠 저장됨
# [949/3837] ㈜미래에셋맵스제1호위탁관리부동산투자회사 저장됨
# [950/3837] (주)신원 저장됨
# [951/3837] (주)풍강 저장됨
# [952/3837] 디케이락(주) 저장됨
# [953/3837] 고려신용정보(주) 저장됨
# [954/3837] (주)신화다이나믹스 저장됨
# [955/3837] (주)SH에너지화학 저장됨
# [956/3837] 대양전기공업(주) 저장됨
# [957/3837] 대봉엘에스(주) 저장됨
# [958/3837] 한국전기초자(주) 저장됨
# [959/3837] (주)플랜티넷 저장됨
# [960/3837] (주)이노메트리 저장됨
# [961/3837] (주)맥스로텍 저장됨
# [962/3837] (주)에스피지 저장됨
# [963/3837] (주)파버나인 저장됨
# [964/3837] (주)썸에이지 저장됨
# [965/3837] 아비코전자(주) 저장됨
# [966/3837] 지스마트글로벌(주) 저장됨
# [967/3837] (주)하림 저장됨
# [968/3837] 코리아에프티(주) 저장됨
# [969/3837] (주)현대에버다임 저장됨
# [970/3837] 디아이동일(주) 저장됨
# [971/3837] 바이오플러스 주식회사 저장됨
# [972/3837] 에프엔에스테크(주) 저장됨
# [973/3837] (주)모나미 저장됨
# [974/3837] 유진기업인수목적9호 주식회사 저장됨
# [975/3837] 일신방직(주) 저장됨
# [976/3837] (주)바이오빌 저장됨
# [977/3837] (주)대한과학 저장됨
# [978/3837] KB오토시스(주) 저장됨
# [979/3837] (주)그리티 저장됨
# [980/3837] 샘표(주) 저장됨
# [981/3837] 아세아제지(주) 저장됨
# [982/3837] (주)유진테크 저장됨
# [983/3837] (주)핑거스토리 저장됨
# [984/3837] 동일산업(주) 저장됨
# [985/3837] (주)와이비엠넷 저장됨
# [986/3837] (주)인터플렉스 저장됨
# [987/3837] (주)천일고속 저장됨
# [988/3837] 에이팸(주) 저장됨
# [989/3837] (주)예스티 저장됨
# [990/3837] (주)스튜디오 산타클로스 엔터테인먼트 저장됨
# [991/3837] (주)크라운해태홀딩스 저장됨
# [992/3837] (주)에스에이엠티 저장됨
# [993/3837] (주)인지소프트 저장됨
# [994/3837] (주)뉴프렉스 저장됨
# [995/3837] (주)에프에스티 저장됨
# [996/3837] (주)서한 저장됨
# [997/3837] (주)웹스 저장됨
# [998/3837] (주)아이티엠반도체 저장됨
# [999/3837] (주)세화피앤씨 저장됨
# [1000/3837] (주)서부티엔디 저장됨
# [1001/3837] (주)일지테크 저장됨
# [1002/3837] (주)프로텍 저장됨
# [1003/3837] (주)에프엔씨엔터테인먼트 저장됨
# [1004/3837] (주)비아트론 저장됨
# [1005/3837] (주)노브메타파마 저장됨
# [1006/3837] (주)이엠네트웍스 저장됨
# [1007/3837] (주)차백신연구소 저장됨
# [1008/3837] 엔에이치기업인수목적27호(주) 저장됨
# [1009/3837] 주식회사 진에어 저장됨
# [1010/3837] (주)한솔홈데코 저장됨
# [1011/3837] (주)로보로보 저장됨
# [1012/3837] 주식회사 필옵틱스 저장됨
# [1013/3837] 대정화금(주) 저장됨
# [1014/3837] (주)슈프리마에이치큐 저장됨
# [1015/3837] 주식회사 하스코 저장됨
# [1016/3837] (주)E1 저장됨
# [1017/3837] (주)메리츠금융지주 저장됨
# [1018/3837] 엔에이치기업인수목적26호 저장됨
# [1019/3837] SK텔레콤(주) 저장됨
# [1020/3837] 주식회사 엘엑스홀딩스 저장됨
# [1021/3837] (주)STX 저장됨
# [1022/3837] (주)한국큐빅 저장됨
# [1023/3837] (주)한국카본 저장됨
# [1024/3837] 신흥에스이씨(주) 저장됨
# [1025/3837] 진원생명과학(주) 저장됨
# [1026/3837] (주)엘에이티 저장됨
# [1027/3837] (주)LS 저장됨
# [1028/3837] (주)케이씨산업 저장됨
# [1029/3837] (주)케이에이치바텍 저장됨
# [1030/3837] (주)천보 저장됨
# [1031/3837] 경남스틸(주) 저장됨
# [1032/3837] (주)한국화장품제조 저장됨
# [1033/3837] 미래에셋벤처투자 주식회사 저장됨
# [1034/3837] 우원개발(주) 저장됨
# [1035/3837] 대상홀딩스(주) 저장됨
# [1036/3837] (주)이글벳 저장됨
# [1037/3837] (주)케이피티유 저장됨
# [1038/3837] (주)아이윈 저장됨
# [1039/3837] (주)코람코더원위탁관리부동산투자회사 저장됨
# [1040/3837] 신원종합개발(주) 저장됨
# [1041/3837] 씨유테크 주식회사 저장됨
# [1042/3837] (주)큐라클 저장됨
# [1043/3837] 아이비케이에스제13호기업인수목적 주식회사 저장됨
# [1044/3837] (주)예선테크 저장됨
# [1045/3837] (주)원티드랩 저장됨
# [1046/3837] 제이엠티(주) 저장됨
# [1047/3837] 큐캐피탈파트너스(주) 저장됨
# [1048/3837] (주)웹젠 저장됨
# [1049/3837] (주)시노펙스 저장됨
# [1050/3837] 주식회사 비스토스 저장됨
# [1051/3837] (주)티쓰리엔터테인먼트 저장됨
# [1052/3837] 교보13호기업인수목적 주식회사 저장됨
# [1053/3837] (주)성도이엔지 저장됨
# [1054/3837] (주)에스티아이 저장됨
# [1055/3837] 주식회사 카카오페이 저장됨
# [1056/3837] (주)한국씨티은행 저장됨
# [1057/3837] 하이트진로(주) 저장됨
# [1058/3837] (주)자비스 저장됨
# [1059/3837] 케이엠제약(주) 저장됨
# [1060/3837] (주)마이크로엔엑스 저장됨
# [1061/3837] 서암기계공업(주) 저장됨
# [1062/3837] (주)대구백화점 저장됨
# [1063/3837] 알에스오토메이션(주) 저장됨
# [1064/3837] 현대에이치티(주) 저장됨
# [1065/3837] 퍼스텍(주) 저장됨
# [1066/3837] (주)오픈베이스 저장됨
# [1067/3837] 송원산업(주) 저장됨
# [1068/3837] (주)멕아이씨에스 저장됨
# [1069/3837] 주식회사 카카오뱅크 저장됨
# [1070/3837] (주)케이씨에스 저장됨
# [1071/3837] 삼화페인트공업(주) 저장됨
# [1072/3837] (주)삼일 저장됨
# [1073/3837] 인포뱅크(주) 저장됨
# [1074/3837] (주)빅솔론 저장됨
# [1075/3837] 신영해피투모로우제6호기업인수목적 주식회사 저장됨
# [1076/3837] (주)광주은행 저장됨
# [1077/3837] (주)에코솔루션 저장됨
# [1078/3837] 케이비제20호기업인수목적 주식회사 저장됨
# [1079/3837] (주)조비 저장됨
# [1080/3837] 주식회사 핌스 저장됨
# [1081/3837] (주)데이터스트림즈 저장됨
# [1082/3837] 부산주공(주) 저장됨
# [1083/3837] 한국단자공업(주) 저장됨
# [1084/3837] 엔젯 주식회사 저장됨
# [1085/3837] (주)아이퀘스트 저장됨
# [1086/3837] (주)코셋 저장됨
# [1087/3837] (주)파이버프로 저장됨
# [1088/3837] 주식회사 제노코 저장됨
# [1089/3837] (주)자유투어 저장됨
# [1090/3837] 와이엠씨(주) 저장됨
# [1091/3837] (주)브이씨 저장됨
# [1092/3837] (주)피델릭스 저장됨
# [1093/3837] 주식회사 파워넷 저장됨
# [1094/3837] 두산밥캣 주식회사 저장됨
# [1095/3837] 지에이치신소재(주) 저장됨
# [1096/3837] 에스케이위탁관리부동산투자회사 주식회사 저장됨
# [1097/3837] 주식회사 디티앤씨알오 저장됨
# [1098/3837] 에스텍(주) 저장됨
# [1099/3837] (주)동양에스텍 저장됨
# [1100/3837] (주)아이컴포넌트 저장됨
# [1101/3837] (주)휴맥스홀딩스 저장됨
# [1102/3837] (주)쎄니트 저장됨
# [1103/3837] (주)성원 저장됨
# [1104/3837] (주)오리온홀딩스 저장됨
# [1105/3837] 유안타제7호기업인수목적 주식회사 저장됨
# [1106/3837] (주)대성하이텍 저장됨
# [1107/3837] (주)노루홀딩스 저장됨
# [1108/3837] 태양금속공업(주) 저장됨
# [1109/3837] 성신양회(주) 저장됨
# [1110/3837] 주식회사 에스제이그룹 저장됨
# [1111/3837] 이에스알켄달스퀘어위탁관리부동산투자회사주식회사 저장됨
# [1112/3837] 주식회사 플레이디 저장됨
# [1113/3837] 현대위아(주) 저장됨
# [1114/3837] (주)케이피에프 저장됨
# [1115/3837] (주)엔터미디어 저장됨
# [1116/3837] (주)진성티이씨 저장됨
# [1117/3837] 영화테크(주) 저장됨
# [1118/3837] 헝셩그룹유한회사 저장됨
# [1119/3837] (주) 탈로스 저장됨
# [1120/3837] (주)에이치비테크놀러지 저장됨
# [1121/3837] (주)우진아이엔에스 저장됨
# [1122/3837] (주)한농화성 저장됨
# [1123/3837] (주)덕성 저장됨
# [1124/3837] (주)상아프론테크 저장됨
# [1125/3837] (주)가온칩스 저장됨
# [1126/3837] (주)모보 저장됨
# [1127/3837] (주)세진중공업 저장됨
# [1128/3837] (주)신한 저장됨
# [1129/3837] 램테크놀러지(주) 저장됨
# [1130/3837] (주)서린바이오사이언스 저장됨
# [1131/3837] 아세아시멘트(주) 저장됨
# [1132/3837] (주)아이엠텍 저장됨
# [1133/3837] (주)호텔신라 저장됨
# [1134/3837] 한국정보통신(주) 저장됨
# [1135/3837] (주)선익시스템 저장됨
# [1136/3837] 한국정밀기계(주) 저장됨
# [1137/3837] (주)핸디소프트 저장됨
# [1138/3837] (주)금화피에스시 저장됨
# [1139/3837] (주)풍산 저장됨
# [1140/3837] 삼성전기(주) 저장됨
# [1141/3837] 하이트진로홀딩스(주) 저장됨
# [1142/3837] (주)이노션 저장됨
# [1143/3837] (주)파인엠텍 저장됨
# [1144/3837] (주)제이엘케이 저장됨
# [1145/3837] 에이치디씨영창 주식회사 저장됨
# [1146/3837] (주)LF 저장됨
# [1147/3837] (주)SG세계물산 저장됨
# [1148/3837] 유니퀘스트(주) 저장됨
# [1149/3837] 동아화성(주) 저장됨
# [1150/3837] 유엔젤(주) 저장됨
# [1151/3837] (주)경동도시가스 저장됨
# [1152/3837] 경인전자(주) 저장됨
# [1153/3837] (주)에스씨디 저장됨
# [1154/3837] (주)나노엔텍 저장됨
# [1155/3837] (주)정상제이엘에스 저장됨
# [1156/3837] (주)이엠비 저장됨
# [1157/3837] 미스터블루(주) 저장됨
# [1158/3837] (주)테크트랜스 저장됨
# [1159/3837] (주)이노진 저장됨
# [1160/3837] 갤럭시아머니트리(주) 저장됨
# [1161/3837] (주)부-스타 저장됨
# [1162/3837] (주)케이에스피 저장됨
# [1163/3837] 피에이치에이(주) 저장됨
# [1164/3837] (주)경동인베스트 저장됨
# [1165/3837] (주)블루탑 저장됨
# [1166/3837] (주)아가방앤컴퍼니 저장됨
# [1167/3837] 와이더블유 주식회사 저장됨
# [1168/3837] (주)파워로직스 저장됨
# [1169/3837] 성우테크론(주) 저장됨
# [1170/3837] (주)국순당 저장됨
# [1171/3837] (주)비지에프 저장됨
# [1172/3837] (주)삼일기업공사 저장됨
# [1173/3837] 태원물산(주) 저장됨
# [1174/3837] (주)네오티스 저장됨
# [1175/3837] SK가스(주) 저장됨
# [1176/3837] (주)더네이쳐홀딩스 저장됨
# [1177/3837] 한국주강(주) 저장됨
# [1178/3837] (주)와이솔 저장됨
# [1179/3837] (주)디아이씨 저장됨
# [1180/3837] (주)서원인텍 저장됨
# [1181/3837] 효성티앤씨(주) 저장됨
# [1182/3837] (주)엘지헬로비전 저장됨
# [1183/3837] 대덕전자(주) 저장됨
# [1184/3837] 신영해피투모로우제8호기업인수목적 주식회사 저장됨
# [1185/3837] (주)에이엔피 저장됨
# [1186/3837] 아세아(주) 저장됨
# [1187/3837] 엔에이치엔(주) 저장됨
# [1188/3837] 성우전자(주) 저장됨
# [1189/3837] (주)한네트 저장됨
# [1190/3837] 대원화성(주) 저장됨
# [1191/3837] (주)안랩 저장됨
# [1192/3837] 주식회사 유엑스엔 저장됨
# [1193/3837] (주)코메론 저장됨
# [1194/3837] 현대로템(주) 저장됨
# [1195/3837] 경남에너지(주) 저장됨
# [1196/3837] (주)폴루스바이오팜 저장됨
# [1197/3837] 금강공업(주) 저장됨
# [1198/3837] 대신증권(주) 저장됨
# [1199/3837] 신영해피투모로우제9호기업인수목적 주식회사 저장됨
# [1200/3837] 효성화학(주) 저장됨
# [1201/3837] (주)원익머트리얼즈 저장됨
# [1202/3837] DB손해보험(주) 저장됨
# [1203/3837] (주)주노콜렉션 저장됨
# [1204/3837] 인탑스(주) 저장됨
# [1205/3837] (주)벽산 저장됨
# [1206/3837] 패션플랫폼(주) 저장됨
# [1207/3837] (주)신세계톰보이 저장됨
# [1208/3837] 주식회사 라닉스 저장됨
# [1209/3837] (주)아이앤씨테크놀로지 저장됨
# [1210/3837] (주)메지온 저장됨
# [1211/3837] 한국월드와이드베트남부동산개발특별자산1호투자회사 저장됨
# [1212/3837] 한국콜마(주) 저장됨
# [1213/3837] 우수AMS(주) 저장됨
# [1214/3837] (주)원익 저장됨
# [1215/3837] (주)우리로 저장됨
# [1216/3837] 우리산업(주) 저장됨
# [1217/3837] 롯데관광개발(주) 저장됨
# [1218/3837] (주)하츠 저장됨
# [1219/3837] (주)아나패스 저장됨
# [1220/3837] 삼화전기(주) 저장됨
# [1221/3837] 현대코퍼레이션(주) 저장됨
# [1222/3837] (주)포메탈 저장됨
# [1223/3837] (주)지에프씨생명과학 저장됨
# [1224/3837] 하나금융15호기업인수목적 주식회사 저장됨
# [1225/3837] (주)웨이브일렉트로닉스 저장됨
# [1226/3837] (주)한독크린텍 저장됨
# [1227/3837] (주)씨엔플러스 저장됨
# [1228/3837] (주)켐온 저장됨
# [1229/3837] (주)코리아센터 저장됨
# [1230/3837] (주)씨앤에스링크 저장됨
# [1231/3837] (주)더존비즈온 저장됨
# [1232/3837] (주)이엘피 저장됨
# [1233/3837] 주식회사 스튜디오미르 저장됨
# [1234/3837] 주식회사 박셀바이오 저장됨
# [1235/3837] (주)이노와이어리스 저장됨
# [1236/3837] (주)이엠넷 저장됨
# [1237/3837] (주)현대리바트 저장됨
# [1238/3837] (주)링크제니시스 저장됨
# [1239/3837] 오픈엣지테크놀로지 주식회사 저장됨
# [1240/3837] (주)한섬 저장됨
# [1241/3837] 금호석유화학(주) 저장됨
# [1242/3837] 위즈코프(주) 저장됨
# [1243/3837] (주)육일씨엔에쓰 저장됨
# [1244/3837] CS 홀딩스(주) 저장됨
# [1245/3837] 유아이엘(주) 저장됨
# [1246/3837] 흥구석유(주) 저장됨
# [1247/3837] (주)이랜시스 저장됨
# [1248/3837] (주)피앤텔 저장됨
# [1249/3837] (주)대창스틸 저장됨
# [1250/3837] (주)제닉 저장됨
# [1251/3837] 부국철강(주) 저장됨
# [1252/3837] (주)에스디시스템 저장됨
# [1253/3837] 그린케미칼(주) 저장됨
# [1254/3837] 풍림산업(주) 저장됨
# [1255/3837] (주)알에프텍 저장됨
# [1256/3837] (주)미코 저장됨
# [1257/3837] 한국가스공사(주) 저장됨
# [1258/3837] 더블유씨피(주) 저장됨
# [1259/3837] (주)우성아이비 저장됨
# [1260/3837] 디와이씨(주) 저장됨
# [1261/3837] (주)유티아이 저장됨
# [1262/3837] (주)비츠로셀 저장됨
# [1263/3837] (주)파인디앤씨 저장됨
# [1264/3837] (주)디와이홀딩스 저장됨
# [1265/3837] 삼목에스폼(주) 저장됨
# [1266/3837] (주)서흥 저장됨
# [1267/3837] 팬오션(주) 저장됨
# [1268/3837] 메가스터디(주) 저장됨
# [1269/3837] (주)비비안 저장됨
# [1270/3837] (주) 유진로봇 저장됨
# [1271/3837] 이화공영(주) 저장됨
# [1272/3837] (주)에이치시티 저장됨
# [1273/3837] (주)솔본 저장됨
# [1274/3837] DSR(주) 저장됨
# [1275/3837] 미래나노텍(주) 저장됨
# [1276/3837] (주)네온테크 저장됨
# [1277/3837] 디와이파워(주) 저장됨
# [1278/3837] 두함지개발 주식회사 저장됨
# [1279/3837] 휴림로봇(주) 저장됨
# [1280/3837] (주)디지털대성 저장됨
# [1281/3837] (주)엠소닉 저장됨
# [1282/3837] (주)원익큐브 저장됨
# [1283/3837] 케어룸의료산업 주식회사 저장됨
# [1284/3837] (주) DB Inc. 저장됨
# [1285/3837] 해원에스티(주) 저장됨
# [1286/3837] (주)퍼시스 저장됨
# [1287/3837] 옴니시스템(주) 저장됨
# [1288/3837] 아이텍주식회사 저장됨
# [1289/3837] (주)액토즈소프트 저장됨
# [1290/3837] (주)네오펙트 저장됨
# [1291/3837] 에이펙스인텍(주) 저장됨
# [1292/3837] (주)레인보우로보틱스 저장됨
# [1293/3837] 펌텍코리아 주식회사 저장됨
# [1294/3837] (주)바이오노트 저장됨
# [1295/3837] 주식회사 지디 저장됨
# [1296/3837] 신송홀딩스(주) 저장됨
# [1297/3837] 이베스트기업인수목적5호 주식회사 저장됨
# [1298/3837] 풍국주정공업(주) 저장됨
# [1299/3837] (주)덕산테코피아 저장됨
# [1300/3837] 성창기업지주(주) 저장됨
# [1301/3837] (주)심팩인더스트리 저장됨
# [1302/3837] 유니온머티리얼(주) 저장됨
# [1303/3837] 유진투자증권(주) 저장됨
# [1304/3837] 주식회사 실리콘투 저장됨
# [1305/3837] 인터지스(주) 저장됨
# [1306/3837] 제룡전기(주) 저장됨
# [1307/3837] (주)이엠티 저장됨
# [1308/3837] 한국지역난방공사 저장됨
# [1309/3837] 삼천리(주) 저장됨
# [1310/3837] 대창단조(주) 저장됨
# [1311/3837] (주)선광 저장됨
# [1312/3837] (주)퓨전 저장됨
# [1313/3837] (주)큐리언트 저장됨
# [1314/3837] (주)브리지텍 저장됨
# [1315/3837] (주)나노신소재 저장됨
# [1316/3837] (주)씨엔알리서치 저장됨
# [1317/3837] 한국내화(주) 저장됨
# [1318/3837] (주)네오위즈 저장됨
# [1319/3837] 디젠스(주) 저장됨
# [1320/3837] 코위버(주) 저장됨
# [1321/3837] (주)피엔풍년 저장됨
# [1322/3837] (주)얼라인드제네틱스 저장됨
# [1323/3837] 일레덱스홀딩스(주) 저장됨
# [1324/3837] 삼화전자공업(주) 저장됨
# [1325/3837] (주)오리엔탈정공 저장됨
# [1326/3837] (주)다함이텍 저장됨
# [1327/3837] (주)아진엑스텍 저장됨
# [1328/3837] (주) 승일 저장됨
# [1329/3837] 피에스케이 주식회사 저장됨
# [1330/3837] (주)SNT홀딩스 저장됨
# [1331/3837] 대한유화(주) 저장됨
# [1332/3837] 티이엠씨 주식회사 저장됨
# [1333/3837] (주)칩스앤미디어 저장됨
# [1334/3837] (주)질경이 저장됨
# [1335/3837] (주)이글루코퍼레이션 저장됨
# [1336/3837] (주)아이디스 저장됨
# [1337/3837] 금호전기(주) 저장됨
# [1338/3837] (주)다산네트웍스 저장됨
# [1339/3837] (주)윌비스 저장됨
# [1340/3837] (주)인터로조 저장됨
# [1341/3837] (주)진바이오텍 저장됨
# [1342/3837] (주)쿠첸 저장됨
# [1343/3837] (주)무학 저장됨
# [1344/3837] (주)아이디스홀딩스 저장됨
# [1345/3837] (주)유한양행 저장됨
# [1346/3837] (주)엔이능률 저장됨
# [1347/3837] (주)아즈텍더블유비이 저장됨
# [1348/3837] (주)신화콘텍 저장됨
# [1349/3837] (주)한국스탠다드차타드은행 저장됨
# [1350/3837] 성문전자(주) 저장됨
# [1351/3837] 주식회사 엠게임 저장됨
# [1352/3837] (주)알테오젠 저장됨
# [1353/3837] (주)엘리비젼 저장됨
# [1354/3837] 엘티씨(주) 저장됨
# [1355/3837] (주)코텍 저장됨
# [1356/3837] (주)한미글로벌건축사사무소 저장됨
# [1357/3837] (주)크린앤사이언스 저장됨
# [1358/3837] (주)안지오랩 저장됨
# [1359/3837] (주)우신시스템 저장됨
# [1360/3837] (주)코맥스 저장됨
# [1361/3837] (주)지앤이헬스케어 저장됨
# [1362/3837] (주)아난티 저장됨
# [1363/3837] (주)노랑풍선 저장됨
# [1364/3837] ㈜에스티오 저장됨
# [1365/3837] (주)JB금융지주 저장됨
# [1366/3837] (주)휴엠앤씨 저장됨
# [1367/3837] (주)하이딥 저장됨
# [1368/3837] 대신밸런스제14호기업인수목적(주) 저장됨
# [1369/3837] (주)에스앤더블류 저장됨
# [1370/3837] (주)에스티큐브 저장됨
# [1371/3837] (주)디아이 저장됨
# [1372/3837] (주)에이치케이 저장됨
# [1373/3837] (주)코이즈 저장됨
# [1374/3837] (주)동방아그로 저장됨
# [1375/3837] (주)소리바다 저장됨
# [1376/3837] (주)세보엠이씨 저장됨
# [1377/3837] (주)케이옥션 저장됨
# [1378/3837] 한국자산신탁(주) 저장됨
# [1379/3837] (주)GS 저장됨
# [1380/3837] 교보증권(주) 저장됨
# [1381/3837] (주)현대바이오랜드 저장됨
# [1382/3837] (주)파인디지털 저장됨
# [1383/3837] (주)링네트 저장됨
# [1384/3837] (주)유니트론텍 저장됨
# [1385/3837] (주)디지아이 저장됨
# [1386/3837] (주)태양 저장됨
# [1387/3837] 대주전자재료(주) 저장됨
# [1388/3837] 대원미디어(주) 저장됨
# [1389/3837] 제일연마공업(주) 저장됨
# [1390/3837] (주)바이오프로테크 저장됨
# [1391/3837] 재영솔루텍(주) 저장됨
# [1392/3837] (주)아이씨디 저장됨
# [1393/3837] 에스지이(주) 저장됨
# [1394/3837] 주식회사 엔에이치프라임위탁관리부동산투자회사 저장됨
# [1395/3837] 디씨엠(주) 저장됨
# [1396/3837] (주)대륙제관 저장됨
# [1397/3837] 한세예스24홀딩스(주) 저장됨
# [1398/3837] (주)유에스티 저장됨
# [1399/3837] (주)바이오톡스텍 저장됨
# [1400/3837] (주)중앙에너비스 저장됨
# [1401/3837] 감성코퍼레이션(주) 저장됨
# [1402/3837] (주)티엘엔지니어링 저장됨
# [1403/3837] (주)화신 저장됨
# [1404/3837] (주)제이스텍 저장됨
# [1405/3837] 툴코리아(주) 저장됨
# [1406/3837] 동양철관(주) 저장됨
# [1407/3837] 현진소재(주) 저장됨
# [1408/3837] (주)하이스틸 저장됨
# [1409/3837] (주)드림씨아이에스 저장됨
# [1410/3837] 주식회사 덴티스 저장됨
# [1411/3837] 주식회사 오션스톤 저장됨
# [1412/3837] 주식회사 켈스 저장됨
# [1413/3837] (주)이오테크닉스 저장됨
# [1414/3837] (주)제주항공 저장됨
# [1415/3837] 주식회사 바이오다인 저장됨
# [1416/3837] (주)세진티에스 저장됨
# [1417/3837] (주)LG 저장됨
# [1418/3837] (주)제낙스 저장됨
# [1419/3837] 주식회사 에스지피엠 저장됨
# [1420/3837] 한국투자금융지주(주) 저장됨
# [1421/3837] 우리기술투자(주) 저장됨
# [1422/3837] (주)대한항공 저장됨
# [1423/3837] (주)동남합성 저장됨
# [1424/3837] 주식회사 석경에이티 저장됨
# [1425/3837] 한일단조공업(주) 저장됨
# [1426/3837] (주)파루 저장됨
# [1427/3837] 리노공업(주) 저장됨
# [1428/3837] 삼보모터스(주) 저장됨
# [1429/3837] 비나텍주식회사 저장됨
# [1430/3837] 우리엔터프라이즈(주) 저장됨
# [1431/3837] 코웨이(주) 저장됨
# [1432/3837] (주)하나투어 저장됨
# [1433/3837] (주)엑사이엔씨 저장됨
# [1434/3837] 코스모신소재(주) 저장됨
# [1435/3837] (주)한글과컴퓨터 저장됨
# [1436/3837] (주)쎌바이오텍 저장됨
# [1437/3837] (주)와이지-원 저장됨
# [1438/3837] (주)파세코 저장됨
# [1439/3837] (주)기산텔레콤 저장됨
# [1440/3837] (주)신테카바이오 저장됨
# [1441/3837] (주)LG화학 저장됨
# [1442/3837] (주)서울옥션 저장됨
# [1443/3837] 엔시트론(주) 저장됨
# [1444/3837] 주식회사 미래에셋글로벌위탁관리부동산투자회사 저장됨
# [1445/3837] (주)디알텍 저장됨
# [1446/3837] (주)매직마이크로 저장됨
# [1447/3837] CJ(주) 저장됨
# [1448/3837] 우리산업홀딩스(주) 저장됨
# [1449/3837] (주)에이원알폼 저장됨
# [1450/3837] 엘컴텍(주) 저장됨
# [1451/3837] (주)바이오스마트 저장됨
# [1452/3837] (주)상상인 저장됨
# [1453/3837] (주)에쎈테크 저장됨
# [1454/3837] (주)에이티넘인베스트먼트 저장됨
# [1455/3837] 기아(주) 저장됨
# [1456/3837] 코오롱글로벌(주) 저장됨
# [1457/3837] (주)SIMPAC 저장됨
# [1458/3837] 롯데지주(주) 저장됨
# [1459/3837] (주)일진파워 저장됨
# [1460/3837] (주)레드캡투어 저장됨
# [1461/3837] 현대엘리베이터(주) 저장됨
# [1462/3837] (주)텔레칩스 저장됨
# [1463/3837] 주식회사 폭스소프트 저장됨
# [1464/3837] (주)디지틀조선일보 저장됨
# [1465/3837] (주)헥토이노베이션 저장됨
# [1466/3837] (주)와이지플러스 저장됨
# [1467/3837] (주)티에프이 저장됨
# [1468/3837] (주)신도기연 저장됨
# [1469/3837] (주)하림지주 저장됨
# [1470/3837] 삼지전자(주) 저장됨
# [1471/3837] (주)에스에이티 저장됨
# [1472/3837] 케이프이에스제4호기업인수목적 주식회사 저장됨
# [1473/3837] 참존글로벌(주) 저장됨
# [1474/3837] 두산에너빌리티(주) 저장됨
# [1475/3837] (주)코미코 저장됨
# [1476/3837] (주)동운아나텍 저장됨
# [1477/3837] (주)에넥스 저장됨
# [1478/3837] (주)푸른기술 저장됨
# [1479/3837] (주)한솔케미칼 저장됨
# [1480/3837] (주)팍스넷 저장됨
# [1481/3837] (주)엔비티 저장됨
# [1482/3837] 삼현철강(주) 저장됨
# [1483/3837] 아이쓰리시스템(주) 저장됨
# [1484/3837] (주)에이스침대 저장됨
# [1485/3837] 현우산업(주) 저장됨
# [1486/3837] (주)전우정밀 저장됨
# [1487/3837] 주식회사 타임기술 저장됨
# [1488/3837] (주)휴코드홀딩스 저장됨
# [1489/3837] (주)금호에이치티 저장됨
# [1490/3837] 세기상사(주) 저장됨
# [1491/3837] ㈜핑거 저장됨
# [1492/3837] (주)유라테크 저장됨
# [1493/3837] 빛샘전자(주) 저장됨
# [1494/3837] 비엔케이제1호기업인수목적(주) 저장됨
# [1495/3837] 세방(주) 저장됨
# [1496/3837] (주)셀바스에이아이 저장됨
# [1497/3837] (주)에이루트 저장됨
# [1498/3837] (주)엔솔바이오사이언스 저장됨
# [1499/3837] (주)엘디티 저장됨
# [1500/3837] 한창산업(주) 저장됨
# [1501/3837] 인바이오주식회사 저장됨
# [1502/3837] 피씨엘(주) 저장됨
# [1503/3837] 부국증권(주) 저장됨
# [1504/3837] (주)이씨에스텔레콤 저장됨
# [1505/3837] 한국수출포장공업(주) 저장됨
# [1506/3837] 주식회사 루닛 저장됨
# [1507/3837] (주)네오리진 저장됨
# [1508/3837] 아진산업(주) 저장됨
# [1509/3837] 한일철강(주) 저장됨
# [1510/3837] (주)녹십자홀딩스 저장됨
# [1511/3837] (주)사조대림 저장됨
# [1512/3837] (주)나노 저장됨
# [1513/3837] 티제이미디어(주) 저장됨
# [1514/3837] 강남제비스코(주) 저장됨
# [1515/3837] (주)셀바스헬스케어 저장됨
# [1516/3837] (주)한국비엔씨 저장됨
# [1517/3837] (주)영우디에스피 저장됨
# [1518/3837] (주)삼성출판사 저장됨
# [1519/3837] (주)카스 저장됨
# [1520/3837] (주)휴비츠 저장됨
# [1521/3837] (주)이브이첨단소재 저장됨
# [1522/3837] (주)유비온 저장됨
# [1523/3837] (주)이미지스테크놀로지 저장됨
# [1524/3837] (주)에스폴리텍 저장됨
# [1525/3837] (주)골프존 저장됨
# [1526/3837] (주)오파스넷 저장됨
# [1527/3837] (주)SG글로벌 저장됨
# [1528/3837] KPX홀딩스(주) 저장됨
# [1529/3837] 켄코아에어로스페이스(주) 저장됨
# [1530/3837] 영화금속(주) 저장됨
# [1531/3837] 풀무원식품 (주) 저장됨
# [1532/3837] 키네마스터(주) 저장됨
# [1533/3837] 동양파일(주) 저장됨
# [1534/3837] (주)동방 저장됨
# [1535/3837] 주식회사 화승엔터프라이즈 저장됨
# [1536/3837] 씨제이바이오사이언스(주) 저장됨
# [1537/3837] 두산건설(주) 저장됨
# [1538/3837] 조선선재(주) 저장됨
# [1539/3837] 유진기업인수목적6호 주식회사 저장됨
# [1540/3837] 다스코(주) 저장됨
# [1541/3837] (주)클리오 저장됨
# [1542/3837] 하나29호기업인수목적 주식회사 저장됨
# [1543/3837] 엘비세미콘(주) 저장됨
# [1544/3837] (주)피엠티 저장됨
# [1545/3837] 주식회사 크래프톤 저장됨
# [1546/3837] 청광건설(주) 저장됨
# [1547/3837] 인크로스(주) 저장됨
# [1548/3837] (주)BYC 저장됨
# [1549/3837] 코츠테크놀로지(주) 저장됨
# [1550/3837] 주식회사 데이드림엔터테인먼트 저장됨
# [1551/3837] 더이앤엠(주) 저장됨
# [1552/3837] (주)제이아이테크 저장됨
# [1553/3837] 잉글우드랩 주식회사 저장됨
# [1554/3837] 레이저쎌 주식회사 저장됨
# [1555/3837] (주)에스제이엠 저장됨
# [1556/3837] 하나28호기업인수목적 주식회사 저장됨
# [1557/3837] (주)에스에프에이반도체 저장됨
# [1558/3837] 큐렉소(주) 저장됨
# [1559/3837] (주)에이텍모빌리티 저장됨
# [1560/3837] 지엠비코리아(주) 저장됨
# [1561/3837] (주)네오팜 저장됨
# [1562/3837] 주식회사 필에너지 저장됨
# [1563/3837] 미래산업(주) 저장됨
# [1564/3837] (주)에이블씨엔씨 저장됨
# [1565/3837] 한전산업개발(주) 저장됨
# [1566/3837] 에스케이증권제10호기업인수목적 주식회사 저장됨
# [1567/3837] 엔에이치기업인수목적29호 주식회사 저장됨
# [1568/3837] 케이비제25호기업인수목적 주식회사 저장됨
# [1569/3837] (주)유투바이오 저장됨
# [1570/3837] (주)비지에프리테일 저장됨
# [1571/3837] 아이비케이에스제17호기업인수목적 주식회사 저장됨
# [1572/3837] 주식회사 디에스단석 저장됨
# [1573/3837] 하나30호기업인수목적 주식회사 저장됨
# [1574/3837] 삼성기업인수목적4호(주) 저장됨
# [1575/3837] (주)티케이케미칼 저장됨
# [1576/3837] 콜마비앤에이치(주) 저장됨
# [1577/3837] (주)신한은행 저장됨
# [1578/3837] (주)케이엔더블유 저장됨
# [1579/3837] 케이비제23호기업인수목적 주식회사 저장됨
# [1580/3837] (주)세니젠 저장됨
# [1581/3837] 케이비제27호기업인수목적(주) 저장됨
# [1582/3837] (주)쏘닉스 저장됨
# [1583/3837] 데코앤에프 저장됨
# [1584/3837] 에이치엠씨아이비제4호기업인수목적 주식회사 저장됨
# [1585/3837] (주)트레스 저장됨
# [1586/3837] 미래에셋드림기업인수목적1호 주식회사 저장됨
# [1587/3837] SNT다이내믹스(주) 저장됨
# [1588/3837] S-Oil(주) 저장됨
# [1589/3837] 한국무브넥스(주) 저장됨
# [1590/3837] 하나금융19호기업인수목적 주식회사 저장됨
# [1591/3837] 팸텍주식회사 저장됨
# [1592/3837] (주)이수화학                              저장됨
# [1593/3837] 케이엔솔(주) 저장됨
# [1594/3837] (주)흥국 저장됨
# [1595/3837] 도이치모터스(주) 저장됨
# [1596/3837] (주)디엔오토모티브 저장됨
# [1597/3837] (주)삼진엘앤디 저장됨
# [1598/3837] (주)주연테크 저장됨
# [1599/3837] (주)다이오진 저장됨
# [1600/3837] 대보마그네틱(주) 저장됨
# [1601/3837] (주) 스맥 저장됨
# [1602/3837] (주)세아메탈 저장됨
# [1603/3837] (주)에코앤드림 저장됨
# [1604/3837] (주)캐스텍코리아 저장됨
# [1605/3837] (주)마니커에프앤지 저장됨
# [1606/3837] 브릿지바이오테라퓨틱스 주식회사 저장됨
# [1607/3837] 에이치엠씨아이비제6호기업인수목적 주식회사 저장됨
# [1608/3837] 넥스틸(주) 저장됨
# [1609/3837] (주)에스에이엠지엔터테인먼트 저장됨
# [1610/3837] 태양3C(주) 저장됨
# [1611/3837] 윙입푸드홀딩스 저장됨
# [1612/3837] 대동금속(주) 저장됨
# [1613/3837] (주)씨티케이 저장됨
# [1614/3837] (주)다우기술 저장됨
# [1615/3837] 주식회사 대원모방 저장됨
# [1616/3837] 대신밸런스제11호기업인수목적 저장됨
# [1617/3837] 유안타제8호기업인수목적 주식회사 저장됨
# [1618/3837] (주)율촌 저장됨
# [1619/3837] (주)휴맥스 저장됨
# [1620/3837] (주)한화갤러리아타임월드 저장됨
# [1621/3837] (주)LX인터내셔널 저장됨
# [1622/3837] (주)피씨디렉트 저장됨
# [1623/3837] 엠케이전자(주) 저장됨
# [1624/3837] (주)케이에스에스 해운 저장됨
# [1625/3837] 인베니아(주) 저장됨
# [1626/3837] LG전자(주) 저장됨
# [1627/3837] (주)크레버스 저장됨
# [1628/3837] (주)산돌 저장됨
# [1629/3837] SK디앤디(주) 저장됨
# [1630/3837] 유일에너테크(주) 저장됨
# [1631/3837] (주)디케이앤디 저장됨
# [1632/3837] (주)케스피온 저장됨
# [1633/3837] (주)마음에이아이 저장됨
# [1634/3837] (주)엑셈 저장됨
# [1635/3837] (주)아이비김영 저장됨
# [1636/3837] (주)누리플랜 저장됨
# [1637/3837] (주)제이에스티나 저장됨
# [1638/3837] 메가엠디(주) 저장됨
# [1639/3837] 스톤브릿지벤처스(주) 저장됨
# [1640/3837] (주)엘엠에스 저장됨
# [1641/3837] 주식회사 오픈놀 저장됨
# [1642/3837] 미래에셋증권(주) 저장됨
# [1643/3837] 에코바이오홀딩스(주) 저장됨
# [1644/3837] 나무기술(주) 저장됨
# [1645/3837] 엠아이큐브솔루션 주식회사 저장됨
# [1646/3837] 디에스티(주) 저장됨
# [1647/3837] (주)파두 저장됨
# [1648/3837] (주)에스엠벡셀 저장됨
# [1649/3837] (주)케이알엠 저장됨
# [1650/3837] 제이에스전선(주) 저장됨
# [1651/3837] 에이치엠씨아이비제5호기업인수목적 주식회사 저장됨
# [1652/3837] 하나26호기업인수목적 주식회사 저장됨
# [1653/3837] (주)멀티캠퍼스 저장됨
# [1654/3837] 대신밸런스제10호기업인수목적 주식회사 저장됨
# [1655/3837] 화성밸브(주) 저장됨
# [1656/3837] 삼정펄프(주) 저장됨
# [1657/3837] 엔에이치기업인수목적30호 주식회사 저장됨
# [1658/3837] 주식회사 넥스틴 저장됨
# [1659/3837] (주)세림비앤지 저장됨
# [1660/3837] (주)하우리 저장됨
# [1661/3837] 케이에이치필룩스(주) 저장됨
# [1662/3837] 주식회사 아센디오 저장됨
# [1663/3837] 한국제13호기업인수목적 주식회사 저장됨
# [1664/3837] (주)강원랜드 저장됨
# [1665/3837] (주)엘아이에스 저장됨
# [1666/3837] (주)케이엔에스 저장됨
# [1667/3837] 웰킵스하이텍(주) 저장됨
# [1668/3837] (주)NICE홀딩스 저장됨
# [1669/3837] (주)아모레퍼시픽 저장됨
# [1670/3837] 엔에이치기업인수목적19호 주식회사 저장됨
# [1671/3837] 압타바이오(주) 저장됨
# [1672/3837] 지니너스 주식회사 저장됨
# [1673/3837] 나라셀라(주) 저장됨
# [1674/3837] 에스지신성건설주식회사 저장됨
# [1675/3837] 우진비앤지(주) 저장됨
# [1676/3837] 롯데에너지머티리얼즈(주) 저장됨
# [1677/3837] (주)원풍 저장됨
# [1678/3837] 동화기업(주) 저장됨
# [1679/3837] STX엔진(주) 저장됨
# [1680/3837] 신화인터텍(주) 저장됨
# [1681/3837] 씨큐브(주) 저장됨
# [1682/3837] 뿌리깊은나무들(주) 저장됨
# [1683/3837] 에스와이스틸텍(주) 저장됨
# [1684/3837] 세명전기공업(주) 저장됨
# [1685/3837] (주)모베이스전자 저장됨
# [1686/3837] 라온시큐어(주) 저장됨
# [1687/3837] (주)다날 저장됨
# [1688/3837] 와이엠티(주) 저장됨
# [1689/3837] (주)디에스앤엘 저장됨
# [1690/3837] (주)서울리거 저장됨
# [1691/3837] 미원홀딩스(주) 저장됨
# [1692/3837] (주)디엠에스 저장됨
# [1693/3837] (주)한컴위드 저장됨
# [1694/3837] 이비테크(주) 저장됨
# [1695/3837] 디엑스앤브이엑스(주) 저장됨
# [1696/3837] (주)디지피 저장됨
# [1697/3837] 동양이엔피(주) 저장됨
# [1698/3837] (주)라온테크 저장됨
# [1699/3837] 금호건설(주) 저장됨
# [1700/3837] (주)토비스 저장됨
# [1701/3837] 한주라이트메탈(주) 저장됨
# [1702/3837] (주)제이엔비 저장됨
# [1703/3837] (주)코세스 저장됨
# [1704/3837] 주식회사 청담글로벌 저장됨
# [1705/3837] (주)파인테크닉스 저장됨
# [1706/3837] 대성산업(주) 저장됨
# [1707/3837] (주)에스엘에스바이오 저장됨
# [1708/3837] (주)체시스 저장됨
# [1709/3837] (주)유비쿼스 저장됨
# [1710/3837] (주)골드앤에스 저장됨
# [1711/3837] 현대제철(주) 저장됨
# [1712/3837] 이성씨엔아이(주) 저장됨
# [1713/3837] 디비금융제10호기업인수목적 주식회사 저장됨
# [1714/3837] (주)한빛레이저 저장됨
# [1715/3837] (주)까뮤이앤씨 저장됨
# [1716/3837] 미원화학(주) 저장됨
# [1717/3837] (주)이퓨쳐 저장됨
# [1718/3837] (주)케이엑스넥스지 저장됨
# [1719/3837] (주)메디젠휴먼케어 저장됨
# [1720/3837] (주)티사이언티픽 저장됨
# [1721/3837] (주)알멕 저장됨
# [1722/3837] 롯데위탁관리부동산투자회사 주식회사 저장됨
# [1723/3837] 주식회사 라온텍 저장됨
# [1724/3837] 가온그룹(주) 저장됨
# [1725/3837] 와이씨켐(주) 저장됨
# [1726/3837] 주식회사 프로티아 저장됨
# [1727/3837] (주)프로젠 저장됨
# [1728/3837] 캡스톤파트너스(주) 저장됨
# [1729/3837] (주)폴라리스오피스 저장됨
# [1730/3837] 동부건설(주) 저장됨
# [1731/3837] 한화손해보험(주) 저장됨
# [1732/3837] (주)동국알앤에스 저장됨
# [1733/3837] (주)삼원강재 저장됨
# [1734/3837] 주식회사 삼양패키징 저장됨
# [1735/3837] 엔에이치기업인수목적22호 주식회사 저장됨
# [1736/3837] 슈어소프트테크 주식회사 저장됨
# [1737/3837] (주)이노시뮬레이션 저장됨
# [1738/3837] 교보14호기업인수목적 주식회사 저장됨
# [1739/3837] 에이치엘비테라퓨틱스(주) 저장됨
# [1740/3837] (주)모두투어네트워크 저장됨
# [1741/3837] 주식회사 맘스터치앤컴퍼니 저장됨
# [1742/3837] 에스케이오션플랜트(주) 저장됨
# [1743/3837] (주)삼영 저장됨
# [1744/3837] (주)톱텍 저장됨
# [1745/3837] (주)매커스 저장됨
# [1746/3837] 미래에셋대우기업인수목적 5호 주식회사 저장됨
# [1747/3837] 주식회사 트루엔 저장됨
# [1748/3837] KG스틸(주) 저장됨
# [1749/3837] (주)넥슨게임즈 저장됨
# [1750/3837] 대신밸런스제12호기업인수목적 주식회사 저장됨
# [1751/3837] (주)넥스트아이 저장됨
# [1752/3837] 바다로19호선박투자회사 저장됨
# [1753/3837] 씨엑스아이헬스케어테크놀리지그룹리미티드 저장됨
# [1754/3837] 디비금융제9호기업인수목적 주식회사 저장됨
# [1755/3837] (주)도화엔지니어링 저장됨
# [1756/3837] (주)NI스틸 저장됨
# [1757/3837] (주)모헨즈 저장됨
# [1758/3837] 디와이(주) 저장됨
# [1759/3837] (주)대성미생물연구소 저장됨
# [1760/3837] 문배철강(주) 저장됨
# [1761/3837] (주)제이브이엠 저장됨
# [1762/3837] (주)WISCOM 저장됨
# [1763/3837] (주)파트론 저장됨
# [1764/3837] 한선엔지니어링(주) 저장됨
# [1765/3837] (주)SBS 저장됨
# [1766/3837] (주)아세아텍 저장됨
# [1767/3837] 해성옵틱스(주) 저장됨
# [1768/3837] (주)제이웨이 저장됨
# [1769/3837] (주)동성화인텍 저장됨
# [1770/3837] 주식회사 엠투아이코퍼레이션 저장됨
# [1771/3837] (주)세아특수강 저장됨
# [1772/3837] (주)우진엔텍 저장됨
# [1773/3837] 대신밸런스제17호기업인수목적 주식회사 저장됨
# [1774/3837] (주)케이티알파 저장됨
# [1775/3837] (주)에이치와이티씨 저장됨
# [1776/3837] 대신밸런스제16호기업인수목적(주) 저장됨
# [1777/3837] (주)웅진 저장됨
# [1778/3837] 주식회사 티에스인베스트먼트 저장됨
# [1779/3837] (주)앱코 저장됨
# [1780/3837] 에이치엘만도(주) 저장됨
# [1781/3837] (주)우리금융지주 저장됨
# [1782/3837] (주)티비씨 저장됨
# [1783/3837] (주)한진 저장됨
# [1784/3837] (주)모비데이즈 저장됨
# [1785/3837] (주)인팩 저장됨
# [1786/3837] (주)비엠티 저장됨
# [1787/3837] (주)진양홀딩스 저장됨
# [1788/3837] (주)애니플러스 저장됨
# [1789/3837] (주)아이오바이오 저장됨
# [1790/3837] (주)엠씨넥스 저장됨
# [1791/3837] (주)케이비스타위탁관리부동산투자회사 저장됨
# [1792/3837] (주)길교이앤씨 저장됨
# [1793/3837] 한화플러스제4호기업인수목적(주) 저장됨
# [1794/3837] 하이제6호기업인수목적 주식회사 저장됨
# [1795/3837] 삼보오토(주) 저장됨
# [1796/3837] (주)엘앤에프 저장됨
# [1797/3837] 한국투자ANKOR유전해외자원개발특별자산투자회사1호(지분증권) 저장됨
# [1798/3837] (주)뉴인텍 저장됨
# [1799/3837] (주)정원엔시스 저장됨
# [1800/3837] (주)케이프 저장됨
# [1801/3837] (주) 소프트센 저장됨
# [1802/3837] (주)부방 저장됨
# [1803/3837] (주)디에이피 저장됨
# [1804/3837] (주)키이스트 저장됨
# [1805/3837] (주)유성티엔에스 저장됨
# [1806/3837] (주)한빛소프트 저장됨
# [1807/3837] (주)포스뱅크 저장됨
# [1808/3837] 하나27호기업인수목적 주식회사 저장됨
# [1809/3837] 아퓨어스 주식회사 저장됨
# [1810/3837] (주)로지스몬 저장됨
# [1811/3837] (주)프럼파스트 저장됨
# [1812/3837] 에이치엘비생명과학(주) 저장됨
# [1813/3837] 무송지오씨(주) 저장됨
# [1814/3837] (주)자연과환경 저장됨
# [1815/3837] 한국항공우주산업(주) 저장됨
# [1816/3837] (주)에이디칩스 저장됨
# [1817/3837] 주식회사 센코 저장됨
# [1818/3837] 한국제10호기업인수목적 주식회사 저장됨
# [1819/3837] 에이치비인베스트먼트(주) 저장됨
# [1820/3837] (주)메카로 저장됨
# [1821/3837] (주)케이엔제이 저장됨
# [1822/3837] (주)협진 저장됨
# [1823/3837] (주)지노믹트리 저장됨
# [1824/3837] (주)모다 저장됨
# [1825/3837] 주식회사 카이노스메드 저장됨
# [1826/3837] (주)경인양행 저장됨
# [1827/3837] 이연제약(주) 저장됨
# [1828/3837] (주)이상네트웍스 저장됨
# [1829/3837] 나노캠텍(주) 저장됨
# [1830/3837] (주)코스텍시스 저장됨
# [1831/3837] (주)베노티앤알 저장됨
# [1832/3837] (주)티비에이치글로벌 저장됨
# [1833/3837] (주)손오공 저장됨
# [1834/3837] (주)나우코스 저장됨
# [1835/3837] (주)우리넷 저장됨
# [1836/3837] 하나금융23호기업인수목적 주식회사 저장됨
# [1837/3837] 어보브반도체(주) 저장됨
# [1838/3837] 주식회사 진코스텍 저장됨
# [1839/3837] 써니전자(주) 저장됨
# [1840/3837] (주)퓨쳐켐 저장됨
# [1841/3837] 씨앤지하이테크(주) 저장됨
# [1842/3837] 디엘 주식회사 저장됨
# [1843/3837] (주)연우 저장됨
# [1844/3837] 컴퍼니케이파트너스(주) 저장됨
# [1845/3837] (주)앤씨앤 저장됨
# [1846/3837] 에스케이증권제11호기업인수목적 주식회사 저장됨
# [1847/3837] (주)비올 저장됨
# [1848/3837] (주)원익큐엔씨 저장됨
# [1849/3837] (주)지유온 저장됨
# [1850/3837] 유니셈(주) 저장됨
# [1851/3837] 한화위탁관리부동산투자회사(주) 저장됨
# [1852/3837] 케이씨그린홀딩스(주) 저장됨
# [1853/3837] 주식회사 파로스아이바이오 저장됨
# [1854/3837] 주식회사 퓨런티어 저장됨
# [1855/3837] 주식회사 에코아이 저장됨
# [1856/3837] (주)내츄럴엔도텍 저장됨
# [1857/3837] (주)제놀루션 저장됨
# [1858/3837] 유진기업인수목적10호 주식회사 저장됨
# [1859/3837] 제이더블유신약(주) 저장됨
# [1860/3837] 하나31호기업인수목적 주식회사 저장됨
# [1861/3837] 비엔케이제2호기업인수목적(주) 저장됨
# [1862/3837] 케이에이치건설 주식회사 저장됨
# [1863/3837] (주)동인기연 저장됨
# [1864/3837] (주)인텍플러스 저장됨
# [1865/3837] 메리츠화재해상보험(주) 저장됨
# [1866/3837] (주)미래아이앤지 저장됨
# [1867/3837] (주)아모그린텍 저장됨
# [1868/3837] (주)경농 저장됨
# [1869/3837] (주)미래엔에듀파트너 저장됨
# [1870/3837] 화일약품(주) 저장됨
# [1871/3837] (주)이스트소프트 저장됨
# [1872/3837] (주)제이오 저장됨
# [1873/3837] 상상인제4호기업인수목적 주식회사 저장됨
# [1874/3837] 주식회사 싸이버원 저장됨
# [1875/3837] (주)아이패밀리에스씨 저장됨
# [1876/3837] (주)지에스이 저장됨
# [1877/3837] 대림통상(주) 저장됨
# [1878/3837] 지투파워(주) 저장됨
# [1879/3837] (주)펨트론 저장됨
# [1880/3837] 삼성공조(주) 저장됨
# ...
# [3217/3837] (주)리튬포어스 저장됨
# [3218/3837] 동아에스티(주) 저장됨
# [3219/3837] (주)디지아이티엑스 저장됨
# [3220/3837] 씨피시스템(주) 저장됨
# [3221/3837] 한서제약(주) 저장됨
# [3222/3837] 플래닛팔이(주) 저장됨
# [3223/3837] 미래반도체(주) 저장됨
# [3224/3837] 하이젠알앤엠 주식회사 저장됨
# [3225/3837] 한국맥널티(주) 저장됨
# [3226/3837] CJ제일제당(주) 저장됨
# [3227/3837] (주)선진 저장됨
# [3228/3837] (주)노바렉스 저장됨
# [3229/3837] (주)삼양사 저장됨
# [3230/3837] 주식회사 팜스빌 저장됨
# [3231/3837] 샘표식품(주) 저장됨
# [3232/3837] (주)크라운제과 저장됨
# [3233/3837] 주식회사 에이치피오 저장됨
# [3234/3837] (주)오리온 저장됨
# [3235/3837] (주)미래생명자원 저장됨
# [3236/3837] 롯데웰푸드(주) 저장됨
# [3237/3837] (주)뉴트리 저장됨
# [3238/3837] (주)유니포인트 저장됨
# [3239/3837] 광동헬스바이오(주) 저장됨
# [3240/3837] 하나금융22호기업인수목적 주식회사 저장됨
# [3241/3837] 온코닉테라퓨틱스(주) 저장됨
# [3242/3837] (주)케이비지 저장됨
# [3243/3837] (주)경동나비엔 저장됨
# [3244/3837] 남화토건(주) 저장됨
# [3245/3837] 남광토건(주) 저장됨
# [3246/3837] (주)스페코 저장됨
# [3247/3837] (주)에스엠코어 저장됨
# [3248/3837] (주)대창 저장됨
# [3249/3837] 한국알콜산업(주) 저장됨
# [3250/3837] 동원산업(주) 저장됨
# [3251/3837] 유진기업(주) 저장됨
# [3252/3837] 동화약품(주) 저장됨
# [3253/3837] (주)아이즈비전 저장됨
# [3254/3837] 보해양조(주) 저장됨
# [3255/3837] 에스엘(주) 저장됨
# [3256/3837] 대아티아이(주) 저장됨
# [3257/3837] 에스케이디스커버리(주) 저장됨
# [3258/3837] (주)코데즈컴바인 저장됨
# [3259/3837] 한성크린텍(주) 저장됨
# [3260/3837] 동원시스템즈(주) 저장됨
# [3261/3837] 한라아이엠에스(주) 저장됨
# [3262/3837] 유화증권(주) 저장됨
# [3263/3837] 케이비제30호기업인수목적(주) 저장됨
# [3264/3837] (주)소룩스 저장됨
# [3265/3837] (주)에이치엘사이언스 저장됨
# [3266/3837] 대동고려삼(주) 저장됨
# [3267/3837] 한솔피엔에스(주) 저장됨
# [3268/3837] (주)한국애보트진단 저장됨
# [3269/3837] 제이엔케이글로벌(주) 저장됨
# [3270/3837] (주)씨알푸드 저장됨
# [3271/3837] 바이오텐(주) 저장됨
# [3272/3837] (주)인산가 저장됨
# [3273/3837] (주)위지윅스튜디오 저장됨
# [3274/3837] (주)휴럼 저장됨
# [3275/3837] (주)이지바이오 저장됨
# [3276/3837] 주식회사 오에스피 저장됨
# [3277/3837] 경동제약(주) 저장됨
# [3278/3837] 고려제약(주) 저장됨
# [3279/3837] 국제약품(주) 저장됨
# [3280/3837] 대한약품공업(주) 저장됨
# [3281/3837] (주)동구바이오제약 저장됨
# [3282/3837] 동국제약(주) 저장됨
# [3283/3837] (주)원익피앤이 저장됨
# [3284/3837] 에스엔유프리시젼(주) 저장됨
# [3285/3837] (주)글로벌스탠다드테크놀로지 저장됨
# [3286/3837] 일성건설(주) 저장됨
# [3287/3837] (주)이엠텍 저장됨
# [3288/3837] 오씨아이홀딩스 주식회사 저장됨
# [3289/3837] (주)제넥신 저장됨
# [3290/3837] (주)휴스틸 저장됨
# [3291/3837] (주)휴메딕스 저장됨
# [3292/3837] (주)한국종합기술 저장됨
# [3293/3837] 코스맥스엔비티(주) 저장됨
# [3294/3837] 한국앤컴퍼니(주) 저장됨
# [3295/3837] (주)삼기 저장됨
# [3296/3837] 코스모화학(주) 저장됨
# [3297/3837] 한미사이언스(주) 저장됨
# [3298/3837] (주)씨이랩 저장됨
# [3299/3837] (주)한창제지 저장됨
# [3300/3837] (주)코아시아씨엠 저장됨
# [3301/3837] 에이치디씨(주) 저장됨
# [3302/3837] (주)강동씨앤엘 저장됨
# [3303/3837] 에이치엠엠(주)  저장됨
# [3304/3837] 기신정기(주) 저장됨
# [3305/3837] (주)진도 저장됨
# [3306/3837] (주)하스 저장됨
# [3307/3837] (주)메디쎄이 저장됨
# [3308/3837] (주)폴라리스에이아이 저장됨
# [3309/3837] (주)에스씨엘사이언스 저장됨
# [3310/3837] (주)이렘 저장됨
# [3311/3837] (주)백산 저장됨
# [3312/3837] 한솔로지스틱스(주) 저장됨
# [3313/3837] 안국약품(주) 저장됨
# [3314/3837] (주)영흥 저장됨
# [3315/3837] (주)오션인더블유 저장됨
# [3316/3837] 주식회사 한컴라이프케어 저장됨
# [3317/3837] 한솔제지(주) 저장됨
# [3318/3837] 우리이앤엘(주) 저장됨
# [3319/3837] (주)케어랩스 저장됨
# [3320/3837] (주)비엔디 저장됨
# [3321/3837] (주)씨티앤티 저장됨
# [3322/3837] 콜마파마(주) 저장됨
# [3323/3837] (주)지케이파워 저장됨
# [3324/3837] (주)수산아이앤티 저장됨
# [3325/3837] 부광약품(주) 저장됨
# [3326/3837] 삼성제약(주) 저장됨
# [3327/3837] 삼아제약(주) 저장됨
# [3328/3837] 삼천당제약(주) 저장됨
# [3329/3837] (주)녹십자 저장됨
# [3330/3837] (주)서울제약 저장됨
# [3331/3837] (주)팜젠사이언스 저장됨
# [3332/3837] 신신제약(주) 저장됨
# [3333/3837] 신일제약(주) 저장됨
# [3334/3837] 신풍제약(주) 저장됨
# [3335/3837] 영진약품(주) 저장됨
# [3336/3837] (주)유유제약 저장됨
# [3337/3837] 일동홀딩스(주) 저장됨
# [3338/3837] JW중외제약(주) 저장됨
# [3339/3837] 진양제약(주) 저장됨
# [3340/3837] 한국유나이티드제약(주) 저장됨
# [3341/3837] (주)한독 저장됨
# [3342/3837] 동양생명보험(주) 저장됨
# [3343/3837] 삼부토건(주) 저장됨
# [3344/3837] 태양기계(주) 저장됨
# [3345/3837] (주)대양금속 저장됨
# [3346/3837] (주)씨유메디칼시스템 저장됨
# [3347/3837] (주)드림시큐리티 저장됨
# [3348/3837] (주)넥센 저장됨
# [3349/3837] 넥센타이어(주) 저장됨
# [3350/3837] 선샤인푸드(주) 저장됨
# [3351/3837] (주)동아지질 저장됨
# [3352/3837] (주)본느 저장됨
# [3353/3837] (주)한국토지신탁 저장됨
# [3354/3837] 코오롱이앤피(주) 저장됨
# [3355/3837] (주)형지글로벌 저장됨
# [3356/3837] 에이치디씨현대이피(주) 저장됨
# [3357/3837] 에이치엘비바이오스텝(주) 저장됨
# [3358/3837] AJ네트웍스 주식회사 저장됨
# [3359/3837] 에브리봇(주) 저장됨
# [3360/3837] (주)엘엑스하우시스 저장됨
# [3361/3837] 주식회사 코윈테크 저장됨
# [3362/3837] 코오롱인더스트리(주) 저장됨
# [3363/3837] 에스디바이오센서(주) 저장됨
# [3364/3837] 한솔테크닉스(주) 저장됨
# [3365/3837] (주)루트로닉 저장됨
# [3366/3837] (주)코디 저장됨
# [3367/3837] (주)퓨처코어 저장됨
# [3368/3837] 주식회사 에스바이오메딕스 저장됨
# [3369/3837] (주)티엘아이 저장됨
# [3370/3837] (주)영진코퍼레이션 저장됨
# [3371/3837] (주)닷밀 저장됨
# [3372/3837] 한올바이오파마(주) 저장됨
# [3373/3837] 현대약품(주) 저장됨
# [3374/3837] 환인제약(주) 저장됨
# [3375/3837] (주)한국파마 저장됨
# [3376/3837] 대화제약(주) 저장됨
# [3377/3837] (주)바이넥스 저장됨
# [3378/3837] 조아제약(주) 저장됨
# [3379/3837] (주)비씨월드제약 저장됨
# [3380/3837] 주식회사 바스칸바이오제약 저장됨
# [3381/3837] (주)셀트리온제약 저장됨
# [3382/3837] 위더스제약(주) 저장됨
# [3383/3837] 한미약품(주) 저장됨
# [3384/3837] (주)헬릭스미스 저장됨
# [3385/3837] 주식회사 알체라 저장됨
# [3386/3837] 세원이앤씨(주) 저장됨
# [3387/3837] (주)세토피아 저장됨
# [3388/3837] 미래에셋비전기업인수목적1호 주식회사 저장됨
# [3389/3837] 주식회사 블랙야크아이앤씨 저장됨
# [3390/3837] 한국타이어앤테크놀로지(주) 저장됨
# [3391/3837] 코오롱티슈진(주) 저장됨
# [3392/3837] 현대코퍼레이션홀딩스(주) 저장됨
# [3393/3837] (주)리메드 저장됨
# [3394/3837] 에이치디씨현대산업개발(주) 저장됨
# [3395/3837] 코오롱모빌리티그룹(주) 저장됨
# [3396/3837] 인바이츠바이오코아(주) 저장됨
# [3397/3837] (주)월덱스 저장됨
# [3398/3837] 주식회사 아이엠뱅크 저장됨
# [3399/3837] 대원강업(주) 저장됨
# [3400/3837] 에쓰씨엔지니어링(주) 저장됨
# [3401/3837] 주식회사알에프세미 저장됨
# [3402/3837] 피엔케이피부임상연구센타(주) 저장됨
# [3403/3837] 퀀타피아(주) 저장됨
# [3404/3837] 코칩(주) 저장됨
# [3405/3837] 에스케이증권제12호기업인수목적 주식회사 저장됨
# [3406/3837] 코아스템켐온 주식회사 저장됨
# [3407/3837] (주)종근당 저장됨
# [3408/3837] 에이치케이이노엔 주식회사 저장됨
# [3409/3837] 일동제약(주) 저장됨
# [3410/3837] (주)알피바이오 저장됨
# [3411/3837] (주)제주은행 저장됨
# [3412/3837] (주)앱트뉴로사이언스 저장됨
# [3413/3837] (주)빌리언스 저장됨
# [3414/3837] (주)아이엠 저장됨
# [3415/3837] 주식회사 에이치피에스피 저장됨
# [3416/3837] 아이에스동서(주) 저장됨
# [3417/3837] 경창산업(주) 저장됨
# [3418/3837] (주)TCC스틸 저장됨
# [3419/3837] 대동기어(주) 저장됨
# [3420/3837] (주)키다리스튜디오 저장됨
# [3421/3837] (주)포스코엠텍 저장됨
# [3422/3837] 서울반도체(주) 저장됨
# [3423/3837] 코스맥스비티아이(주) 저장됨
# [3424/3837] (주)태광 저장됨
# [3425/3837] (주)씨티알모빌리티 저장됨
# [3426/3837] 에스비아이인베스트먼트(주) 저장됨
# [3427/3837] (주)케이이씨 저장됨
# [3428/3837] 코스맥스(주) 저장됨
# [3429/3837] (주)오텍 저장됨
# [3430/3837] 두산퓨얼셀 주식회사 저장됨
# [3431/3837] 서울바이오시스(주) 저장됨
# [3432/3837] (주)폴라리스에이아이파마 저장됨
# [3433/3837] 에스에이치엔엘(주) 저장됨
# [3434/3837] 유안타제11호기업인수목적 주식회사 저장됨
# [3435/3837] 유안타제12호기업인수목적 주식회사 저장됨
# [3436/3837] 유안타제13호기업인수목적 주식회사 저장됨
# [3437/3837] 유안타제14호기업인수목적 주식회사 저장됨
# [3438/3837] (주)지오엘리먼트 저장됨
# [3439/3837] 엔에이치기업인수목적20호(주) 저장됨
# [3440/3837] 한화갤러리아(주) 저장됨
# [3441/3837] 애경케미칼(주) 저장됨
# [3442/3837] (주)테라젠이텍스 저장됨
# [3443/3837] (주)모비스 저장됨
# [3444/3837] 대한광통신(주) 저장됨
# [3445/3837] (주)이건홀딩스 저장됨
# [3446/3837] (주)인크레더블버즈 저장됨
# [3447/3837] (주)형지아이앤씨 저장됨
# [3448/3837] 제룡산업(주) 저장됨
# [3449/3837] 신한제11호기업인수목적 주식회사 저장됨
# [3450/3837] 신한제13호기업인수목적주식회사 저장됨
# [3451/3837] 신한제12호기업인수목적 주식회사 저장됨
# [3452/3837] (주)남산물산 저장됨
# [3453/3837] 솔루스첨단소재 주식회사 저장됨
# [3454/3837] 주식회사 케이조선 저장됨
# [3455/3837] 깨끗한나라(주) 저장됨
# [3456/3837] KD(주) 저장됨
# [3457/3837] (주)동원개발 저장됨
# [3458/3837] (주)태경비케이 저장됨
# [3459/3837] (주)티앤알바이오팹 저장됨
# [3460/3837] 성일하이텍 주식회사 저장됨
# [3461/3837] 엑스큐어(주) 저장됨
# [3462/3837] (주)에이피헬스케어 저장됨
# [3463/3837] 일양약품(주) 저장됨
# [3464/3837] (주)타조엔터테인먼트 저장됨
# [3465/3837] 한신기계공업(주) 저장됨
# [3466/3837] (주)케이쓰리아이 저장됨
# [3467/3837] (주)셀트리온 저장됨
# [3468/3837] (주)세우글로벌 저장됨
# [3469/3837] (주)엠에스씨 저장됨
# [3470/3837] (주)바른손 저장됨
# [3471/3837] (주)삼양홀딩스 저장됨
# [3472/3837] (주)서원 저장됨
# [3473/3837] 서울전자통신(주) 저장됨
# [3474/3837] (주)영풍 저장됨
# [3475/3837] 시그네틱스(주) 저장됨
# [3476/3837] (주)사조오양 저장됨
# [3477/3837] (주)좋은사람들 저장됨
# [3478/3837] 한국석유공업(주) 저장됨
# [3479/3837] (주)아이에이 저장됨
# [3480/3837] (주)한진중공업홀딩스 저장됨
# [3481/3837] (주)바른손이앤에이 저장됨
# [3482/3837] (주)파라다이스 저장됨
# [3483/3837] (주)삼현 저장됨
# [3484/3837] 에이치에스화성(주) 저장됨
# [3485/3837] 베뉴지(주) 저장됨
# [3486/3837] (주)콘텐트리중앙 저장됨
# [3487/3837] 데브시스터즈(주) 저장됨
# [3488/3837] 천지산업(주) 저장됨
# [3489/3837] 에이치엘비(주) 저장됨
# [3490/3837] (주)오스템 저장됨
# [3491/3837] (주)국보디자인 저장됨
# [3492/3837] (주)한국경제티브이 저장됨
# [3493/3837] 삼아알미늄(주) 저장됨
# [3494/3837] 아남전자(주) 저장됨
# [3495/3837] 제이씨케미칼(주) 저장됨
# [3496/3837] KPX케미칼(주) 저장됨
# [3497/3837] (주)씨젠 저장됨
# [3498/3837] 교보11호기업인수목적 주식회사 저장됨
# [3499/3837] 주식회사 제이투케이바이오 저장됨
# [3500/3837] (주)사이노젠 저장됨
# [3501/3837] 삼성증권(주) 저장됨
# [3502/3837] 엘지이노텍(주) 저장됨
# [3503/3837] 삼성생명보험(주) 저장됨
# [3504/3837] (주)엔텔스 저장됨
# [3505/3837] 삼성중공업(주) 저장됨
# [3506/3837] 한솔인티큐브(주) 저장됨
# [3507/3837] (주)신세계 저장됨
# [3508/3837] 현대차증권(주) 저장됨
# [3509/3837] (주)에스원 저장됨
# [3510/3837] 화천기공(주) 저장됨
# [3511/3837] 일진다이아몬드(주) 저장됨
# [3512/3837] ㈜에어레인 저장됨
# [3513/3837] (주)유아이디 저장됨
# [3514/3837] (주)화신테크 저장됨
# [3515/3837] (주)나무가 저장됨
# [3516/3837] 키움증권(주) 저장됨
# [3517/3837] (주)지슨 저장됨
# [3518/3837] (주)씨앤씨인터내셔널 저장됨
# [3519/3837] 키움제8호기업인수목적 주식회사 저장됨
# [3520/3837] 주식회사 비피도 저장됨
# [3521/3837] 주식회사 엔젠바이오 저장됨
# [3522/3837] 하나금융21호기업인수목적 주식회사 저장됨
# [3523/3837] 주식회사 파인메딕스 저장됨
# [3524/3837] (주)동방메디컬 저장됨
# [3525/3837] 유니슨(주) 저장됨
# [3526/3837] 제일일렉트릭(주) 저장됨
# [3527/3837] 주식회사 신한서부티엔디위탁관리부동산투자회사 저장됨
# [3528/3837] (주)인지디스플레이 저장됨
# [3529/3837] (주)가비아 저장됨
# [3530/3837] 고려제강(주) 저장됨
# [3531/3837] 흥국화재해상보험(주) 저장됨
# [3532/3837] (주)케이씨씨건설 저장됨
# [3533/3837] 대성창업투자(주) 저장됨
# [3534/3837] (주)대현 저장됨
# [3535/3837] (주)엘엑스세미콘 저장됨
# [3536/3837] (주)부산은행 저장됨
# [3537/3837] 자화전자(주) 저장됨
# [3538/3837] 코웰패션(주) 저장됨
# [3539/3837] (주)라이온켐텍 저장됨
# [3540/3837] (주)코아스 저장됨
# [3541/3837] (주)시지메드텍 저장됨
# [3542/3837] (주)티에스이 저장됨
# [3543/3837] 텔코웨어(주) 저장됨
# [3544/3837] (주)케이티씨에스 저장됨
# [3545/3837] (주)숲 저장됨
# [3546/3837] (주)웅진씽크빅 저장됨
# [3547/3837] 씨지인바이츠(주) 저장됨
# [3548/3837] 엘브이엠씨홀딩스(주) 저장됨
# [3549/3837] (주)시디즈 저장됨
# [3550/3837] (주)성창오토텍 저장됨
# [3551/3837] (주)씨케이솔루션 저장됨
# [3552/3837] (주)이녹스 저장됨
# [3553/3837] (주)티와이홀딩스 저장됨
# [3554/3837] 에스와이(주) 저장됨
# [3555/3837] (주)유니테스트 저장됨
# [3556/3837] 주식회사 코셈 저장됨
# [3557/3837] (주)셀로맥스사이언스 저장됨
# [3558/3837] 광동제약(주) 저장됨
# [3559/3837] (주)한국테크놀로지 저장됨
# [3560/3837] 세븐브로이맥주 주식회사 저장됨
# [3561/3837] (주)씨엔티드림 저장됨
# [3562/3837] (주)효성 저장됨
# [3563/3837] 유안타증권(주) 저장됨
# [3564/3837] 한국선재(주) 저장됨
# [3565/3837] 동원수산(주) 저장됨
# [3566/3837] (주)에너토크 저장됨
# [3567/3837] (주)코콤 저장됨
# [3568/3837] 선도전기(주) 저장됨
# [3569/3837] (주)일신석재 저장됨
# [3570/3837] 한국주철관공업(주) 저장됨
# [3571/3837] 한신공영(주) 저장됨
# [3572/3837] (주)케이엘넷 저장됨
# [3573/3837] 경남기업(주) 저장됨
# [3574/3837] 지나인제약(주) 저장됨
# [3575/3837] 비케이탑스(주) 저장됨
# [3576/3837] (주)이스트에이드 저장됨
# [3577/3837] 상신브레이크(주) 저장됨
# [3578/3837] (주)신풍 저장됨
# [3579/3837] 애머릿지코퍼레이션 저장됨
# [3580/3837] (주)툴젠 저장됨
# [3581/3837] SK시그넷(주) 저장됨
# [3582/3837] (주)아이에스시 저장됨
# [3583/3837] 주식회사에스코넥 저장됨
# [3584/3837] (주)아이윈플러스 저장됨
# [3585/3837] (주)케이엑스이노베이션 저장됨
# [3586/3837] (주)디티앤씨 저장됨
# [3587/3837] (주)앤디포스 저장됨
# [3588/3837] (주)아이스크림에듀 저장됨
# [3589/3837] (주)와이씨 저장됨
# [3590/3837] 주식회사 모비릭스 저장됨
# [3591/3837] 엠에프씨(주) 저장됨
# [3592/3837] (주)이녹스첨단소재 저장됨
# [3593/3837] 솔트웨어 주식회사 저장됨
# [3594/3837] (주)한국팩키지 저장됨
# [3595/3837] 롯데쇼핑(주) 저장됨
# [3596/3837] 더라미(주) 저장됨
# [3597/3837] (주)에스엠라이프디자인그룹 저장됨
# [3598/3837] 현대비앤지스틸(주) 저장됨
# [3599/3837] (주)현대이지웰 저장됨
# [3600/3837] 서울도시가스(주) 저장됨
# [3601/3837] (주)위메이드플레이 저장됨
# [3602/3837] (주)포스코디엑스 저장됨
# [3603/3837] (주)퓨릿 저장됨
# [3604/3837] 에이치디한국조선해양(주) 저장됨
# [3605/3837] (주)와이어블 저장됨
# [3606/3837] 새론오토모티브(주) 저장됨
# [3607/3837] 아시아나아이디티(주) 저장됨
# [3608/3837] 한국정보공학(주) 저장됨
# [3609/3837] (주)비상교육 저장됨
# [3610/3837] (주)누리플렉스 저장됨
# [3611/3837] (주)에이치제이중공업 저장됨
# [3612/3837] 대한화섬(주) 저장됨
# [3613/3837] (주)엠투엔 저장됨
# [3614/3837] 이화전기공업(주) 저장됨
# [3615/3837] 사조산업(주) 저장됨
# [3616/3837] 한주에이알티(주) 저장됨
# [3617/3837] (주)디에이치오토넥스 저장됨
# [3618/3837] (주)심텍홀딩스 저장됨
# [3619/3837] 태광산업(주) 저장됨
# [3620/3837] 농업회사법인 (주)엔에이치농우바이오 저장됨
# [3621/3837] (주)오상헬스케어 저장됨
# [3622/3837] (주)에스지엔지 저장됨
# [3623/3837] 세종텔레콤(주) 저장됨
# [3624/3837] (주)피노 저장됨
# [3625/3837] (주)코나솔 저장됨
# [3626/3837] (주)아이톡시 저장됨
# [3627/3837] 케이지에코솔루션(주) 저장됨
# [3628/3837] (주)스타코링크 저장됨
# [3629/3837] 에이치엘비사이언스(주) 저장됨
# [3630/3837] (주)푸른소나무 저장됨
# [3631/3837] 비트맥스(주) 저장됨
# [3632/3837] 주식회사 아이엠비디엑스 저장됨
# [3633/3837] (주)블리츠웨이엔터테인먼트 저장됨
# [3634/3837] (주)나우로보틱스 저장됨
# [3635/3837] (주)코리아나화장품 저장됨
# [3636/3837] (주)디이엔티 저장됨
# [3637/3837] (주)티플랙스 저장됨
# [3638/3837] 에이피위성(주) 저장됨
# [3639/3837] 주식회사 씨앤투스 저장됨
# [3640/3837] 주식회사 위니아에이드 저장됨
# [3641/3837] (주)쿠콘 저장됨
# [3642/3837] 보로노이(주) 저장됨
# [3643/3837] 주식회사 에스피소프트 저장됨
# [3644/3837] (주)쓰리빌리언 저장됨
# [3645/3837] 폰드그룹(주) 저장됨
# [3646/3837] (주)세아제강 저장됨
# [3647/3837] 산일전기(주) 저장됨
# [3648/3837] (주)그래디언트 저장됨
# [3649/3837] (주)피에스일렉트로닉스 저장됨
# [3650/3837] (주)에스엘테라퓨틱스 저장됨
# [3651/3837] (주)오하임앤컴퍼니 저장됨
# [3652/3837] (주)제로투세븐 저장됨
# [3653/3837] (주)잇츠한불 저장됨
# [3654/3837] (주)지에스글로벌 저장됨
# [3655/3837] (주)디티씨 저장됨
# [3656/3837] (주)제일기획 저장됨
# [3657/3837] (주)스피어코퍼레이션 저장됨
# [3658/3837] 에스케이증권제8호기업인수목적 주식회사 저장됨
# [3659/3837] (주)인디에프 저장됨
# [3660/3837] 디비금융제11호기업인수목적 주식회사 저장됨
# [3661/3837] (주)바이오포트코리아 저장됨
# [3662/3837] (주)대백저축은행 저장됨
# [3663/3837] (주)달바글로벌 저장됨
# [3664/3837] (주)이엘씨 저장됨
# [3665/3837] (주)우정바이오 저장됨
# [3666/3837] 주식회사 이지트로닉스 저장됨
# [3667/3837] 이에이트 주식회사 저장됨
# [3668/3837] 주식회사 더 미동 저장됨
# [3669/3837] (주)큐러블 저장됨
# [3670/3837] (주)대덕 저장됨
# [3671/3837] (주)카프로 저장됨
# [3672/3837] 주식회사 나래나노텍 저장됨
# [3673/3837] (주)아이마켓코리아 저장됨
# [3674/3837] 유안타제10호기업인수목적 주식회사 저장됨
# [3675/3837] (주)이노룰스 저장됨
# [3676/3837] (주)다산솔루에타 저장됨
# [3677/3837] (주)청호ICT 저장됨
# [3678/3837] 이니텍(주) 저장됨
# [3679/3837] 주식회사 제이티씨 저장됨
# [3680/3837] DB증권(주) 저장됨
# [3681/3837] 케이지모빌리티(주) 저장됨
# [3682/3837] 농업회사법인 우듬지팜 주식회사 저장됨
# [3683/3837] 키스트론(주) 저장됨
# [3684/3837] 삼양통상(주) 저장됨
# [3685/3837] 주식회사 포바이포 저장됨
# [3686/3837] 주식회사 센서뷰 저장됨
# [3687/3837] 한국투자파트너스(주) 저장됨
# [3688/3837] 엘지디스플레이(주) 저장됨
# [3689/3837] (주)수산세보틱스 저장됨
# [3690/3837] 티케이지애강(주) 저장됨
# [3691/3837] (주)아하 저장됨
# [3692/3837] (주)퀀텀온 저장됨
# [3693/3837] SK이노베이션(주) 저장됨
# [3694/3837] (주)토모큐브 저장됨
# [3695/3837] 신한제16호기업인수목적 주식회사 저장됨
# [3696/3837] (주)스타에스엠자기관리부동산투자회사 저장됨
# [3697/3837] 핸즈코퍼레이션(주) 저장됨
# [3698/3837] (주)엑스플러스 저장됨
# [3699/3837] 퓨쳐메디신 주식회사 저장됨
# [3700/3837] (주)위니아 저장됨
# [3701/3837] (주)제넨바이오 저장됨
# [3702/3837] 씨앤에이치(주) 저장됨
# [3703/3837] 더큐브앤(주) 저장됨
# [3704/3837] (주)캐프 저장됨
# [3705/3837] 아이비케이에스제20호기업인수목적 주식회사 저장됨
# [3706/3837] 삼성기업인수목적7호 주식회사 저장됨
# [3707/3837] 주식회사 티움바이오 저장됨
# [3708/3837] (주)건영 저장됨
# [3709/3837] DSR제강(주) 저장됨
# [3710/3837] 메이슨캐피탈주식회사 저장됨
# [3711/3837] (주)삼에스코리아 저장됨
# [3712/3837] (주)넥사다이내믹스 저장됨
# [3713/3837] (주)케이씨텍 저장됨
# [3714/3837] (주)빙그레 저장됨
# [3715/3837] 인스피언(주) 저장됨
# [3716/3837] 신영증권(주) 저장됨
# [3717/3837] 주식회사 플라즈맵 저장됨
# [3718/3837] (주)미스토홀딩스 저장됨
# [3719/3837] (주)대창솔루션 저장됨
# [3720/3837] 서울평가정보(주) 저장됨
# [3721/3837] (주)아이티센글로벌 저장됨
# [3722/3837] (주)한울앤제주 저장됨
# [3723/3837] (주)아이엘 저장됨
# [3724/3837] (주)포커스에이아이 저장됨
# [3725/3837] (주)쎄크 저장됨
# [3726/3837] (주)동성케미컬 저장됨
# [3727/3837] 씨앤티85(주) 저장됨
# [3728/3837] 에이치엘비펩(주) 저장됨
# [3729/3837] (주)아스타 저장됨
# [3730/3837] 에이비엘바이오(주) 저장됨
# [3731/3837] (주)시선에이아이 저장됨
# [3732/3837] 일성아이에스(주) 저장됨
# [3733/3837] 주성엔지니어링(주) 저장됨
# [3734/3837] (주)아크솔루션스 저장됨
# [3735/3837] 한국제14호기업인수목적 주식회사 저장됨
# [3736/3837] (주)에이아이코리아 저장됨
# [3737/3837] (주)두산테스나 저장됨
# [3738/3837] (주)위메이드 저장됨
# [3739/3837] (주)레몬 저장됨
# [3740/3837] (주)넵튠 저장됨
# [3741/3837] 코원에너지서비스(주) 저장됨
# [3742/3837] OCI(주) 저장됨
# [3743/3837] 도부(주) 저장됨
# [3744/3837] 한세실업(주) 저장됨
# [3745/3837] (주)한송네오텍 저장됨
# [3746/3837] 한양증권(주) 저장됨
# [3747/3837] 엠에프엠코리아(주) 저장됨
# [3748/3837] 주식회사 더본코리아 저장됨
# [3749/3837] (주)링크솔루션 저장됨
# [3750/3837] 주식회사 에이프릴바이오 저장됨
# [3751/3837] (주)케이씨씨글라스 저장됨
# [3752/3837] 네이트커뮤니케이션즈 주식회사 저장됨
# [3753/3837] (주)일신바이오베이스 저장됨
# [3754/3837] (주)에이프로젠바이오로직스 저장됨
# [3755/3837] 삼환기업(주) 저장됨
# [3756/3837] (주)아이티센씨티에스 저장됨
# [3757/3837] 화승인더스트리(주) 저장됨
# [3758/3837] 한화비전(주) 저장됨
# [3759/3837] 디에이치엑스컴퍼니(주) 저장됨
# [3760/3837] 주식회사 다보링크 저장됨
# [3761/3837] 주식회사 인터로이드 저장됨
# [3762/3837] (주)케이티밀리의서재 저장됨
# [3763/3837] 주식회사 로킷헬스케어 저장됨
# [3764/3837] (주)인스웨이브 저장됨
# [3765/3837] (주)에스켐 저장됨
# [3766/3837] (주)광명전기 저장됨
# [3767/3837] (주)푸른저축은행 저장됨
# [3768/3837] 디와이피(주) 저장됨
# [3769/3837] (주)제일바이오 저장됨
# [3770/3837] (주)아모레퍼시픽홀딩스 저장됨
# [3771/3837] NICE인프라(주) 저장됨
# [3772/3837] (주)유니온바이오메트릭스 저장됨
# [3773/3837] (주)케이티나스미디어 저장됨
# [3774/3837] (주)디바이스 저장됨
# [3775/3837] (주)오건에코텍 저장됨
# [3776/3837] (주)솔디펜스 저장됨
# [3777/3837] (주)아이티센엔텍 저장됨
# [3778/3837] (주)중앙첨단소재 저장됨
# [3779/3837] (주)인트로메딕 저장됨
# [3780/3837] (주)아티스트스튜디오 저장됨
# [3781/3837] 엘에스티라유텍(주) 저장됨
# [3782/3837] 대신밸런스제15호기업인수목적 주식회사 저장됨
# [3783/3837] 티씨머티리얼즈(주) 저장됨
# [3784/3837] 일정실업(주) 저장됨
# [3785/3837] (주)아티스트컴퍼니 저장됨
# [3786/3837] 우리금융캐피탈(주) 저장됨
# [3787/3837] 지에스건설(주) 저장됨
# [3788/3837] (주)케이에스인더스트리 저장됨
# [3789/3837] (주)휴먼테크놀로지 저장됨
# [3790/3837] (주)넥써쓰 저장됨
# [3791/3837] (주)경남은행 저장됨
# [3792/3837] 에이치엘비이노베이션(주) 저장됨
# [3793/3837] (주)에코글로우 저장됨
# [3794/3837] (주)마녀공장 저장됨
# [3795/3837] 주식회사 바이오비쥬 저장됨
# [3796/3837] (주)위닉스 저장됨
# [3797/3837] 올리패스(주) 저장됨
# [3798/3837] (주)인투셀 저장됨
# [3799/3837] 디케이엠이(주) 저장됨
# [3800/3837] (주)브이원텍 저장됨
# [3801/3837] 롯데이노베이트(주) 저장됨
# [3802/3837] (주)에코마케팅 저장됨
# [3803/3837] (주)이뮨온시아 저장됨
# [3804/3837] (주)한싹 저장됨
# [3805/3837] 엔에이치기업인수목적24호 주식회사 저장됨
# [3806/3837] 하나금융25호기업인수목적 주식회사 저장됨
# [3807/3837] (주)더즌 저장됨
# [3808/3837] (주)셀리버리 저장됨
# [3809/3837] (주)노보믹스 저장됨
# [3810/3837] (주)디에이치오토리드 저장됨
# [3811/3837] (주)판도라티비 저장됨
# [3812/3837] 엔에이치기업인수목적25호 주식회사 저장됨
# [3813/3837] (주)지씨지놈 저장됨
# [3814/3837] 제이준코스메틱(주) 저장됨
# [3815/3837] (주)코엔텍 저장됨
# [3816/3837] (주)디에이치오토웨어 저장됨
# [3817/3837] (주)베셀 저장됨
# [3818/3837] (주)네오크레마 저장됨
# [3819/3837] 삼성기업인수목적9호(주) 저장됨
# [3820/3837] 케이지에이(주) 저장됨
# [3821/3837] (주)조은저축은행 저장됨
# [3822/3837] 주식회사 꿈비 저장됨
# [3823/3837] 디와이덕양(주) 저장됨
# [3824/3837] (주)모나리자 저장됨
# [3825/3837] (주)티웨이항공 저장됨
# [3826/3837] 디에스씨인베스트먼트(주) 저장됨
# [3827/3837] (주)랩지노믹스 저장됨
# [3828/3837] (주)타이드 저장됨
# [3829/3837] 대진첨단소재(주) 저장됨
# [3830/3837] 고려아연(주) 저장됨
# [3831/3837] (주)새빗켐 저장됨
# [3832/3837] (주)더바이오메드 저장됨
# [3833/3837] (주)나라소프트 저장됨
# [3834/3837] (주)아이티센피엔에스 저장됨
# [3835/3837] (주)원일티엔아이 저장됨
# [3836/3837] 오가노이드사이언스(주) 저장됨
# [3837/3837] 에스케이엔펄스(주) 저장됨
